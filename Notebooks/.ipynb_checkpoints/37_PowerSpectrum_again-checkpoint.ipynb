# %% [markdown]
# ## Imports

# %%
import os
import sys
import numpy as np
import time
import scipy
import matplotlib.pyplot as plt
import time

# import the frank2d directory
current_dir =  os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

#frank2d
from frank2d import Frank2D 
from May31_Frank2D_CPU import *
from optimization import *

# frank1d
import frank
from frank.geometry import FixedGeometry, SourceGeometry, FitGeometryGaussian
from frank.radial_fitters import FrankFitter
from frank.utilities import UVDataBinner

# %% [markdown]
# ## Functions

# %%
def frank2d_cpu(disk_name, filename, disk_geometry, Rout, N = 100, maxiter=20000, kernel_params = {'m': -0.3, 'c': -0.1 , 'l': 1e4}):
    print("Running: " + disk_name +" ...." + " frank2d model with " + str(N)+ 'x'+str(N)+ " points" )

    inc = disk_geometry['inc']
    pa = disk_geometry['pa']
    dra = disk_geometry['dra']
    ddec = disk_geometry['ddec']
    
    # UVtable
    dir = "../../../data/"
    data_file = dir + filename
    
     # load data
    data = np.load(data_file)
    u, v, Re, Imag, Weights = data['u'], data['v'], data['Re'], data['Im'], data['w']
    Vis = Re + Imag*1j
    
    #idx = (np.abs(u) < 2e6) & (np.abs(v) < 2e6)
    #u, v, Vis, Weights =  u[idx], v[idx], Vis[idx], Weights[idx]
    
    geom = Geometry(inc, pa, dra, ddec)
    frank2d = Frank2D(N, Rout, geom)
    
    start_time = time.time()
    
    frank2d.preprocess_vis(u, v, Vis, Weights, hermitian= True)
    u_gridded, v_gridded, vis_gridded, weights_gridded = frank2d._gridded_data['u'], frank2d._gridded_data['v'], frank2d._gridded_data['vis'], frank2d._gridded_data['weights']
    sol = Frank2D_optimized(N, u_gridded, v_gridded, vis_gridded, weights_gridded, maxiter = maxiter,
                            kernel_params = kernel_params)
    frank2d.sol_visibility = sol
    frank2d.fft()
    
    end_time = time.time()
    execution_time = end_time - start_time
    print(f'  ------------------------------------------> TOTAL ALGORITHM TIME = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')

    return u_gridded, v_gridded, sol, frank2d, geom, [u, v, Vis, Weights]

# %% [markdown]
# ## Power Spectrum

# %%
AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}
HD143006 = {'inc':18.6, 'pa':169 , 'dra':-5.9e-3, 'ddec':21.7e-3, 'rout':0.518*2, 'disk_name': 'HD143006'}

data_dic = AS209

dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
disk_name = data_dic['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum.npz"


# Huang 2018 
inc = data_dic['inc']
pa = data_dic['pa']
dra = data_dic['dra']
ddec = data_dic['ddec']
r_out = data_dic['rout']

# Frank Parameters
N = 50
 # load data
data = np.load(data_file)

# %%
u, v, Re, Imag, Weights = data['u'], data['v'], data['Re'], data['Im'], data['w']

Vis = Re + Imag*1j

#idx = (np.abs(u) < 651362.5460434622) & (np.abs(v) < 651362.5460434622)

geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)

# %%
baselines = np.hypot(u, v)         
grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
                           np.log10(max(baselines.max(), baselines[-1])),
                           10**4)

cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths=[1e3, 1e5]
binned_vis = UVDataBinner(baselines, Vis, Weights, bin_widths[0])

# %%
def linear(x, m, c):
    return m*x + np.log10(c)

# %%
def power_spectrum(x, m, c):
    return c*(x**m)

# %%
m, c, l = -0.7, 100, 1e5

# %%
m_best1, c_best1 =  -3, 1e14
m_best2, c_best2 =  -2, 1e8 #-2, 1e8
m, c = -0.3, 60
m_array = [ -0.5, -0.9, -1, -1, -2, -2, -3, -3,  -3, -4,  -4, -4, -4]
c_array = [1e1, 1e2,  1e1,  1e3, 1e5, 1e8, 1e5, 1e8, 1e13, 1e15,  1e19, 1e21, 1e22]
log_c_array = [1, 2, 1, 3, 5, 8, 5, 8, 13, 15, 19, 21, 22]

x = binned_vis.uv[100:]
y = np.abs(binned_vis.V[100:])**2

plt.clf()
plt.figure(figsize=(12, 6))
logy = np.log10(y)
logx = np.log10(x)
plt.plot(logx, logy, c=cs[0], marker=ms[0], ls='None', label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))
for i in range(0, len(m_array)):
    plt.plot(logx, linear(logx, m_array[i], c_array[i]), ls = '--', label = f'm = {m_array[i]}, c = {c_array[i]:.1e}')
#plt.plot(logx, linear(logx, m_best1, c_best1), c = 'yellow', ls = '-', label = f'm_best = {m_best1}, c_best = {c_best1:.1e}')
#plt.plot(logx, linear(logx, m_best2, c_best2), c = 'pink',  ls = '-',  label = f'm_best = {m_best2}, c_best = {c_best2:.1e}')

plt.axhline(0, c='black', ls=':')
plt.title( data_dic['disk_name'], size = 10)    
plt.xlabel(r'log Baseline [$\lambda$]', size = 10)
plt.ylabel(r'log $|Vis_{Obs}|$ [Jy]', size = 10)
plt.legend(loc = 'best')
plt.ylim(-15, 1)
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_82046/3375083826.py:13: RuntimeWarning: divide by zero encountered in log10
#   logy = np.log10(y)
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_82046/3375083826.py:14: RuntimeWarning: divide by zero encountered in log10
#   logx = np.log10(x)

# %% [markdown]
# ## Plotting with F1D

# %%
data = data_dic

dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum_gridded_N200.txt"


# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
r_out = data['rout']

# Frank Parameters
N = 50
 # load data
u, v, Re, Im, Weights = np.loadtxt(data_file, unpack = True)
Vis = Re + Im*1j

geom = Geometry(inc= inc, pa= pa, dra= dra, ddec= ddec)

# %%
import time
start_time = time.time()
FF = FourierBesselFitter(r_out, N, geom)
sol = FF.fit(u, v, Vis, Weights)
total_time = time.time() - start_time
print("--- %s minutes ---", total_time/60, " or ", total_time, " seconds.")
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/optimization.py:381: RuntimeWarning: divide by zero encountered in log
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/optimization.py:381: RuntimeWarning: invalid value encountered in scalar multiply
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# Minimum frequency in the data: 42971.83463481175
# Maximum frequency in the data: 1519283.783515117
# --- %s minutes --- 0.9450681289037068  or  56.70408773422241  seconds.

# %%
GM = FF._GaussianModel

# %%
x_min, x_max = -4, 0
y_min, y_max = 0, 25

nx, ny = 20, 20
x = np.linspace(x_min, x_max, nx)
y = np.linspace(y_min, y_max, ny)
X, Y = np.meshgrid(x, y)

m_array = X.flatten()
log_c_array = Y.flatten()

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'

# %%
# Caculating likelihood
import time

minus_log_likelihood_array = []
intensity_array = []

logdetS_array = []
logdetD_array = []
jTDj_array = []

start_time = time.time()
for i in range(0, len(m_array)):
    minus_log_likelihood, logdetS, logdetD, jTDj = GM.likelihood([m_array[i], log_c_array[i]])
    minus_log_likelihood_array.append(minus_log_likelihood)
    logdetS_array.append(logdetS)
    logdetD_array.append(logdetD)
    jTDj_array.append(jTDj)
    intensity_array.append(GM.mean)
    print(f"for (m, log_c):({m_array[i]}, {log_c_array[i]}) with likelihood: {minus_log_likelihood: 2e}")

print("--- %s minutes ---" % (time.time()/60 - start_time/60))
# Out:
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 1.0 5
# --- 11.056648969650269 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 0.0) with likelihood:  6.232225e-06
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 1.0 5
# --- 10.384919166564941 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 0.0) with likelihood:  5.810191e-05
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 1.0 5
# --- 10.01295518875122 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 0.0) with likelihood:  5.412590e-04
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 1.0 5
# --- 11.08206582069397 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 0.0) with likelihood:  5.039041e-03
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 1.0 5
# --- 11.68190598487854 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 0.0) with likelihood:  4.689475e-02
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 1.0 5
# --- 14.564146041870117 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 0.0) with likelihood:  4.364479e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 1.0 5
# --- 12.344897031784058 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 0.0) with likelihood:  4.065515e+00
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 1.0 5
# --- 10.948657989501953 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 0.0) with likelihood:  3.795253e+01
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 1.0 5
# --- 10.050678730010986 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 0.0) with likelihood:  3.558756e+02
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 1.0 5
# --- 10.489624977111816 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 0.0) with likelihood:  3.378500e+03
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 1.0 5
# --- 11.341416358947754 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 0.0) with likelihood:  3.570800e+04
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 1.0 5
# --- 11.659862041473389 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 0.0) with likelihood:  1.008348e+06
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 1.0 5
# --- 11.833364963531494 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 0.0) with likelihood: -2.878386e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 1.0 5
# --- 12.354416847229004 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 0.0) with likelihood: -1.168639e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 1.0 5
# --- 11.21915316581726 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 0.0) with likelihood: -1.282267e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 1.0 5
# --- 5.83923602104187 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 0.0) with likelihood: -1.312390e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 1.0 5
# --- 5.472497940063477 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 0.0) with likelihood: -1.273013e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 1.0 5
# --- 5.082546949386597 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 0.0) with likelihood: -1.272899e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 1.0 5
# --- 5.1894919872283936 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 0.0) with likelihood: -1.272864e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 1.0 5
# --- 4.794353008270264 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 0.0) with likelihood: -1.272828e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 20.6913808111479 5
# --- 10.615907907485962 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 1.3157894736842106) with likelihood:  1.289566e-04
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 20.6913808111479 5
# --- 10.561038970947266 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 1.3157894736842106) with likelihood:  1.202207e-03
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 20.6913808111479 5
# --- 10.300177335739136 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 1.3157894736842106) with likelihood:  1.119940e-02
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 20.6913808111479 5
# --- 11.905150890350342 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 1.3157894736842106) with likelihood:  1.042647e-01
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 20.6913808111479 5
# --- 11.691054105758667 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 1.3157894736842106) with likelihood:  9.703171e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 20.6913808111479 5
# --- 11.681636095046997 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 1.3157894736842106) with likelihood:  9.030716e+00
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 20.6913808111479 5
# --- 11.192927122116089 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 1.3157894736842106) with likelihood:  8.412223e+01
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 20.6913808111479 5
# --- 11.18809986114502 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 1.3157894736842106) with likelihood:  7.855024e+02
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 20.6913808111479 5
# --- 10.968522071838379 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 1.3157894736842106) with likelihood:  7.403961e+03
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 20.6913808111479 5
# --- 11.815496921539307 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 1.3157894736842106) with likelihood:  7.761324e+04
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 20.6913808111479 5
# --- 12.079121828079224 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 1.3157894736842106) with likelihood:  2.248949e+06
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 20.6913808111479 5
# --- 12.628957033157349 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 1.3157894736842106) with likelihood: -1.038788e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 20.6913808111479 5
# --- 14.135148048400879 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 1.3157894736842106) with likelihood: -1.028896e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 20.6913808111479 5
# --- 12.127422094345093 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 1.3157894736842106) with likelihood: -1.268200e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 20.6913808111479 5
# --- 5.589795827865601 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 1.3157894736842106) with likelihood: -1.307456e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 20.6913808111479 5
# --- 5.646270990371704 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 1.3157894736842106) with likelihood: -1.273003e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 20.6913808111479 5
# --- 5.989581108093262 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 1.3157894736842106) with likelihood: -1.272897e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 20.6913808111479 5
# --- 5.747709035873413 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 1.3157894736842106) with likelihood: -1.272862e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 20.6913808111479 5
# --- 5.516721248626709 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 1.3157894736842106) with likelihood: -1.272826e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 20.6913808111479 5
# --- 5.585459232330322 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 1.3157894736842106) with likelihood: -1.272790e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 428.13323987193957 5
# --- 12.845402717590332 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 2.6315789473684212) with likelihood:  2.668290e-03
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 428.13323987193957 5
# --- 12.543329954147339 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 2.6315789473684212) with likelihood:  2.487533e-02
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 428.13323987193957 5
# --- 11.214044094085693 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 2.6315789473684212) with likelihood:  2.317310e-01
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 428.13323987193957 5
# --- 10.953022003173828 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 2.6315789473684212) with likelihood:  2.157381e+00
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 428.13323987193957 5
# --- 12.812503099441528 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 2.6315789473684212) with likelihood:  2.007721e+01
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 428.13323987193957 5
# --- 11.526062965393066 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 2.6315789473684212) with likelihood:  1.868605e+02
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 428.13323987193957 5
# --- 10.815830945968628 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 2.6315789473684212) with likelihood:  1.741082e+03
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 428.13323987193957 5
# --- 11.721487998962402 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 2.6315789473684212) with likelihood:  1.634397e+04
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 428.13323987193957 5
# --- 10.914148807525635 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 2.6315789473684212) with likelihood:  1.705352e+05
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 428.13323987193957 5
# --- 11.372506141662598 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 2.6315789473684212) with likelihood:  5.133083e+06
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 428.13323987193957 5
# --- 10.43466591835022 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 2.6315789473684212) with likelihood: -5.356524e+07
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 428.13323987193957 5
# --- 10.169370174407959 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 2.6315789473684212) with likelihood:  1.617843e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 428.13323987193957 5
# --- 10.463135004043579 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 2.6315789473684212) with likelihood: -1.276055e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 428.13323987193957 5
# --- 5.323460102081299 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 2.6315789473684212) with likelihood: -1.303345e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 428.13323987193957 5
# --- 5.972654104232788 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 2.6315789473684212) with likelihood: -1.272993e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 428.13323987193957 5
# --- 5.7779247760772705 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 2.6315789473684212) with likelihood: -1.272895e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 428.13323987193957 5
# --- 5.516956806182861 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 2.6315789473684212) with likelihood: -1.272859e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 428.13323987193957 5
# --- 6.096919059753418 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 2.6315789473684212) with likelihood: -1.272824e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 428.13323987193957 5
# --- 5.820345878601074 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 2.6315789473684212) with likelihood: -1.272788e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 428.13323987193957 5
# --- 4.733216047286987 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 2.6315789473684212) with likelihood: -1.272753e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 8858.667904100832 5
# --- 12.00481915473938 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 3.947368421052632) with likelihood:  5.521061e-02
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 8858.667904100832 5
# --- 10.522694110870361 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 3.947368421052632) with likelihood:  5.147049e-01
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 8858.667904100832 5
# --- 11.5433931350708 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 3.947368421052632) with likelihood:  4.794834e+00
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 8858.667904100832 5
# --- 10.822330951690674 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 3.947368421052632) with likelihood:  4.463922e+01
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 8858.667904100832 5
# --- 11.112922191619873 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 3.947368421052632) with likelihood:  4.154309e+02
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 8858.667904100832 5
# --- 13.001046895980835 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 3.947368421052632) with likelihood:  3.867476e+03
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 8858.667904100832 5
# --- 13.280243873596191 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 3.947368421052632) with likelihood:  3.622985e+04
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 8858.667904100832 5
# --- 11.081685066223145 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 3.947368421052632) with likelihood:  3.772867e+05
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 8858.667904100832 5
# --- 13.316030263900757 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 3.947368421052632) with likelihood:  1.227903e+07
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 8858.667904100832 5
# --- 11.337216854095459 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 3.947368421052632) with likelihood:  7.475203e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 8858.667904100832 5
# --- 10.183338165283203 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 3.947368421052632) with likelihood: -2.538157e+09
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 8858.667904100832 5
# --- 10.723718881607056 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 3.947368421052632) with likelihood: -1.271633e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 8858.667904100832 5
# --- 5.439191818237305 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 3.947368421052632) with likelihood: -1.299862e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 8858.667904100832 5
# --- 5.689711809158325 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 3.947368421052632) with likelihood: -1.272985e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 8858.667904100832 5
# --- 5.5484230518341064 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 3.947368421052632) with likelihood: -1.272892e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 8858.667904100832 5
# --- 5.8970019817352295 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 3.947368421052632) with likelihood: -1.272857e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 8858.667904100832 5
# --- 5.873661994934082 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 3.947368421052632) with likelihood: -1.272821e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 8858.667904100832 5
# --- 5.885804176330566 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 3.947368421052632) with likelihood: -1.272786e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 8858.667904100832 5
# --- 5.655343770980835 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 3.947368421052632) with likelihood: -1.272750e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 8858.667904100832 5
# --- 4.5081987380981445 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 3.947368421052632) with likelihood: -1.272715e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 183298.07108324376 5
# --- 10.740855932235718 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 5.2631578947368425) with likelihood:  1.142384e+00
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 183298.07108324376 5
# --- 10.735107898712158 seconds to calculate log_likelihood ---
# for (m, log_c):(-3
seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 7.894736842105264) with likelihood:  4.248878e+04
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 78475997.03514622 5
# --- 11.834730863571167 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 7.894736842105264) with likelihood:  3.979167e+05
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 78475997.03514622 5
# --- 12.164788961410522 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 7.894736842105264) with likelihood:  4.181252e+06
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 78475997.03514622 5
# --- 10.18227505683899 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 7.894736842105264) with likelihood: -2.198980e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 78475997.03514622 5
# --- 10.149438858032227 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 7.894736842105264) with likelihood: -5.395673e+07
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 78475997.03514622 5
# --- 10.350192070007324 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 7.894736842105264) with likelihood: -1.452064e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 78475997.03514622 5
# --- 11.298496007919312 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 7.894736842105264) with likelihood: -1.272945e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 78475997.03514622 5
# --- 4.946892976760864 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 7.894736842105264) with likelihood: -1.292033e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 78475997.03514622 5
# --- 5.28053617477417 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 7.894736842105264) with likelihood: -1.272962e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 78475997.03514622 5
# --- 5.665727138519287 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 7.894736842105264) with likelihood: -1.272886e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 78475997.03514622 5
# --- 5.385002136230469 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 7.894736842105264) with likelihood: -1.272850e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 78475997.03514622 5
# --- 5.032048940658569 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 7.894736842105264) with likelihood: -1.272815e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 78475997.03514622 5
# --- 5.099695205688477 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 7.894736842105264) with likelihood: -1.272779e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 78475997.03514622 5
# --- 5.155493974685669 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 7.894736842105264) with likelihood: -1.272743e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 78475997.03514622 5
# --- 5.088904857635498 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 7.894736842105264) with likelihood: -1.272708e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 78475997.03514622 5
# --- 5.4501049518585205 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 7.894736842105264) with likelihood: -1.272672e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 78475997.03514622 5
# --- 5.604647159576416 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 7.894736842105264) with likelihood: -1.272637e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 78475997.03514622 5
# --- 5.091335773468018 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 7.894736842105264) with likelihood: -1.272601e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 1623776739.1887243 5
# --- 10.815821647644043 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 9.210526315789474) with likelihood:  1.012015e+04
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 1623776739.1887243 5
# --- 10.09971284866333 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 9.210526315789474) with likelihood:  9.437365e+04
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 1623776739.1887243 5
# --- 11.49137282371521 seconds to calculate log_likelihood ---
# for (m, log_c):(-3
+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 4.832930238571772e+23 5
# --- 5.778759956359863 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 23.68421052631579) with likelihood: -1.272574e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 4.832930238571772e+23 5
# --- 5.8794450759887695 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 23.68421052631579) with likelihood: -1.272538e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 4.832930238571772e+23 5
# --- 5.705935001373291 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 23.68421052631579) with likelihood: -1.272502e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 4.832930238571772e+23 5
# --- 5.805318117141724 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 23.68421052631579) with likelihood: -1.272467e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 4.832930238571772e+23 5
# --- 5.919035911560059 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 23.68421052631579) with likelihood: -1.272431e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 4.832930238571772e+23 5
# --- 5.507239818572998 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 23.68421052631579) with likelihood: -1.272396e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 4.832930238571772e+23 5
# --- 5.413568019866943 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 23.68421052631579) with likelihood: -1.272360e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 4.832930238571772e+23 5
# --- 5.509396076202393 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 23.68421052631579) with likelihood: -1.272324e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 4.832930238571772e+23 5
# --- 5.256425857543945 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 23.68421052631579) with likelihood: -1.272289e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 4.832930238571772e+23 5
# --- 5.025106191635132 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 23.68421052631579) with likelihood: -1.272253e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 4.832930238571772e+23 5
# --- 6.206608057022095 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 23.68421052631579) with likelihood: -1.272218e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 4.832930238571772e+23 5
# --- 6.007258892059326 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 23.68421052631579) with likelihood: -1.272182e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 4.832930238571772e+23 5
# --- 6.408332109451294 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 23.68421052631579) with likelihood: -1.272147e+08
# ......................................... Calculating likelihood with m, c, log(l):  -4.0 1e+25 5
# --- 7.076297998428345 seconds to calculate log_likelihood ---
# for (m, log_c):(-4.0, 25.0) with likelihood: -1.272785e+08
# ......................................... Calculating likelihood with m, c, log(l):  -3.7894736842105265 1e+25 5
# --- 6.681529998779297 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.7894736842105265, 25.0) with likelihood: -1.272749e+08
# ......................................... Calculating likelihood with m, c, log(l):  -3.5789473684210527 1e+25 5
# --- 6.942171812057495 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.5789473684210527, 25.0) with likelihood: -1.272714e+08
# ......................................... Calculating likelihood with m, c, log(l):  -3.3684210526315788 1e+25 5
# --- 7.324753761291504 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.3684210526315788, 25.0) with likelihood: -1.272678e+08
# ......................................... Calculating likelihood with m, c, log(l):  -3.1578947368421053 1e+25 5
# --- 7.028984069824219 seconds to calculate log_likelihood ---
# for (m, log_c):(-3.1578947368421053, 25.0) with likelihood: -1.272642e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.947368421052632 1e+25 5
# --- 6.02749490737915 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.947368421052632, 25.0) with likelihood: -1.272607e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.736842105263158 1e+25 5
# --- 6.532383918762207 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.736842105263158, 25.0) with likelihood: -1.272571e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.526315789473684 1e+25 5
# --- 6.516759157180786 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.526315789473684, 25.0) with likelihood: -1.272536e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.3157894736842106 1e+25 5
# --- 7.258946180343628 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.3157894736842106, 25.0) with likelihood: -1.272500e+08
# ......................................... Calculating likelihood with m, c, log(l):  -2.105263157894737 1e+25 5
# --- 6.993017673492432 seconds to calculate log_likelihood ---
# for (m, log_c):(-2.105263157894737, 25.0) with likelihood: -1.272465e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.8947368421052633 1e+25 5
# --- 6.667298078536987 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.8947368421052633, 25.0) with likelihood: -1.272429e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.6842105263157894 1e+25 5
# --- 6.336903095245361 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.6842105263157894, 25.0) with likelihood: -1.272393e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.473684210526316 1e+25 5
# --- 6.3915159702301025 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.473684210526316, 25.0) with likelihood: -1.272358e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.2631578947368425 1e+25 5
# --- 7.048978090286255 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.2631578947368425, 25.0) with likelihood: -1.272322e+08
# ......................................... Calculating likelihood with m, c, log(l):  -1.0526315789473686 1e+25 5
# --- 6.58850884437561 seconds to calculate log_likelihood ---
# for (m, log_c):(-1.0526315789473686, 25.0) with likelihood: -1.272287e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.8421052631578947 1e+25 5
# --- 5.464221000671387 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.8421052631578947, 25.0) with likelihood: -1.272251e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.6315789473684212 1e+25 5
# --- 6.193525075912476 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.6315789473684212, 25.0) with likelihood: -1.272215e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.4210526315789478 1e+25 5
# --- 6.016209840774536 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.4210526315789478, 25.0) with likelihood: -1.272180e+08
# ......................................... Calculating likelihood with m, c, log(l):  -0.2105263157894739 1e+25 5
# --- 5.63486909866333 seconds to calculate log_likelihood ---
# for (m, log_c):(-0.2105263157894739, 25.0) with likelihood: -1.272144e+08
# ......................................... Calculating likelihood with m, c, log(l):  0.0 1e+25 5
# --- 5.913535833358765 seconds to calculate log_likelihood ---
# for (m, log_c):(0.0, 25.0) with likelihood: -1.272109e+08
# --- 47.77312371507287 seconds ---

# %%
minus_log_likelihood_array = np.array(minus_log_likelihood_array)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

norm = colors.CenteredNorm()
Z = minus_log_likelihood_array.reshape(nx, ny)/1e9

plt.figure()
pcm = plt.pcolormesh(X, Y, Z, cmap="magma", norm=norm, shading="auto")
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
cbar = plt.colorbar(pcm, shrink=0.9)
cbar.set_label(r"$-\log \mathcal{P}(\theta | X) \,/\,10^9$")
plt.title( data_dic['disk_name'], size = 10)    


plt.tight_layout()
plt.show()

# %%
norm = colors.CenteredNorm()
Z = np.array(logdetS_array).reshape(nx, ny)/1e9


plt.figure()
pcm = plt.pcolormesh(X, Y, Z, cmap="magma", norm=norm, shading="auto")
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
cbar = plt.colorbar(pcm, shrink=0.9)
cbar.set_label(r"$-\log \mathcal{P}(\theta | X) \,/\,10^9$")
plt.title(data_dic['disk_name'] +': logdetS term', size=10)

plt.tight_layout()
plt.show()

# %%
norm = colors.CenteredNorm()
Z = np.array(logdetD_array).reshape(nx, ny)/1e9


plt.figure()
pcm = plt.pcolormesh(X, Y, Z, cmap="magma", norm=norm, shading="auto")
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
cbar = plt.colorbar(pcm, shrink=0.9)
cbar.set_label(r"$-\log \mathcal{P}(\theta | X) \,/\,10^9$")
plt.title(data_dic['disk_name'] +': -logdetD term', size=10)

plt.tight_layout()
plt.show()

# %%
norm = colors.CenteredNorm()
Z = np.array(jTDj_array).reshape(nx, ny)/1e9


plt.figure()
pcm = plt.pcolormesh(X, Y, Z, cmap="magma", norm=norm, shading="auto")
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
cbar = plt.colorbar(pcm, shrink=0.9)
cbar.set_label(r"$-\log \mathcal{P}(\theta | X) \,/\,10^9$")
plt.title(data_dic['disk_name'] +': -jTDj term', size=10)

plt.tight_layout()
plt.show()

# %%
N = 50

# %%
x_f1d = FF._DFT._Xn * rad_to_arcsec
y_f1d = FF._DFT._Yn * rad_to_arcsec

Xg = x_f1d.reshape(N, N)
Yg = y_f1d.reshape(N, N)

I_list = []
for I in intensity_array:
    I = np.asarray(I)
    if I.ndim == 1:
        I = I.reshape(N, N)
    elif I.shape != (N, N):
        raise ValueError(f"Mapa con forma {I.shape}, esperado {(N,N)}")
    I_list.append(I)

vmax = np.nanmax([np.nanmax(I) for I in I_list])
norm = colors.PowerNorm(gamma=0.5, vmin=0, vmax=3e10)


nrows, ncols = 10, 10
fig, axs = plt.subplots(nrows, ncols,
                        figsize=(2*ncols, 2*nrows),
                        constrained_layout=True)

axs = np.array(axs)  # shape (10,10)

for k, I in enumerate(I_list):
    row, col = divmod(k, ncols)
    row_inv = nrows - 1 - row
    ax = axs[row_inv, col]

    im = ax.pcolormesh(Xg, Yg, I, shading='auto', cmap="magma", norm=norm)
    ax.invert_xaxis()
    ax.set_aspect(1)

    ax.set_xticks([])
    ax.set_yticks([])


m_vals = np.unique(m_array.reshape(nrows, ncols)[0, :])        # columnas
logc_vals = np.unique(log_c_array.reshape(nrows, ncols)[:, 0]) # filas

for j, m_val in enumerate(m_vals):
    axs[-1, j].set_xlabel(f"{m_val:.2g}")

for i, logc_val in enumerate(logc_vals[::-1]):  # invertido porque reordenamos filas
    axs[i, 0].set_ylabel(f"{logc_val:.2g}")

fig.suptitle(data_dic['disk_name'] , fontsize=16)
fig.text(0.5, -0.008, r"$m$", ha="center", fontsize=14)
fig.text(-0.008, 0.5, r"$\log_{10} c$", va="center", rotation="vertical", fontsize=14)

cbar = fig.colorbar(im, ax=axs.ravel().tolist(), shrink=0.9, pad=0.01)
cbar.set_label(r"$I_{\mathrm{model}}\;[\mathrm{Jy}\,\mathrm{sr}^{-1}]$", size=12)

plt.show()

# %%
idx_min = np.argmin(minus_log_likelihood_array)
val_min = minus_log_likelihood_array[idx_min]

m_best = m_array[idx_min]
log_c_best = log_c_array[idx_min]
print(f"({m_best}, {log_c_best}) with - log posterior = {val_min}")
# Out:
# (-4.0, 16.666666666666664) with - log posterior = -11936796.192451093

# %%
idx_flat = np.argmin(Z)
i, j = np.unravel_index(idx_flat, Z.shape)
print(i, j)
# Out:
# 6 0

# %% [markdown]
# ## Plot the best fit

# %%
m_best = -4.05
log_c_best = 15.11

# %%
c_best = 10**(log_c_best)

# %%
x = binned_vis.uv[100:]
y = np.abs(binned_vis.V[100:].real)**2

plt.figure(figsize=(5, 2))
plt.plot(x, y, c=cs[0], marker=ms[0], ls='None', label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))
plt.plot(x, power_spectrum(x, m_best, c_best), label = f'best -> m = {m_best:.2f}, log(c) = {log_c_best:.2f}', color = 'red')
plt.axhline(0, c='c', ls='-')
plt.title(r'$Vis_{Obs}$ '+ data_dic['disk_name'], size = 10)    
plt.xlabel(r'log Baseline [$\lambda$]', size = 10)
plt.ylabel(r'log $|Re(V)|^{2}$ [Jy]', size = 10)
plt.xscale('log', base = 10)
plt.yscale('log', base = 10)
plt.ylim(1e-18, 0)
plt.legend(loc = 'best')
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_79236/1516205827.py:13: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(1e-18, 0)

# %%
FF._GaussianModel.one_fit([m_best, log_c_best])
# Out:
#                  --------------> Fitting with m, c, log_l: -4.05 1288249551693132.2 5

# %%
N = 50

# %%
I = GM.mean
I_reshape = I.reshape(N, N)
r_out_rad = r_out

import matplotlib.colors as colors

x_f1d = FF._DFT._Xn * rad_to_arcsec
y_f1d = FF._DFT._Yn * rad_to_arcsec
u_f1d = FF._DFT._Un
v_f1d = FF._DFT._Vn

fig, axs = plt.subplots(2, 1, figsize=(4, 6), constrained_layout=True)  # 1 columna, 2 filas
# --- Panel 1: Real plane ---
norm = colors.PowerNorm(gamma=0.5, vmin=0, vmax = 3e10)

fig.suptitle(f'best-> m = {m_best:.2f}, $log(c) $ =  {log_c_best:.2f}, N = ' + str(N), fontsize=10)

plot1 = axs[0].pcolormesh(x_f1d.reshape(N, N),
                          y_f1d.reshape(N, N),
                          I_reshape, cmap="magma", norm=norm)
cbar1 = fig.colorbar(plot1, ax=axs[0], shrink = 0.9, pad=0.01)
cbar1.set_label(r'$I_{model}$ [$Jy\, sr^{-1}$]', size=12)
axs[0].invert_xaxis()
axs[0].set_title(r'Real plane')
axs[0].set_xlabel("x ['']")
axs[0].set_ylabel("y ['']")
axs[0].set_aspect(1)

# --- Panel 2: Fourier plane ---
plot2 = axs[1].pcolormesh(np.fft.fftshift(u_f1d.reshape(N, N))/1e6,
                          np.fft.fftshift(v_f1d.reshape(N, N))/1e6,
                          np.log(np.fft.fftshift(np.abs(np.fft.ifft2(I_reshape)))),
                          cmap="magma")
cbar2 = fig.colorbar(plot2, ax=axs[1], shrink = 1, pad=0.01)
cbar2.set_label(r'$\log(|Vis_{model}|)$ [$Jy^{2}$]', size=12)
axs[1].set_title(r'Fourier plane')
axs[1].set_xlabel(r'u [10$^{6}$ $\lambda$]')
axs[1].set_ylabel(r'v [10$^{6}$ $\lambda$]')
axs[1].set_aspect(1)

plt.show()

# %%
sol = FF._sol

# %%
from scipy.stats import binned_statistic

def get_vis_profile_binned(u, v, Vis, n_bins = 300, weighted = False):
    q = np.hypot(u, v)
    
    Vis_binned, bin_edges, _ = binned_statistic(q, Vis, 'mean', bins = n_bins)
    q_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    return q_centers, Vis_binned

# %%
#  Plot variables.
cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths = [1e3, 1e5]

baselines = np.hypot(u, v)         
grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
                           np.log10(max(baselines.max(), baselines[-1])),
                           10**4)

plt.figure(figsize=(14,5))

# Raw visibilities -------------------------------------------------------------------
binned_vis = UVDataBinner(baselines, Vis, Weights, bin_widths[0])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[0],
             marker=ms[0], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))

#frank1d
u_f1d = FF._DFT._Un
v_f1d = FF._DFT._Vn

n_bins = 150
vis_fit_1d = sol.predict(u_f1d, v_f1d, I = sol.mean)
baselines_centers, vis_fit = get_vis_profile_binned(u_f1d, v_f1d, vis_fit_1d, n_bins = n_bins, weighted = True)
plt.plot(baselines_centers, np.abs(vis_fit), color = "blue", ls ='--', label = r'fit')

binned_vis = UVDataBinner(baselines, Vis, Weights, bin_widths[1])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[1],
             marker=ms[1], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[1]/1e3))


plt.xlabel(r'baseline [$\lambda$]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(0.5e-4, 1)
plt.xlim(1e5, 6e6)
plt.ylabel('|V| [Jy]', size = 10)
plt.title(r'$V_{Model}$ F2D simulated in F1D with N = ' + str(N))
plt.legend(fontsize= 10)
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_79236/3552204767.py:6: RuntimeWarning: divide by zero encountered in log10
#   grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/Frank2D_PROD/lib/python3.12/site-packages/numpy/_core/function_base.py:168: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/Frank2D_PROD/lib/python3.12/site-packages/numpy/_core/function_base.py:178: RuntimeWarning: invalid value encountered in add
#   y += start
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:224: RuntimeWarning: invalid value encountered in divide
#   bin_uv[idx] /= w
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:225: RuntimeWarning: invalid value encountered in divide
#   bin_vis[idx] /= w
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:250: RuntimeWarning: invalid value encountered in divide
#   err[idx2] /= bin_wgt[idx2]**2 * (1 - 1 / bin_n[idx2])
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:259: RuntimeWarning: divide by zero encountered in divide
#   bin_vis_err[idx1].real = 1 / np.sqrt(bin_wgt[idx1])
