# %% [markdown]
# ## Frank2D CPU
# ### Description
# This algorithm uses gridded data from gridding the UVTABLE data, to optimize the calculation of the visibilities solution through Frankenstein scheme.

# %% [markdown]
# #### Imports

# %%
import os
import sys
import numpy as np
import time
import scipy
import matplotlib.pyplot as plt
import time


from scipy.stats import binned_statistic
from scipy.interpolate import interp1d
from scipy.sparse.linalg import LinearOperator, splu
from scipy.sparse.linalg._isolve.utils import make_system
from scipy.sparse import csr_matrix

current_dir =  os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

#frank2d
from frank2d import Frank2D
from constants import rad_to_arcsec, deg_to_rad
from plot import Plot
from fitting import IterativeSolverMethod
from preprocess_vis import Gridding
from geometry import Geometry

# %% [markdown]
# #### Functions

# %% [markdown]
# #### CGM

# %%
def cg(A, b, x0=None, rtol=1e-7, atol=0.0, maxiter=None, M=None, callback=None):
    # Assume: A, M are LinearOperators; b is 1-D ndarray.

    # Build initial guess x
    if x0 is None:
        # No initial guess: start from zeros, keep b's dtype
        x = np.zeros_like(b, dtype=b.dtype)
    else:
        # Use x0, cast to a safe result dtype with b
        x0 = np.asarray(x0)
        x = x0.astype(np.result_type(b.dtype, x0.dtype), copy=True)

    # Default preconditioner: identity
    if M is None:
        class _Id:
            def matvec(self, v): return v
        M = _Id()

    # Norm of RHS and effective stopping tolerance
    bnrm2 = np.linalg.norm(b)
    eff_atol = max(atol, rtol * bnrm2)

    if bnrm2 == 0.0:
        return b, 0

    n = len(b)
    if maxiter is None:
        maxiter = n * 10

    # Inner product and operators
    dotprod = np.vdot if np.iscomplexobj(x) else np.dot
    matvec  = A.matvec
    psolve  = M.matvec

    # Initial residual
    r = b - matvec(x) if x.any() else b.copy()

    # Dummy init
    rho_prev, p = None, None

    for iteration in range(maxiter):
        print(".... iteration: ", iteration)
        # Convergence check
        act_tol = np.linalg.norm(r)
        print("                        -> actual tol: ", str(act_tol), "vs ", str(atol))
        if act_tol < eff_atol:
            return x, 0

        # Preconditioned residual
        z = psolve(r)
        rho_cur = dotprod(r, z)

        if iteration > 0:
            beta = rho_cur / rho_prev
            p *= beta
            p += z
        else:
            p = np.empty_like(r)
            p[:] = z[:]

        q = matvec(p)
        alpha = rho_cur / dotprod(p, q)

        x += alpha * p
        r -= alpha * q
        rho_prev = rho_cur

        if callback:
            callback(x)

    # Incomplete progress
    return x, maxiter

# %%
def bicgstab(A, b, x0=None, rtol=1e-7, atol=0., maxiter=None, M=None, callback=None):
    print("     * BICGSTAB")

    # Assume: A, M are LinearOperators; b is 1-D ndarray of matching size.

    # Initial guess
    # Build initial guess x
    if x0 is None:
        # No initial guess: start from zeros, keep b's dtype
        x = np.zeros_like(b, dtype=b.dtype)
    else:
        # Use x0, cast to a safe result dtype with b
        x0 = np.asarray(x0)
        x = x0.astype(np.result_type(b.dtype, x0.dtype), copy=True)

    # Default preconditioner: identity
    if M is None:
        class _Id:
            def matvec(self, v): return v
        M = _Id()

    # Norm of RHS and stopping tolerance
    bnrm2 = np.linalg.norm(b)
    atol = max(float(atol), float(rtol) * float(bnrm2))
    print("Final tolerance : ", atol)

    if bnrm2 == 0:
        return b, 0

    n = len(b)
    if maxiter is None:
        maxiter = 2 * n

    # Inner products and operators
    dotprod = np.vdot if np.iscomplexobj(x) else np.dot
    matvec  = A.matvec
    psolve  = M.matvec

    # Breakdown tolerances (kept from original)
    rhotol   = np.finfo(x.dtype.char).eps**2
    omegatol = rhotol

    # Init
    rho_prev = omega = alpha = None
    p = v = None

    r = b - matvec(x) if x.any() else b.copy()
    rtilde = r.copy()

    for iteration in range(maxiter):
        print(".... iteration: ", iteration)
        act_tol = np.linalg.norm(r)
        print("                        -> actual tol: ", str(act_tol), "vs ", str(atol))
        if act_tol < atol:
            print(" --------------------------------------> CGM converged in ", iteration, " iterations with tol ", act_tol)
            return x, 0

        rho = dotprod(rtilde, r)
        if np.abs(rho) < rhotol:
            print("converged by norm of rho")
            return x, -10

        if iteration > 0:
            if np.abs(omega) < omegatol:
                print("converged by norm of omega")
                return x, -11
            beta = (rho / rho_prev) * (alpha / omega)
            p -= omega * v
            p *= beta
            p += r
        else:
            s = np.empty_like(r)
            p = r.copy()

        phat = psolve(p)
        v = matvec(phat)
        rv = dotprod(rtilde, v)
        if rv == 0:
            print("converged by rv = 0")
            return x, -11
        alpha = rho / rv
        r -= alpha * v
        s[:] = r[:]

        if np.linalg.norm(s) < atol:
            print("converged by norm of s")
            x += alpha * phat
            return x, 0

        shat = psolve(s)
        t = matvec(shat)
        omega = dotprod(t, s) / dotprod(t, t)
        x += alpha * phat
        x += omega * shat
        r -= omega * t
        rho_prev = rho

        if callback:
            callback(x)

    # Incomplete progress
    return x, maxiter

# %% [markdown]
# ####  Functions for optimization

# %%
def linear_operator(A, size):
    def dot_product(x):
        return A.dot(x)

    return LinearOperator(size, matvec=dot_product)

# %%
def P_k(r, k):
    if k == 0:
        return np.ones_like(r)  # P_0(r) = 1
    elif k == 1:
        return 4*r +1  # P_1(r) = 4r + 1
    elif k == 2:
        return (35/3)*r**2 +6*r + 1  # P_2(r) = 35r^2 + 18r + 3
    else:
        raise ValueError("k must be 0, 1, or 2.")

# %%
def kernel_row(u, v, i, min_freq, u2 = None, v2 = None, m = -0.33, c = -0.1, l = 1e5):
    def power_spectrum(q, m, c):
        if not np.isscalar(q):  
            q[q == 0] = min_freq
        elif q == 0:
            q = min_freq
        return (q**m)*np.exp(c)
    
    j, k = 4, 1
    H = 2*1.897367*l

    q = np.hypot(u, v)
    power_spectrum_q1 = power_spectrum(q, m, c)
    uh = u/H
    vh = v/H

    q2 = uh2 = vh2 =  None

    if isinstance(u2, np.ndarray):
        q2 = np.hypot(u2[i], v2[i])
        uh2 = u2[i]/H
        vh2 = v2[i]/H
    else:
        q2 = q[i]
        uh2 = uh[i]
        vh2 = vh[i]

    amp = np.sqrt(power_spectrum_q1 * power_spectrum(q2, m, c))
    
    r_normalized = np.sqrt((uh-uh2)**2 + (vh-vh2)**2)
    factor = (1 - r_normalized)**j
    factor[r_normalized > 1] = 0

    return amp * factor * P_k(r_normalized, k)

# %%
def create_sparse_kernel(kernel_function, u, v, min_freq, u2 = None, v2 = None ):
    data = []
    indices = []
    indptr = [0]
    size1 = size2 = None

    if isinstance(u2, np.ndarray):
        size1 = len(u2)
        size2 = len(u)
    else:
        size1 = size2 = len(u)

    for i in range(size1):
        row = kernel_function(u, v, i, min_freq, u2 = u2, v2 = v2) if isinstance(u2, np.ndarray) else kernel_function(u, v, i, min_freq)
            
        non_zero_indices = np.nonzero(row)[0]
        kernel_values = row[non_zero_indices]
        
        data.extend(kernel_values)
        indices.extend(non_zero_indices)
        indptr.append(len(data))

    data = np.array(data)
    indices = np.array(indices)
    indptr = np.array(indptr)

    size = (size1, size2)
    kernel_csr = csr_matrix((data, indices, indptr), shape=size)
    kernel = linear_operator(kernel_csr, size)

    return kernel

# %%
def create_sparse_system_data(u_gridded_data, v_gridded_data, vis_gridded_data, weights_gridded_data, min_freq):
    N_data = vis_gridded_data.shape[0]
    
    data_A = []
    indices_A = []
    indptr_A = [0]

    data_Aprecond = []
    indices_Aprecond = []
    indptr_Aprecond = [0]
    
    for i in range(N_data):  
        row = kernel_row(u_gridded_data, v_gridded_data, i, min_freq)
        non_zero_indices = np.nonzero(row)[0]
        non_zero_values = row[non_zero_indices]
        Nm1_S_values = non_zero_values * weights_gridded_data[i]

        # A
        diagonal_pos = np.where((non_zero_indices == i))[0][0]
        Nm1_S_values[diagonal_pos] += 1
        diag_value = Nm1_S_values[diagonal_pos]
        
        data_A.extend(Nm1_S_values)
        indices_A.extend(non_zero_indices)
        indptr_A.append(len(data_A))

        # Preconditioner of A
        data_Aprecond.extend([diag_value**(-1)])
        indices_Aprecond.extend([i])
        indptr_Aprecond.append(len(data_Aprecond))
        
    data_A = np.array(data_A)
    indices_A = np.array(indices_A)
    indptr_A = np.array(indptr_A)

    data_Aprecond = np.array(data_Aprecond)
    indices_Aprecond = np.array(indices_Aprecond)
    indptr_Aprecond = np.array(indptr_Aprecond)

    A_csr = csr_matrix((data_A, indices_A, indptr_A), shape=(N_data, N_data))
    A_precond_csr = csr_matrix((data_Aprecond, indices_Aprecond, indptr_Aprecond), shape=(N_data, N_data))

    A = linear_operator(A_csr, (N_data, N_data))
    A_precond = linear_operator(A_precond_csr, (N_data, N_data))
    b = weights_gridded_data * vis_gridded_data

    return A, A_precond, b

# %% [markdown]
# ### Frank2D CPU

# %% [markdown]
# **Params for algorithm: N, u_gridded, v_gridded, Visibilities_gridded, Weights_gridded**

# %%
def Frank2D_optimized(N, u_gridded, v_gridded, vis_gridded, weights_gridded, maxiter = 20000):
    input = weights_gridded.reshape(N, N)
    data_index = np.argwhere(input.flatten() != 0)
    no_data_index = np.argwhere(input.flatten() == 0) 

    # data
    u_gridded_data = u_gridded[data_index].flatten()
    v_gridded_data = v_gridded[data_index].flatten()
    vis_gridded_data  = vis_gridded[data_index].flatten()
    weights_gridded_data = weights_gridded[data_index].flatten()

    # no data or data with weights == 0.
    u_gridded_no_data = u_gridded[no_data_index].flatten()
    v_gridded_no_data = v_gridded[no_data_index].flatten()
    vis_gridded_no_data  = vis_gridded[no_data_index].flatten()
    weights_gridded_no_data = weights_gridded[no_data_index].flatten()

    #  We intend to solve now:  (I + N^{-1} S_{11})  V* = N^{-1} V_{data} with CGM
    min_freq = np.sort(np.abs(np.unique(v_gridded_data)))[1]

    print("------> Creating linear operators")
    start_time = time.time()
    S11_linearOp = create_sparse_kernel(kernel_row, u_gridded_data, v_gridded_data, min_freq)
    S12_T_linearOp = create_sparse_kernel(kernel_row, u_gridded_data, v_gridded_data, min_freq, u2 = u_gridded_no_data, v2 = v_gridded_no_data)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f'  --> time = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
    print("---------------------------------")

    print("------> Creating sparse system")
    start_time = time.time()
    params = [u_gridded_data, v_gridded_data, vis_gridded_data, weights_gridded_data, min_freq]
    A_opt, A_precond_opt, b_opt = create_sparse_system_data(*params)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f'  --> time = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
    print("---------------------------------")

    print("------> Running CGM")
    start_time = time.time()
    x_data, info = cg(A_opt, b_opt, M = A_precond_opt, rtol = 1e-8, maxiter = maxiter)
    C_ = x_data
    end_time = time.time()
    execution_time = end_time - start_time
    print(f'  --> time = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
    print("---------------------------------")
    
    print("------> CGM converged?  ", info == 0)
    fit_correctly = np.allclose(A_opt.matvec(C_), b_opt)
    print("              --> Fit correctly?  ", fit_correctly)
    if fit_correctly:
        print("                                                     !!!!!!!!!!!!!!!!!!! CORRECT !!!!!!!!!!!!!!!!!!!")
    print("---------------------------------")
    

    def recovering_sol(C):
        V_1_m = S11_linearOp.matvec(C)
        V_2_m = S12_T_linearOp.matvec(C)
        
        V_m = np.zeros((N, N), dtype = 'c16')
        
        data_coords = np.unravel_index(data_index.flatten(), (N, N))
        no_data_coords = np.unravel_index(no_data_index.flatten(), (N, N))
        
        V_m[data_coords] = V_1_m
        V_m[no_data_coords] = V_2_m
    
        return V_m

    V_m_2 = recovering_sol(C_)
    return V_m_2

# %%
disk_name = 'AS209 1mm'
filename = 'uvtable_AS209_continuum.npz'
disk_geometry = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3 }
Rout = 1.2*2
N = 200
maxiter=20000

# %%
print("Running: " + disk_name +" ...." + " frank2d model with " + str(N)+ 'x'+str(N)+ " points" )

inc = disk_geometry['inc']
pa = disk_geometry['pa']
dra = disk_geometry['dra']
ddec = disk_geometry['ddec']

# UVtable
dir = "../../data/"
data_file = dir + filename

 # load data
data = np.load(data_file)
u, v, Re, Imag, Weights = data['u'], data['v'], data['Re'], data['Im'], data['w']
Vis = Re + Imag*1j
# Out:
# Running: AS209 1mm .... frank2d model with 200x200 points

# %%
geom = Geometry(inc, pa, dra, ddec)
frank2d = Frank2D(N, Rout, geom)

# %%
frank2d.process_vis(u, v, Vis, Weights, hermitian= True)
u_gridded, v_gridded, vis_gridded, weights_gridded = frank2d._gridded_data['u'], frank2d._gridded_data['v'], frank2d._gridded_data['vis'], frank2d._gridded_data['weights']
# Out:
# Shifted grid..
# Setting gridded data...

# %%
plt.figure(figsize = (3, 3))
plt.imshow(np.log(np.abs(vis_gridded.reshape(N, N))), origin='lower', vmin=-15, vmax=-2)
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(r'log |$Vis_{Input}$|')
cmap = plt.colorbar()
cmap.set_label(r'V [Jy]', size=15)

# %%
start_time = time.time()

sol = Frank2D_optimized(N, u_gridded, v_gridded, vis_gridded, weights_gridded, maxiter = maxiter)

end_time = time.time()
execution_time = end_time - start_time
print(f'  ------------------------------------------> TOTAL ALGORITHM TIME = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
# Out:
# ------> Creating linear operators
#   --> time = 1.98  min |  118.52 seconds
# ---------------------------------
# ------> Creating sparse system
#   --> time = 1.14  min |  68.43 seconds
# ---------------------------------
# ------> Running CGM
# .... iteration:  0
#                         -> actual tol:  288175023.92761976 vs  0.0
# .... iteration:  1
#                         -> actual tol:  71092030.1726429 vs  0.0
# .... iteration:  2
#                         -> actual tol:  72259169.3049233 vs  0.0
# .... iteration:  3
#                         -> actual tol:  99307249.59622546 vs  0.0
# .... iteration:  4
#                         -> actual tol:  95540543.67351586 vs  0.0
# .... iteration:  5
#                         -> actual tol:  65929219.548426695 vs  0.0
# .... iteration:  6
#                         -> actual tol:  37120730.97139572 vs  0.0
# .... iteration:  7
#                         -> actual tol:  43247820.47712783 vs  0.0
# .... iteration:  8
#                         -> actual tol:  53743964.46877377 vs  0.0
# .... iteration:  9
#                         -> actual tol:  84256931.5679015 vs  0.0
# .... iteration:  10
#                         -> actual tol:  43084474.93664507 vs  0.0
# .... iteration:  11
#                         -> actual tol:  53981872.64309671 vs  0.0
# .... iteration:  12
#                         -> actual tol:  50642063.60515505 vs  0.0
# .... iteration:  13
#                         -> actual tol:  47495840.027962916 vs  0.0
# .... iteration:  14
#                         -> actual tol:  68297418.52922107 vs  0.0
# .... iteration:  15
#                         -> actual tol:  102647673.68036406 vs  0.0
# .... iteration:  16
#                         -> actual tol:  77787581.83443989 vs  0.0
# .... iteration:  17
#                         -> actual tol:  94821617.6555313 vs  0.0
# .... iteration:  18
#                         -> actual tol:  87829631.6621327 vs  0.0
# .... iteration:  19
#                         -> actual tol:  59573255.033593625 vs  0.0
# .... iteration:  20
#                         -> actual tol:  74496394.95348613 vs  0.0
# .... iteration:  21
#                         -> actual tol:  93779345.11001405 vs  0.0
# .... iteration:  22
#                         -> actual tol:  99633108.97350353 vs  0.0
# .... iteration:  23
#                         -> actual tol:  102523253.17130968 vs  0.0
# .... iteration:  24
#                         -> actual tol:  121976106.80219738 vs  0.0
# .... iteration:  25
#                         -> actual tol:  171739514.28280535 vs  0.0
# .... iteration:  26
#                         -> actual tol:  110082204.4598023 vs  0.0
# .... iteration:  27
#                         -> actual tol:  89532494.68489887 vs  0.0
# .... iteration:  28
#                         -> actual tol:  150208213.53137624 vs  0.0
# .... iteration:  29
#                         -> actual tol:  129309539.20847376 vs  0.0
# .... iteration:  30
#                         -> actual tol:  85508746.11047848 vs  0.0
# .... iteration:  31
#                         -> actual tol:  173987699.17840016 vs  0.0
# .... iteration:  32
#                         -> actual tol:  173347339.27822623 vs  0.0
# .... iteration:  33
#                         -> actual tol:  103055715.3347678 vs  0.0
# .... iteration:  34
#                         -> actual tol:  103266666.06894827 vs  0.0
# .... iteration:  35
#                         -> actual tol:  98713779.15068215 vs  0.0
# .... iteration:  36
#                         -> actual tol:  75424240.38579993 vs  0.0
# .... iteration:  37
#                         -> actual tol:  92491542.502241 vs  0.0
# .... iteration:  38
#                         -> actual tol:  97600280.42090991 vs  0.0
# .... iteration:  39
#                         -> actual tol:  116062538.08748384 vs  0.0
# .... iteration:  40
#                         -> actual tol:  129751526.18205483 vs  0.0
# .... iteration:  41
#                         -> actual tol:  95774447.2455336 vs  0.0
# .... iteration:  42
#                         -> actual tol:  66395153.022995025 vs  0.0
# .... iteration:  43
#                         -> actual tol:  92376169.7307892 vs  0.0
# .... iteration:  44
#                         -> actual tol:  99234403.63833398 vs  0.0
# .... iteration:  45
#                         -> actual tol:  90494852.32970832 vs  0.0
# .... iteration:  46
#                         -> actual tol:  86485627.0810014 vs  0.0
# .... iteration:  47
#                         -> actual tol:  68307533.77751364 vs  0.0
# .... iteration:  48
#                         -> actual tol:  55328205.80657143 vs  0.0
# .... iteration:  49
#                         -> actual tol:  59696374.04200464 vs  0.0
# .... iteration:  50
#                         -> actual tol:  77042386.98882496 vs  0.0
# .... iteration:  51
#                         -> actual tol:  75515139.46247625 vs  0.0
# .... iteration:  52
#                         -> actual tol:  64875933.910340205 vs  0.0
# .... iteration:  53
#                         -> actual tol:  69066528.62023959 vs  0.0
# .... iteration:  54
#                         -> actual tol:  65745535.528549045 vs  0.0
# .... iteration:  55
#                         -> actual tol:  68340600.60832445 vs  0.0
# .... iteration:  56
#                         -> actual tol:  65913013.29160409 vs  0.0
# .... iteration:  57
#                         -> actual tol:  56166161.02333931 vs  0.0
# .... iteration:  58
#                         -> actual tol:  49678609.49297864 vs  0.0
# .... iteration:  59
#                         -> actual tol:  51926867.85073642 vs  0.0
# .... iteration:  60
#                         -> actual tol:  67976835.48038357 vs  0.0
# .... iteration:  61
#                         -> actual tol:  60115957.06763787 vs  0.0
# .... iteration:  62
#                         -> actual tol:  64590595.83908396 vs  0.0
# .... iteration:  63
#                         -> actual tol:  64587076.6530545 vs  0.0
# .... iteration:  64
#                         -> actual tol:  59197118.05871038 vs  0.0
# .... iteration:  65
#                         -> actual tol:  66492136.81939624 vs  0.0
# .... iteration:  66
#                         -> actual tol:  60334567.97078762 vs  0.0
# .... iteration:  67
#                         -> actual tol:  74190950.87455271 vs  0.0
# .... iteration:  68
#                         -> actual tol:  76159073.75964142 vs  0.0
# .... iteration:  69
#                         -> actual tol:  72482402.60380824 vs  0.0
# .... iteration:  70
#                         -> actual tol:  86203662.41203305 vs  0.0
# .... iteration:  71
#                         -> actual tol:  79334952.09048554 vs  0.0
# .... iteration:  72
#                         -> actual tol:  66018897.867899835 vs  0.0
# .... iteration:  73
#                         -> actual tol:  70094305.09441477 vs  0.0
# .... iteration:  74
#                         -> actual tol:  69552352.88323665 vs  0.0
# .... iteration:  75
#                         -> actual tol:  70670427.84824489 vs  0.0
# .... iteration:  76
#                         -> actual tol:  72532664.54425043 vs  0.0
# .... iteration:  77
#                         -> actual tol:  63847502.847788095 vs  0.0
# .... iteration:  78
#                         -> actual tol:  69289979.97984296 vs  0.0
# .... iteration:  79
#                         -> actual tol:  72205756.80151248 vs  0.0
# .... iteration:  80
#                         -> actual tol:  56827619.707112215 vs  0.0
# .... iteration:  81
#                         -> actual tol:  59356355.14020987 vs  0.0
# .... iteration:  82
#                         -> actual tol:  82851608.3161382 vs  0.0
# .... iteration:  83
#                         -> actual tol:  87416121.36157209 vs  0.0
# .... iteration:  84
#                         -> actual tol:  69264030.74499825 vs  0.0
# .... iteration:  85
#                         -> actual tol:  80285868.2458562 vs  0.0
# .... iteration:  86
#                         -> actual tol:  105167733.65621892 vs  0.0
# .... iteration:  87
#                         -> actual tol:  107308312.62795684 vs  0.0
# .... iteration:  88
#                         -> actual tol:  88187130.45272668 vs  0.0
# .... iteration:  89
#                         -> actual tol:  87156824.07160541 vs  0.0
# .... iteration:  90
#                         -> actual tol:  107541270.52071625 vs  0.0
# .... iteration:  91
#                         -> actual tol:  113411228.85350026 vs  0.0
# .... iteration:  92
#                         -> actual tol:  96428013.6476666 vs  0.0
# .... iteration:  93
#                         -> actual tol:  98646122.1320127 vs  0.0
# .... iteration:  94
#                         -> actual tol:  136086244.60110512 vs  0.0
# .... iteration:  95
#                         -> actual tol:  152513664.6010503 vs  0.0
# .... iteration:  96
#                         -> actual tol:  123324122.35325335 vs  0.0
# .... iteration:  97
#                         -> actual tol:  81051329.96284483 vs  0.0
# .... iteration:  98
#                         -> actual tol:  75049636.85971186 vs  0.0
# .... iteration:  99
#                         -> actual tol:  95095935.60205746 vs  0.0
# .... iteration:  100
#                         -> actual tol:  103061723.20924506 vs  0.0
# .... iteration:  101
#                         -> actual tol:  88694945.71170224 vs  0.0
# .... iteration:  102
#                         -> actual tol:  68867739.83796509 vs  0.0
# .... iteration:  103
#                         -> actual tol:  70240136.44222225 vs  0.0
# .... iteration:  104
#                         -> actual tol:  81244279.80963123 vs  0.0
# .... iteration:  105
#                         -> actual tol:  83902230.24969241 vs  0.0
# .... iteration:  106
#                         -> actual tol:  77085499.4189886 vs  0.0
# .... iteration:  107
#                         -> actual tol:  75166333.87044035 vs  0.0
# .... iteration:  108
#                         -> actual tol:  86707654.51413012 vs  0.0
# .... iteration:  109
#                         -> actual tol:  102454209.37502559 vs  0.0
# .... iteration:  110
#                         -> actual tol:  112873843.47589 vs  0.0
# .... iteration:  111
#                         -> actual tol:  109640965.93148634 vs  0.0
# .... iteration:  112
#                         -> actual tol:  89488607.11717533 vs  0.0
# .... iteration:  113
#                         -> actual tol:  64426234.98180366 vs  0.0
# .... iteration:  114
#                         -> actual tol:  57118226.65858386 vs  0.0
# .... iteration:  115
#                         -> actual tol:  73197091.81279999 vs  0.0
# .... iteration:  116
#                         -> actual tol:  93739855.0564774 vs  0.0
# .... iteration:  117
#                         -> actual tol:  101933981.81621538 vs  0.0
# .... iteration:  118
#                         -> actual tol:  91764577.02554485 vs  0.0
# .... iteration:  119
#                         -> actual tol:  72388326.27002057 vs  0.0
# .... iteration:  120
#                         -> actual tol:  62179816.78786852 vs  0.0
# .... iteration:  121
#                         -> actual tol:  70960516.09718405 vs  0.0
# .... iteration:  122
#                         -> actual tol:  84757654.35300249 vs  0.0
# .... iteration:  123
#                         -> actual tol:  86541224.67264019 vs  0.0
# .... iteration:  124
#                         -> actual tol:  71755208.70096147 vs  0.0
# .... iteration:  125
#                         -> actual tol:  61050624.21925965 vs  0.0
# .... iteration:  126
#                         -> actual tol:  78169219.00298817 vs  0.0
# .... iteration:  127
#                         -> actual tol:  96906956.85333516 vs  0.0
# .... iteration:  128
#                         -> actual tol:  93337921.72051828 vs  0.0
# .... iteration:  129
#                         -> actual tol:  73027800.46466187 vs  0.0
# .... iteration:  130
#                         -> actual tol:  66472444.800096676 vs  0.0
# .... iteration:  131
#                         -> actual tol:  85042955.5083796 vs  0.0
# .... iteration:  132
#                         -> actual tol:  102559249.7980898 vs  0.0
# .... iteration:  133
#                         -> actual tol:  101375765.31999809 vs  0.0
# .... iteration:  134
#                         -> actual tol:  82187957.15001713 vs  0.0
# .... iteration:  135
#                         -> actual tol:  68767148.62371874 vs  0.0
# .... iteration:  136
#                         -> actual tol:  86751504.77207087 vs  0.0
# .... iteration:  137
#                         -> actual tol:  117082990.48673935 vs  0.0
# .... iteration:  138
#                         -> actual tol:  134383464.8497209 vs  0.0
# .... iteration:  139
#                         -> actual tol:  129029941.41752699 vs  0.0
# .... iteration:  140
#                         -> actual tol:  109711569.76460971 vs  0.0
# .... iteration:  141
#                         -> actual tol:  96562548.1159469 vs  0.0
# .... iteration:  142
#                         -> actual tol:  100668887.19107507 vs  0.0
# .... iteration:  143
#                         -> actual tol:  110082124.19055527 vs  0.0
# .... iteration:  144
#                         -> actual tol:  109879125.96386422 vs  0.0
# .... iteration:  145
#                         -> actual tol:  97829807.67968272 vs  0.0
# .... iteration:  146
#                         -> actual tol:  82734254.6955438 vs  0.0
# .... iteration:  147
#                         -> actual tol:  76679250.99948907 vs  0.0
# .... iteration:  148
#                         -> actual tol:  84437817.37818578 vs  0.0
# .... iteration:  149
#                         -> actual tol:  97852919.47117656 vs  0.0
# .... iteration:  150
#                         -> actual tol:  104290535.93679741 vs  0.0
# .... iteration:  151
#                         -> actual tol:  96174604.40761992 vs  0.0
# .... iteration:  152
#                         -> actual tol:  78317410.75320837 vs  0.0
# .... iteration:  153
#                         -> actual tol:  66354399.04433007 vs  0.0
# .... iteration:  154
#                         -> actual tol:  68922489.17936583 vs  0.0
# .... iteration:  155
#                         -> actual tol:  76202515.23204175 vs  0.0
# .... iteration:  156
#                         -> actual tol:  78546599.2375551 vs  0.0
# .... iteration:  157
#                         -> actual tol:  76352675.63052358 vs  0.0
# .... iteration:  158
#                         -> actual tol:  78237186.65898359 vs  0.0
# .... iteration:  159
#                         -> actual tol:  91488999.18939601 vs  0.0
# .... iteration:  160
#                         -> actual tol:  111539182.53518999 vs  0.0
# .... iteration:  161
#                         -> actual tol:  126968349.50538814 vs  0.0
# .... iteration:  162
#                         -> actual tol:  128275347.09953463 vs  0.0
# .... iteration:  163
#                         -> actual tol:  113414850.41170762 vs  0.0
# .... iteration:  164
#                         -> actual tol:  90518830.7253292 vs  0.0
# .... iteration:  165
#                         -> actual tol:  76722981.25871728 vs  0.0
# .... iteration:  166
#                         -> actual tol:  84356713.16543892 vs  0.0
# .... iteration:  167
#                         -> actual tol:  101732129.86873049 vs  0.0
# .... iteration:  168
#                         -> actual tol:  112543720.24127495 vs  0.0
# .... iteration:  169
#                         -> actual tol:  109817658.12584268 vs  0.0
# .... iteration:  170
#                         -> actual tol:  95237972.13981661 vs  0.0
# .... iteration:  171
#                         -> actual tol:  77900011.8504774 vs  0.0
# .... iteration:  172
#                         -> actual tol:  71926349.66557653 vs  0.0
# .... iteration:  173
#                         -> actual tol:  81948535.8154322 vs  0.0
# .... iteration:  174
#                         -> actual tol:  94938443.08191493 vs  0.0
# .... iteration:  175
#                         -> actual tol:  98956337.17277361 vs  0.0
# .... iteration:  176
#                         -> actual tol:  91697276.22531173 vs  0.0
# .... iteration:  177
#                         -> actual tol:  80199418.15218556 vs  0.0
# .... iteration:  178
#                         -> actual tol:  77388888.9059988 vs  0.0
# .... iteration:  179
#                         -> actual tol:  88618099.63077323 vs  0.0
# .... iteration:  180
#                         -> actual tol:  103712997.1467094 vs  0.0
# .... iteration:  181
#                         -> actual tol:  110876804.17379922 vs  0.0
# .... iteration:  182
#                         -> actual tol:  105019553.23329557 vs  0.0
# .... iteration:  183
#                         -> actual tol:  88958121.32155733 vs  0.0
# .... iteration:  184
#                         -> actual tol:  72789989.23005825 vs  0.0
# .... iteration:  185
#                         -> actual tol:  69053243.92917143 vs  0.0
# .... iteration:  186
#                         -> actual tol:  78845587.37314026 vs  0.0
# .... iteration:  187
#                         -> actual tol:  91619297.95211528 vs  0.0
# .... iteration:  188
#                         -> actual tol:  98659260.99001753 vs  0.0
# .... iteration:  189
#                         -> actual tol:  95585597.81997193 vs  0.0
# .... iteration:  190
#                         -> actual tol:  83644710.89211789 vs  0.0
# .... iteration:  191
#                         -> actual tol:  73039798.91092859 vs  0.0
# .... iteration:  192
#                         -> actual tol:  76976014.68470554 vs  0.0
# .... iteration:  193
#                         -> actual tol:  93595287.30378443 vs  0.0
# .... iteration:  194
#                         -> actual tol:  112015034.90846282 vs  0.0
# .... iteration:  195
#                         -> actual tol:  124757891.62687686 vs  0.0
# .... iteration:  196
#                         -> actual tol:  127126629.89446746 vs  0.0
# .... iteration:  197
#                         -> actual tol:  117005420.44412418 vs  0.0
# .... iteration:  198
#                         -> actual tol:  96961665.08846836 vs  0.0
# .... iteration:  199
#                         -> actual tol:  74973080.29951815 vs  0.0
# .... iteration:  200
#                         -> actual tol:  62278542.4727347 vs  0.0
# .... iteration:  201
#                         -> actual tol:  65638303.74831458 vs  0.0
# .... iteration:  202
#                         -> actual tol:  79290583.54054928 vs  0.0
# .... iteration:  203
#                         -> actual tol:  94662971.98646508 vs  0.0
# .... iteration:  204
#                         -> actual tol:  106319635.0542164 vs  0.0
# .... iteration:  205
#                         -> actual tol:  110440459.61598009 vs  0.0
# .... iteration:  206
#                         -> actual tol:  105010494.20960145 vs  0.0
# .... iteration:  207
#                         -> actual tol:  91466254.92237437 vs  0.0
# .... iteration:  208
#                         -> actual tol:  75112761.58852486 vs  0.0
# .... iteration:  209
#                         -> actual tol:  63476156.856219135 vs  0.0
# .... iteration:  210
#                         -> actual tol:  62156150.52591932 vs  0.0
# .... iteration:  211
#                         -> actual tol:  69229048.05838443 vs  0.0
# .... iteration:  212
#                         -> actual tol:  77999173.10401644 vs  0.0
# .... iteration:  213
#                         -> actual tol:  83137524.87931983 vs  0.0
# .... iteration:  214
#                         -> actual tol:  82262956.02030908 vs  0.0
# .... iteration:  215
#                         -> actual tol:  76118747.93627158 vs  0.0
# .... iteration:  216
#                         -> actual tol:  68233701.32079597 vs  0.0
# .... iteration:  217
#                         -> actual tol:  63589843.20705174 vs  0.0
# .... iteration:  218
#                         -> actual tol:  65761004.39386714 vs  0.0
# .... iteration:  219
#                         -> actual tol:  73944458.8530377 vs  0.0
# .... iteration:  220
#                         -> actual tol:  84060978.88874993 vs  0.0
# .... iteration:  221
#                         -> actual tol:  91688805.56760372 vs  0.0
# .... iteration:  222
#                         -> actual tol:  93755614.84525436 vs  0.0
# .... iteration:  223
#                         -> actual tol:  90164130.57446758 vs  0.0
# .... iteration:  224
#                         -> actual tol:  85132394.99618448 vs  0.0
# .... iteration:  225
#                         -> actual tol:  85491493.62467878 vs  0.0
# .... iteration:  226
#                         -> actual tol:  94313724.16479181 vs  0.0
# .... iteration:  227
#                         -> actual tol:  107481255.6147618 vs  0.0
# .... iteration:  228
#                         -> actual tol:  118054815.59613438 vs  0.0
# .... iteration:  229
#                         -> actual tol:  120404659.65631832 vs  0.0
# .... iteration:  230
#                         -> actual tol:  112251219.21222708 vs  0.0
# .... iteration:  231
#                         -> actual tol:  96030213.72826669 vs  0.0
# .... iteration:  232
#                         -> actual tol:  79016286.97949871 vs  0.0
# .... iteration:  233
#                         -> actual tol:  71268790.78926574 vs  0.0
# .... iteration:  234
#                         -> actual tol:  77650926.45239228 vs  0.0
# .... iteration:  235
#                         -> actual tol:  92137848.81485562 vs  0.0
# .... iteration:  236
#                         -> actual tol:  106473646.56333096 vs  0.0
# .... iteration:  237
#                         -> actual tol:  115119496.56742078 vs  0.0
# .... iteration:  238
#                         -> actual tol:  114886620.36009292 vs  0.0
# .... iteration:  239
#                         -> actual tol:  105399005.5901601 vs  0.0
# .... iteration:  240
#                         -> actual tol:  90317244.16672659 vs  0.0
# .... iteration:  241
#                         -> actual tol:  77487888.53758384 vs  0.0
# .... iteration:  242
#                         -> actual tol:  75197997.29883207 vs  0.0
# .... iteration:  243
#                         -> actual tol:  83972106.28118885 vs  0.0
# .... iteration:  244
#                         -> actual tol:  97163752.5296017 vs  0.0
# .... iteration:  245
#                         -> actual tol:  108814360.96443665 vs  0.0
# .... iteration:  246
#                         -> actual tol:  115394625.8592298 vs  0.0
# .... iteration:  247
#                         -> actual tol:  114972467.71662548 vs  0.0
# .... iteration:  248
#                         -> actual tol:  107263307.78501087 vs  0.0
# .... iteration:  249
#                         -> actual tol:  94337929.53340088 vs  0.0
# .... iteration:  250
#                         -> actual tol:  80857381.54132688 vs  0.0
# .... iteration:  251
#                         -> actual tol:  72577447.22028388 vs  0.0
# .... iteration:  252
#                         -> actual tol:  72431034.5684835 vs  0.0
# .... iteration:  253
#                         -> actual tol:  78080183.9139151 vs  0.0
# .... iteration:  254
#                         -> actual tol:  85207401.57878736 vs  0.0
# .... iteration:  255
#                         -> actual tol:  90693650.60071234 vs  0.0
# .... iteration:  256
#                         -> actual tol:  92800275.61813562 vs  0.0
# .... iteration:  257
#                         -> actual tol:  90814898.6623029 vs  0.0
# .... iteration:  258
#                         -> actual tol:  85251236.99916896 vs  0.0
# .... iteration:  259
#                         -> actual tol:  78266971.50362435 vs  0.0
# .... iteration:  260
#                         -> actual tol:  73343633.09855978 vs  0.0
# .... iteration:  261
#                         -> actual tol:  73343001.59427635 vs  0.0
# .... iteration:  262
#                         -> actual tol:  78219062.14678584 vs  0.0
# .... iteration:  263
#                         -> actual tol:  85503957.42008507 vs  0.0
# .... iteration:  264
#                         -> actual tol:  92493424.21649334 vs  0.0
# .... iteration:  265
#                         -> actual tol:  97239623.1458566 vs  0.0
# .... iteration:  266
#                         -> actual tol:  98556232.06030023 vs  0.0
# .... iteration:  267
#                         -> actual tol:  95996458.50998679 vs  0.0
# .... iteration:  268
#                         -> actual tol:  90053569.25681977 vs  0.0
# .... iteration:  269
#                         -> actual tol:  82409382.19676308 vs  0.0
# .... iteration:  270
#                         -> actual tol:  75865187.75741437 vs  0.0
# .... iteration:  271
#                         -> actual tol:  73424064.04472575 vs  0.0
# .... iteration:  272
#                         -> actual tol:  76454245.36470024 vs  0.0
# .... iteration:  273
#                         -> actual tol:  83755481.53611319 vs  0.0
# .... iteration:  274
#                         -> actual tol:  92805250.16661349 vs  0.0
# .... iteration:  275
#                         -> actual tol:  101187703.84211779 vs  0.0
# .... iteration:  276
#                         -> actual tol:  107003928.49221674 vs  0.0
# .... iteration:  277
#                         -> actual tol:  108919306.86169478 vs  0.0
# .... iteration:  278
#                         -> actual tol:  106393454.90233226 vs  0.0
# .... iteration:  279
#                         -> actual tol:  100088095.79187568 vs  0.0
# .... iteration:  280
#                         -> actual tol:  92125649.77238531 vs  0.0
# .... iteration:  281
#                         -> actual tol:  85756893.35384518 vs  0.0
# .... iteration:  282
#                         -> actual tol:  84035662.18630509 vs  0.0
# .... iteration:  283
#                         -> actual tol:  87920739.34284537 vs  0.0
# .... iteration:  284
#                         -> actual tol:  95810752.26260802 vs  0.0
# .... iteration:  285
#                         -> actual tol:  105029397.42944343 vs  0.0
# .... iteration:  286
#                         -> actual tol:  113145476.71160452 vs  0.0
# .... iteration:  287
#                         -> actual tol:  118335994.20762715 vs  0.0
# .... iteration:  288
#                         -> actual tol:  119421411.61811163 vs  0.0
# .... iteration:  289
#                         -> actual tol:  115971624.48778373 vs  0.0
# .... iteration:  290
#                         -> actual tol:  108484900.83695048 vs  0.0
# .... iteration:  291
#                         -> actual tol:  98519727.7026846 vs  0.0
# .... iteration:  292
#                         -> actual tol:  88676825.4281537 vs  0.0
# .... iteration:  293
#                         -> actual tol:  82224165.8644829 vs  0.0
# .... iteration:  294
#                         -> actual tol:  81868002.44479954 vs  0.0
# .... iteration:  295
#                         -> actual tol:  87991824.37614505 vs  0.0
# .... iteration:  296
#                         -> actual tol:  98524276.93064348 vs  0.0
# .... iteration:  297
#                         -> actual tol:  110554766.05776304 vs  0.0
# .... iteration:  298
#                         -> actual tol:  121424186.02442938 vs  0.0
# .... iteration:  299
#                         -> actual tol:  128915707.79573809 vs  0.0
# .... iteration:  300
#                         -> actual tol:  131305446.49827448 vs  0.0
# .... iteration:  301
#                         -> actual tol:  127608027.92274459 vs  0.0
# .... iteration:  302
#                         -> actual tol:  117937621.70178731 vs  0.0
# .... iteration:  303
#                         -> actual tol:  103786351.82419068 vs  0.0
# .... iteration:  304
#                         -> actual tol:  88168495.93446575 vs  0.0
# .... iteration:  305
#                         -> actual tol:  75699709.15043749 vs  0.0
# .... iteration:  306
#                         -> actual tol:  71698351.44159114 vs  0.0
# .... iteration:  307
#                         -> actual tol:  78305727.25639606 vs  0.0
# .... iteration:  308
#                         -> actual tol:  92221960.09324324 vs  0.0
# .... iteration:  309
#                         -> actual tol:  108583283.54031686 vs  0.0
# .... iteration:  310
#                         -> actual tol:  123670292.71605729 vs  0.0
# .... iteration:  311
#                         -> actual tol:  134856724.31953824 vs  0.0
# .... iteration:  312
#                         -> actual tol:  140312299.23803425 vs  0.0
# .... iteration:  313
#                         -> actual tol:  139082687.82639915 vs  0.0
# .... iteration:  314
#                         -> actual tol:  131325471.84598908 vs  0.0
# .... iteration:  315
#                         -> actual tol:  118446103.79517928 vs  0.0
# .... iteration:  316
#                         -> actual tol:  103072430.61574654 vs  0.0
# .... iteration:  317
#                         -> actual tol:  88969792.77925855 vs  0.0
# .... iteration:  318
#                         -> actual tol:  80630701.67517522 vs  0.0
# .... iteration:  319
#                         -> actual tol:  81299753.23645054 vs  0.0
# .... iteration:  320
#                         -> actual tol:  90206777.01512206 vs  0.0
# .... iteration:  321
#                         -> actual tol:  103539759.1926737 vs  0.0
# .... iteration:  322
#                         -> actual tol:  117485288.9493048 vs  0.0
# .... iteration:  323
#                         -> actual tol:  129256004.43879345 vs  0.0
# .... iteration:  324
#                         -> actual tol:  136913595.99299994 vs  0.0
# .... iteration:  325
#                         -> actual tol:  139212474.0056693 vs  0.0
# .... iteration:  326
#                         -> actual tol:  135650017.9204724 vs  0.0
# .... iteration:  327
#                         -> actual tol:  126591465.59699138 vs  0.0
# .... iteration:  328
#                         -> actual tol:  113344485.09761247 vs  0.0
# .... iteration:  329
#                         -> actual tol:  98164240.75961128 vs  0.0
# .... iteration:  330
#                         -> actual tol:  84242038.41375013 vs  0.0
# .... iteration:  331
#                         -> actual tol:  75438273.76757368 vs  0.0
# .... iteration:  332
#                         -> actual tol:  74728330.90649079 vs  0.0
# .... iteration:  333
#                         -> actual tol:  81734527.61289878 vs  0.0
# .... iteration:  334
#                         -> actual tol:  93232366.66641134 vs  0.0
# .... iteration:  335
#                         -> actual tol:  105874558.19007005 vs  0.0
# .... iteration:  336
#                         -> actual tol:  117285479.8609065 vs  0.0
# .... iteration:  337
#                         -> actual tol:  125884819.81951216 vs  0.0
# .... iteration:  338
#                         -> actual tol:  130619119.961211 vs  0.0
# .... iteration:  339
#                         -> actual tol:  130870215.7431967 vs  0.0
# .... iteration:  340
#                         -> actual tol:  126489270.48595834 vs  0.0
# .... iteration:  341
#                         -> actual tol:  117880608.41677126 vs  0.0
# .... iteration:  342
#                         -> actual tol:  106095930.25377734 vs  0.0
# .... iteration:  343
#                         -> actual tol:  92952496.57682933 vs  0.0
# .... iteration:  344
#                         -> actual tol:  81189135.94400322 vs  0.0
# .... iteration:  345
#                         -> actual tol:  74346640.77064784 vs  0.0
# .... iteration:  346
#                         -> actual tol:  75325578.21502328 vs  0.0
# .... iteration:  347
#                         -> actual tol:  84007731.1720371 vs  0.0
# .... iteration:  348
#                         -> actual tol:  97596051.72027694 vs  0.0
# .... iteration:  349
#                         -> actual tol:  113042095.4107457 vs  0.0
# .... iteration:  350
#                         -> actual tol:  128083827.44328949 vs  0.0
# .... iteration:  351
#                         -> actual tol:  141116558.64063647 vs  0.0
# .... iteration:  352
#                         -> actual tol:  150933586.85398382 vs  0.0
# .... iteration:  353
#                         -> actual tol:  156611860.7903658 vs  0.0
# .... iteration:  354
#                         -> actual tol:  157526709.7511705 vs  0.0
# .... iteration:  355
#                         -> actual tol:  153438055.38380092 vs  0.0
# .... iteration:  356
#                         -> actual tol:  144591998.93081865 vs  0.0
# .... iteration:  357
#                         -> actual tol:  131797695.28010239 vs  0.0
# .... iteration:  358
#                         -> actual tol:  116473992.58784956 vs  0.0
# .... iteration:  359
#                         -> actual tol:  100697153.26015308 vs  0.0
# .... iteration:  360
#                         -> actual tol:  87238038.15472712 vs  0.0
# .... iteration:  361
#                         -> actual tol:  79243959.7281352 vs  0.0
# .... iteration:  362
#                         -> actual tol:  78801127.42351785 vs  0.0
# .... iteration:  363
#                         -> actual tol:  85169465.30736321 vs  0.0
# .... iteration:  364
#                         -> actual tol:  95475168.59810816 vs  0.0
# .... iteration:  365
#                         -> actual tol:  106837616.35090666 vs  0.0
# .... iteration:  366
#                         -> actual tol:  117253824.7035318 vs  0.0
# .... iteration:  367
#                         -> actual tol:  125493571.61239813 vs  0.0
# .... iteration:  368
#                         -> actual tol:  130848316.7145712 vs  0.0
# .... iteration:  369
#                         -> actual tol:  132969942.18414795 vs  0.0
# .... iteration:  370
#                         -> actual tol:  131791147.55931409 vs  0.0
# .... iteration:  371
#                         -> actual tol:  127493424.6740292 vs  0.0
# .... iteration:  372
#                         -> actual tol:  120503568.76887716 vs  0.0
# .... iteration:  373
#                         -> actual tol:  111514791.71436608 vs  0.0
# .... iteration:  374
#                         -> actual tol:  101536098.95562439 vs  0.0
# .... iteration:  375
#                         -> actual tol:  91959181.6067602 vs  0.0
# .... iteration:  376
#                         -> actual tol:  84554218.68006495 vs  0.0
# .... iteration:  377
#                         -> actual tol:  81144178.78177086 vs  0.0
# .... iteration:  378
#                         -> actual tol:  82768581.29254115 vs  0.0
# .... iteration:  379
#                         -> actual tol:  88945258.28019921 vs  0.0
# .... iteration:  380
#                         -> actual tol:  97971360.04500447 vs  0.0
# .... iteration:  381
#                         -> actual tol:  107837513.20755452 vs  0.0
# .... iteration:  382
#                         -> actual tol:  116810742.12642922 vs  0.0
# .... iteration:  383
#                         -> actual tol:  123594823.78364792 vs  0.0
# .... iteration:  384
#                         -> actual tol:  127335550.95237352 vs  0.0
# .... iteration:  385
#                         -> actual tol:  127606216.96316925 vs  0.0
# .... iteration:  386
#                         -> actual tol:  124393476.31119117 vs  0.0
# .... iteration:  387
#                         -> actual tol:  118075005.31756169 vs  0.0
# .... iteration:  388
#                         -> actual tol:  109387702.67874947 vs  0.0
# .... iteration:  389
#                         -> actual tol:  99396857.71427387 vs  0.0
# .... iteration:  390
#                         -> actual tol:  89472365.77460699 vs  0.0
# .... iteration:  391
#                         -> actual tol:  81230080.78429793 vs  0.0
# .... iteration:  392
#                         -> actual tol:  76289556.86021063 vs  0.0
# .... iteration:  393
#                         -> actual tol:  75698017.37620428 vs  0.0
# .... iteration:  394
#                         -> actual tol:  79340867.01771683 vs  0.0
# .... iteration:  395
#                         -> actual tol:  86049167.24405526 vs  0.0
# .... iteration:  396
#                         -> actual tol:  94299124.96678746 vs  0.0
# .... iteration:  397
#                         -> actual tol:  102745880.60751216 vs  0.0
# .... iteration:  398
#                         -> actual tol:  110370060.96060331 vs  0.0
# .... iteration:  399
#                         -> actual tol:  116442394.88776276 vs  0.0
# .... iteration:  400
#                         -> actual tol:  120465617.5182559 vs  0.0
# .... iteration:  401
#                         -> actual tol:  122142054.26195918 vs  0.0
# .... iteration:  402
#                         -> actual tol:  121369482.04654418 vs  0.0
# .... iteration:  403
#                         -> actual tol:  118258498.18434466 vs  0.0
# .... iteration:  404
#                         -> actual tol:  113165917.59816584 vs  0.0
# .... iteration:  405
#                         -> actual tol:  106740159.5405704 vs  0.0
# .... iteration:  406
#                         -> actual tol:  99967144.1356887 vs  0.0
# .... iteration:  407
#                         -> actual tol:  94172128.06599885 vs  0.0
# .... iteration:  408
#                         -> actual tol:  90864396.18921977 vs  0.0
# .... iteration:  409
#                         -> actual tol:  91297625.96440063 vs  0.0
# .... iteration:  410
#                         -> actual tol:  95888983.11968902 vs  0.0
# .... iteration:  411
#                         -> actual tol:  104013113.83565521 vs  0.0
# .... iteration:  412
#                         -> actual tol:  114377453.39469962 vs  0.0
# .... iteration:  413
#                         -> actual tol:  125542690.92682177 vs  0.0
# .... iteration:  414
#                         -> actual tol:  136218983.33243048 vs  0.0
# .... iteration:  415
#                         -> actual tol:  145352293.88390675 vs  0.0
# .... iteration:  416
#                         -> actual tol:  152127027.00402692 vs  0.0
# .... iteration:  417
#                         -> actual tol:  155956801.9384622 vs  0.0
# .... iteration:  418
#                         -> actual tol:  156483770.6888173 vs  0.0
# .... iteration:  419
#                         -> actual tol:  153585597.54840803 vs  0.0
# .... iteration:  420
#                         -> actual tol:  147384449.93257743 vs  0.0
# .... iteration:  421
#                         -> actual tol:  138254795.06305957 vs  0.0
# .... iteration:  422
#                         -> actual tol:  126832932.94885461 vs  0.0
# .... iteration:  423
#                         -> actual tol:  114038749.13245627 vs  0.0
# .... iteration:  424
#                         -> actual tol:  101122634.96108162 vs  0.0
# .... iteration:  425
#                         -> actual tol:  89723175.68049031 vs  0.0
# .... iteration:  426
#                         -> actual tol:  81801690.72728996 vs  0.0
# .... iteration:  427
#                         -> actual tol:  79125285.13654107 vs  0.0
# .... iteration:  428
#                         -> actual tol:  82265248.22425535 vs  0.0
# .... iteration:  429
#                         -> actual tol:  90166919.9874643 vs  0.0
# .... iteration:  430
#                         -> actual tol:  100953461.3350926 vs  0.0
# .... iteration:  431
#                         -> actual tol:  112865968.00424989 vs  0.0
# .... iteration:  432
#                         -> actual tol:  124579651.28284037 vs  0.0
# .... iteration:  433
#                         -> actual tol:  135150369.54115143 vs  0.0
# .... iteration:  434
#                         -> actual tol:  143899086.81846803 vs  0.0
# .... iteration:  435
#                         -> actual tol:  150331278.29080835 vs  0.0
# .... iteration:  436
#                         -> actual tol:  154096934.1388773 vs  0.0
# .... iteration:  437
#                         -> actual tol:  154978964.71912178 vs  0.0
# .... iteration:  438
#                         -> actual tol:  152898882.63248265 vs  0.0
# .... iteration:  439
#                         -> actual tol:  147932273.38164648 vs  0.0
# .... iteration:  440
#                         -> actual tol:  140330234.30735666 vs  0.0
# .... iteration:  441
#                         -> actual tol:  130546933.32521102 vs  0.0
# .... iteration:  442
#                         -> actual tol:  119277537.65754259 vs  0.0
# .... iteration:  443
#                         -> actual tol:  107511600.52108568 vs  0.0
# .... iteration:  444
#                         -> actual tol:  96590474.24121626 vs  0.0
# .... iteration:  445
#                         -> actual tol:  88187287.95539327 vs  0.0
# .... iteration:  446
#                         -> actual tol:  83993597.98786476 vs  0.0
# .... iteration:  447
#                         -> actual tol:  84968365.07874244 vs  0.0
# .... iteration:  448
#                         -> actual tol:  90696381.39289153 vs  0.0
# .... iteration:  449
#                         -> actual tol:  99676055.84220341 vs  0.0
# .... iteration:  450
#                         -> actual tol:  110157745.58428954 vs  0.0
# .... iteration:  451
#                         -> actual tol:  120666354.44584724 vs  0.0
# .... iteration:  452
#                         -> actual tol:  130104081.75233616 vs  0.0
# .... iteration:  453
#                         -> actual tol:  137690403.78059232 vs  0.0
# .... iteration:  454
#                         -> actual tol:  142889055.86919758 vs  0.0
# .... iteration:  455
#                         -> actual tol:  145359306.19243234 vs  0.0
# .... iteration:  456
#                         -> actual tol:  144930575.85121217 vs  0.0
# .... iteration:  457
#                         -> actual tol:  141593437.87368947 vs  0.0
# .... iteration:  458
#                         -> actual tol:  135502153.8779697 vs  0.0
# .... iteration:  459
#                         -> actual tol:  126987527.84469989 vs  0.0
# .... iteration:  460
#                         -> actual tol:  116582984.46110864 vs  0.0
# .... iteration:  461
#                         -> actual tol:  105070753.98580623 vs  0.0
# .... iteration:  462
#                         -> actual tol:  93553172.26654439 vs  0.0
# .... iteration:  463
#                         -> actual tol:  83521563.51078567 vs  0.0
# .... iteration:  464
#                         -> actual tol:  76774361.28525415 vs  0.0
# .... iteration:  465
#                         -> actual tol:  74874866.26089834 vs  0.0
# .... iteration:  466
#                         -> actual tol:  78203007.35394599 vs  0.0
# .... iteration:  467
#                         -> actual tol:  85639811.41559425 vs  0.0
# .... iteration:  468
#                         -> actual tol:  95362097.20448391 vs  0.0
# .... iteration:  469
#                         -> actual tol:  105690267.10214229 vs  0.0
# .... iteration:  470
#                         -> actual tol:  115371280.78392385 vs  0.0
# .... iteration:  471
#                         -> actual tol:  123542578.63227509 vs  0.0
# .... iteration:  472
#                         -> actual tol:  129638335.03461006 vs  0.0
# .... iteration:  473
#                         -> actual tol:  133318292.67632268 vs  0.0
# .... iteration:  474
#                         -> actual tol:  134424199.62221238 vs  0.0
# .... iteration:  475
#                         -> actual tol:  132955239.27031785 vs  0.0
# .... iteration:  476
#                         -> actual tol:  129055915.96666348 vs  0.0
# .... iteration:  477
#                         -> actual tol:  123013766.24770314 vs  0.0
# .... iteration:  478
#                         -> actual tol:  115267486.57168661 vs  0.0
# .... iteration:  479
#                         -> actual tol:  106427945.9398773 vs  0.0
# .... iteration:  480
#                         -> actual tol:  97312339.18485308 vs  0.0
# .... iteration:  481
#                         -> actual tol:  88976085.3951846 vs  0.0
# .... iteration:  482
#                         -> actual tol:  82680338.39865206 vs  0.0
# .... iteration:  483
#                         -> actual tol:  79666980.16812593 vs  0.0
# .... iteration:  484
#                         -> actual tol:  80684694.47565997 vs  0.0
# .... iteration:  485
#                         -> actual tol:  85580996.58823878 vs  0.0
# .... iteration:  486
#                         -> actual tol:  93415390.03092238 vs  0.0
# .... iteration:  487
#                         -> actual tol:  102952835.91172287 vs  0.0
# .... iteration:  488
#                         -> actual tol:  113049039.46997194 vs  0.0
# .... iteration:  489
#                         -> actual tol:  122780257.82275859 vs  0.0
# .... iteration:  490
#                         -> actual tol:  131434849.42914066 vs  0.0
# .... iteration:  491
#                         -> actual tol:  138472162.8012828 vs  0.0
# .... iteration:  492
#                         -> actual tol:  143488800.4642518 vs  0.0
# .... iteration:  493
#                         -> actual tol:  146199463.05157462 vs  0.0
# .... iteration:  494
#                         -> actual tol:  146430109.73709717 vs  0.0
# .... iteration:  495
#                         -> actual tol:  144120037.21665567 vs  0.0
# .... iteration:  496
#                         -> actual tol:  139330552.0155424 vs  0.0
# .... iteration:  497
#                         -> actual tol:  132259679.24863663 vs  0.0
# .... iteration:  498
#                         -> actual tol:  123264805.72073272 vs  0.0
# .... iteration:  499
#                         -> actual tol:  112898368.96508326 vs  0.0
# .... iteration:  500
#                         -> actual tol:  101963956.96480468 vs  0.0
# .... iteration:  501
#                         -> actual tol:  91591927.31145765 vs  0.0
# .... iteration:  502
#                         -> actual tol:  83283384.45838211 vs  0.0
# .... iteration:  503
#                         -> actual tol:  78738137.4730713 vs  0.0
# .... iteration:  504
#                         -> actual tol:  79225629.58178589 vs  0.0
# .... iteration:  505
#                         -> actual tol:  84807130.71798925 vs  0.0
# .... iteration:  506
#                         -> actual tol:  94339670.88136701 vs  0.0
# .... iteration:  507
#                         -> actual tol:  106246207.63515872 vs  0.0
# .... iteration:  508
#                         -> actual tol:  119125263.56346332 vs  0.0
# .... iteration:  509
#                         -> actual tol:  131910085.25485449 vs  0.0
# .... iteration:  510
#                         -> actual tol:  143817095.10068014 vs  0.0
# .... iteration:  511
#                         -> actual tol:  154264573.86488667 vs  0.0
# .... iteration:  512
#                         -> actual tol:  162813698.5689311 vs  0.0
# .... iteration:  513
#                         -> actual tol:  169134610.41344732 vs  0.0
# .... iteration:  514
#                         -> actual tol:  172990632.59003317 vs  0.0
# .... iteration:  515
#                         -> actual tol:  174234383.8643496 vs  0.0
# .... iteration:  516
#                         -> actual tol:  172811387.90446314 vs  0.0
# .... iteration:  517
#                         -> actual tol:  168768266.55161026 vs  0.0
# .... iteration:  518
#                         -> actual tol:  162263841.86389023 vs  0.0
# .... iteration:  519
#                         -> actual tol:  153582777.48674 vs  0.0
# .... iteration:  520
#                         -> actual tol:  143152919.77986804 vs  0.0
# .... iteration:  521
#                         -> actual tol:  131568897.81093925 vs  0.0
# .... iteration:  522
#                         -> actual tol:  119623879.75833163 vs  0.0
# .... iteration:  523
#                         -> actual tol:  108342315.75093268 vs  0.0
# .... iteration:  524
#                         -> actual tol:  98974741.75833933 vs  0.0
# .... iteration:  525
#                         -> actual tol:  92853826.63421366 vs  0.0
# .... iteration:  526
#                         -> actual tol:  91001453.47610813 vs  0.0
# .... iteration:  527
#                         -> actual tol:  93628040.95385954 vs  0.0
# .... iteration:  528
#                         -> actual tol:  100003927.70051926 vs  0.0
# .... iteration:  529
#                         -> actual tol:  108871495.44552274 vs  0.0
# .... iteration:  530
#                         -> actual tol:  118954159.99266492 vs  0.0
# .... iteration:  531
#                         -> actual tol:  129210541.29052322 vs  0.0
# .... iteration:  532
#                         -> actual tol:  138869736.6987322 vs  0.0
# .... iteration:  533
#                         -> actual tol:  147384162.39252153 vs  0.0
# .... iteration:  534
#                         -> actual tol:  154373675.59542447 vs  0.0
# .... iteration:  535
#                         -> actual tol:  159582106.38103613 vs  0.0
# .... iteration:  536
#                         -> actual tol:  162847538.5899087 vs  0.0
# .... iteration:  537
#                         -> actual tol:  164083313.82881773 vs  0.0
# .... iteration:  538
#                         -> actual tol:  163266911.70547724 vs  0.0
# .... iteration:  539
#                         -> actual tol:  160434833.11025447 vs  0.0
# .... iteration:  540
#                         -> actual tol:  155682479.08538458 vs  0.0
# .... iteration:  541
#                         -> actual tol:  149168703.86259806 vs  0.0
# .... iteration:  542
#                         -> actual tol:  141125328.0150358 vs  0.0
# .... iteration:  543
#                         -> actual tol:  131872475.37482941 vs  0.0
# .... iteration:  544
#                         -> actual tol:  121840898.14237292 vs  0.0
# .... iteration:  545
#                         -> actual tol:  111601288.5909004 vs  0.0
# .... iteration:  546
#                         -> actual tol:  101894294.41250446 vs  0.0
# .... iteration:  547
#                         -> actual tol:  93635866.5002872 vs  0.0
# .... iteration:  548
# ...
# .... iteration:  19824
#                         -> actual tol:  44914423.367491454 vs  0.0
# .... iteration:  19825
#                         -> actual tol:  44998835.19292072 vs  0.0
# .... iteration:  19826
#                         -> actual tol:  45071283.83998116 vs  0.0
# .... iteration:  19827
#                         -> actual tol:  45131622.94641412 vs  0.0
# .... iteration:  19828
#                         -> actual tol:  45179726.3529335 vs  0.0
# .... iteration:  19829
#                         -> actual tol:  45215488.06812836 vs  0.0
# .... iteration:  19830
#                         -> actual tol:  45238822.2394871 vs  0.0
# .... iteration:  19831
#                         -> actual tol:  45249663.13085949 vs  0.0
# .... iteration:  19832
#                         -> actual tol:  45247965.10661995 vs  0.0
# .... iteration:  19833
#                         -> actual tol:  45233702.62275334 vs  0.0
# .... iteration:  19834
#                         -> actual tol:  45206870.225048274 vs  0.0
# .... iteration:  19835
#                         -> actual tol:  45167482.55455186 vs  0.0
# .... iteration:  19836
#                         -> actual tol:  45115574.36041135 vs  0.0
# .... iteration:  19837
#                         -> actual tol:  45051200.52020065 vs  0.0
# .... iteration:  19838
#                         -> actual tol:  44974436.06780024 vs  0.0
# .... iteration:  19839
#                         -> actual tol:  44885376.22886709 vs  0.0
# .... iteration:  19840
#                         -> actual tol:  44784136.463892385 vs  0.0
# .... iteration:  19841
#                         -> actual tol:  44670852.51880006 vs  0.0
# .... iteration:  19842
#                         -> actual tol:  44545680.48298176 vs  0.0
# .... iteration:  19843
#                         -> actual tol:  44408796.8545968 vs  0.0
# .... iteration:  19844
#                         -> actual tol:  44260398.61288052 vs  0.0
# .... iteration:  19845
#                         -> actual tol:  44100703.29710334 vs  0.0
# .... iteration:  19846
#                         -> actual tol:  43929949.09170004 vs  0.0
# .... iteration:  19847
#                         -> actual tol:  43748394.9169409 vs  0.0
# .... iteration:  19848
#                         -> actual tol:  43556320.52434223 vs  0.0
# .... iteration:  19849
#                         -> actual tol:  43354026.59580736 vs  0.0
# .... iteration:  19850
#                         -> actual tol:  43141834.84524734 vs  0.0
# .... iteration:  19851
#                         -> actual tol:  42920088.12115035 vs  0.0
# .... iteration:  19852
#                         -> actual tol:  42689150.508243464 vs  0.0
# .... iteration:  19853
#                         -> actual tol:  42449407.42601857 vs  0.0
# .... iteration:  19854
#                         -> actual tol:  42201265.72146841 vs  0.0
# .... iteration:  19855
#                         -> actual tol:  41945153.75289742 vs  0.0
# .... iteration:  19856
#                         -> actual tol:  41681521.46112845 vs  0.0
# .... iteration:  19857
#                         -> actual tol:  41410840.42381964 vs  0.0
# .... iteration:  19858
#                         -> actual tol:  41133603.88792953 vs  0.0
# .... iteration:  19859
#                         -> actual tol:  40850326.77462457 vs  0.0
# .... iteration:  19860
#                         -> actual tol:  40561545.650107026 vs  0.0
# .... iteration:  19861
#                         -> actual tol:  40267818.65495755 vs  0.0
# .... iteration:  19862
#                         -> actual tol:  39969725.38363615 vs  0.0
# .... iteration:  19863
#                         -> actual tol:  39667866.70477698 vs  0.0
# .... iteration:  19864
#                         -> actual tol:  39362864.51185474 vs  0.0
# .... iteration:  19865
#                         -> actual tol:  39055361.392709486 vs  0.0
# .... iteration:  19866
#                         -> actual tol:  38746020.205313146 vs  0.0
# .... iteration:  19867
#                         -> actual tol:  38435523.54607039 vs  0.0
# .... iteration:  19868
#                         -> actual tol:  38124573.095903695 vs  0.0
# .... iteration:  19869
#                         -> actual tol:  37813888.82842031 vs  0.0
# .... iteration:  19870
#                         -> actual tol:  37504208.063645944 vs  0.0
# .... iteration:  19871
#                         -> actual tol:  37196284.35019852 vs  0.0
# .... iteration:  19872
#                         -> actual tol:  36890886.15843448 vs  0.0
# .... iteration:  19873
#                         -> actual tol:  36588795.36710495 vs  0.0
# .... iteration:  19874
#                         -> actual tol:  36290805.5265 vs  0.0
# .... iteration:  19875
#                         -> actual tol:  35997719.882021636 vs  0.0
# .... iteration:  19876
#                         -> actual tol:  35710349.14370678 vs  0.0
# .... iteration:  19877
#                         -> actual tol:  35429508.98951027 vs  0.0
# .... iteration:  19878
#                         -> actual tol:  35156017.29323558 vs  0.0
# .... iteration:  19879
#                         -> actual tol:  34890691.07193915 vs  0.0
# .... iteration:  19880
#                         -> actual tol:  34634343.152474195 vs  0.0
# .... iteration:  19881
#                         -> actual tol:  34387778.562597476 vs  0.0
# .... iteration:  19882
#                         -> actual tol:  34151790.65870703 vs  0.0
# .... iteration:  19883
#                         -> actual tol:  33927157.00973203 vs  0.0
# .... iteration:  19884
#                         -> actual tol:  33714635.06482094 vs  0.0
# .... iteration:  19885
#                         -> actual tol:  33514957.64106794 vs  0.0
# .... iteration:  19886
#                         -> actual tol:  33328828.27631425 vs  0.0
# .... iteration:  19887
#                         -> actual tol:  33156916.500731558 vs  0.0
# .... iteration:  19888
#                         -> actual tol:  32999853.089052826 vs  0.0
# .... iteration:  19889
#                         -> actual tol:  32858225.362540532 vs  0.0
# .... iteration:  19890
#                         -> actual tol:  32732572.615631483 vs  0.0
# .... iteration:  19891
#                         -> actual tol:  32623381.746239264 vs  0.0
# .... iteration:  19892
#                         -> actual tol:  32531083.170539465 vs  0.0
# .... iteration:  19893
#                         -> actual tol:  32456047.102391336 vs  0.0
# .... iteration:  19894
#                         -> actual tol:  32398580.274151072 vs  0.0
# .... iteration:  19895
#                         -> actual tol:  32358923.169429388 vs  0.0
# .... iteration:  19896
#                         -> actual tol:  32337247.829411473 vs  0.0
# .... iteration:  19897
#                         -> actual tol:  32333656.282928865 vs  0.0
# .... iteration:  19898
#                         -> actual tol:  32348179.636938166 vs  0.0
# .... iteration:  19899
#                         -> actual tol:  32380777.848951582 vs  0.0
# .... iteration:  19900
#                         -> actual tol:  32431340.18691175 vs  0.0
# .... iteration:  19901
#                         -> actual tol:  32499686.36570833 vs  0.0
# .... iteration:  19902
#                         -> actual tol:  32585568.333711278 vs  0.0
# .... iteration:  19903
#                         -> actual tol:  32688672.668029256 vs  0.0
# .... iteration:  19904
#                         -> actual tol:  32808623.524294857 vs  0.0
# .... iteration:  19905
#                         -> actual tol:  32944986.076117467 vs  0.0
# .... iteration:  19906
#                         -> actual tol:  33097270.371271674 vs  0.0
# .... iteration:  19907
#                         -> actual tol:  33264935.52638637 vs  0.0
# .... iteration:  19908
#                         -> actual tol:  33447394.179390676 vs  0.0
# .... iteration:  19909
#                         -> actual tol:  33644017.119133554 vs  0.0
# .... iteration:  19910
#                         -> actual tol:  33854138.014176086 vs  0.0
# .... iteration:  19911
#                         -> actual tol:  34077058.16741383 vs  0.0
# .... iteration:  19912
#                         -> actual tol:  34312051.229515016 vs  0.0
# .... iteration:  19913
#                         -> actual tol:  34558367.81171994 vs  0.0
# .... iteration:  19914
#                         -> actual tol:  34815239.94690215 vs  0.0
# .... iteration:  19915
#                         -> actual tol:  35081885.356528796 vs  0.0
# .... iteration:  19916
#                         -> actual tol:  35357511.48991074 vs  0.0
# .... iteration:  19917
#                         -> actual tol:  35641319.3105915 vs  0.0
# .... iteration:  19918
#                         -> actual tol:  35932506.81264325 vs  0.0
# .... iteration:  19919
#                         -> actual tol:  36230272.25683747 vs  0.0
# .... iteration:  19920
#                         -> actual tol:  36533817.1230202 vs  0.0
# .... iteration:  19921
#                         -> actual tol:  36842348.780484505 vs  0.0
# .... iteration:  19922
#                         -> actual tol:  37155082.88268267 vs  0.0
# .... iteration:  19923
#                         -> actual tol:  37471245.49628072 vs  0.0
# .... iteration:  19924
#                         -> actual tol:  37790074.977381885 vs  0.0
# .... iteration:  19925
#                         -> actual tol:  38110823.60980734 vs  0.0
# .... iteration:  19926
#                         -> actual tol:  38432759.0217065 vs  0.0
# .... iteration:  19927
#                         -> actual tol:  38755165.3975685 vs  0.0
# .... iteration:  19928
#                         -> actual tol:  39077344.50301282 vs  0.0
# .... iteration:  19929
#                         -> actual tol:  39398616.53963919 vs  0.0
# .... iteration:  19930
#                         -> actual tol:  39718320.84679898 vs  0.0
# .... iteration:  19931
#                         -> actual tol:  40035816.46648509 vs  0.0
# .... iteration:  19932
#                         -> actual tol:  40350482.58669405 vs  0.0
# .... iteration:  19933
#                         -> actual tol:  40661718.877645984 vs  0.0
# .... iteration:  19934
#                         -> actual tol:  40968945.734206006 vs  0.0
# .... iteration:  19935
#                         -> actual tol:  41271604.43677178 vs  0.0
# .... iteration:  19936
#                         -> actual tol:  41569157.241809085 vs  0.0
# .... iteration:  19937
#                         -> actual tol:  41861087.412153706 vs  0.0
# .... iteration:  19938
#                         -> actual tol:  42146899.196173474 vs  0.0
# .... iteration:  19939
#                         -> actual tol:  42426117.76391033 vs  0.0
# .... iteration:  19940
#                         -> actual tol:  42698289.1074105 vs  0.0
# .... iteration:  19941
#                         -> actual tol:  42962979.911603525 vs  0.0
# .... iteration:  19942
#                         -> actual tol:  43219777.401313655 vs  0.0
# .... iteration:  19943
#                         -> actual tol:  43468289.16927861 vs  0.0
# .... iteration:  19944
#                         -> actual tol:  43708142.989409685 vs  0.0
# .... iteration:  19945
#                         -> actual tol:  43938986.618953444 vs  0.0
# .... iteration:  19946
#                         -> actual tol:  44160487.59270171 vs  0.0
# .... iteration:  19947
#                         -> actual tol:  44372333.011943065 vs  0.0
# .... iteration:  19948
#                         -> actual tol:  44574229.3304491 vs  0.0
# .... iteration:  19949
#                         -> actual tol:  44765902.13943828 vs  0.0
# .... iteration:  19950
#                         -> actual tol:  44947095.953155965 vs  0.0
# .... iteration:  19951
#                         -> actual tol:  45117573.99644487 vs  0.0
# .... iteration:  19952
#                         -> actual tol:  45277117.99545393 vs  0.0
# .... iteration:  19953
#                         -> actual tol:  45425527.97243917 vs  0.0
# .... iteration:  19954
#                         -> actual tol:  45562622.04544565 vs  0.0
# .... iteration:  19955
#                         -> actual tol:  45688236.233520195 vs  0.0
# .... iteration:  19956
#                         -> actual tol:  45802224.26798834 vs  0.0
# .... iteration:  19957
#                         -> actual tol:  45904457.4102317 vs  0.0
# .... iteration:  19958
#                         -> actual tol:  45994824.276321985 vs  0.0
# .... iteration:  19959
#                         -> actual tol:  46073230.66880198 vs  0.0
# .... iteration:  19960
#                         -> actual tol:  46139599.41585051 vs  0.0
# .... iteration:  19961
#                         -> actual tol:  46193870.21802529 vs  0.0
# .... iteration:  19962
#                         -> actual tol:  46235999.502741896 vs  0.0
# .... iteration:  19963
#                         -> actual tol:  46265960.28662003 vs  0.0
# .... iteration:  19964
#                         -> actual tol:  46283742.04580387 vs  0.0
# .... iteration:  19965
#                         -> actual tol:  46289350.5943452 vs  0.0
# .... iteration:  19966
#                         -> actual tol:  46282807.97072018 vs  0.0
# .... iteration:  19967
#                         -> actual tol:  46264152.3325358 vs  0.0
# .... iteration:  19968
#                         -> actual tol:  46233437.859466344 vs  0.0
# .... iteration:  19969
#                         -> actual tol:  46190734.66444377 vs  0.0
# .... iteration:  19970
#                         -> actual tol:  46136128.713107824 vs  0.0
# .... iteration:  19971
#                         -> actual tol:  46069721.751500316 vs  0.0
# .... iteration:  19972
#                         -> actual tol:  45991631.24196254 vs  0.0
# .... iteration:  19973
#                         -> actual tol:  45901990.30716457 vs  0.0
# .... iteration:  19974
#                         -> actual tol:  45800947.68215874 vs  0.0
# .... iteration:  19975
#                         -> actual tol:  45688667.67430579 vs  0.0
# .... iteration:  19976
#                         -> actual tol:  45565330.13087036 vs  0.0
# .... iteration:  19977
#                         -> actual tol:  45431130.41402118 vs  0.0
# .... iteration:  19978
#                         -> actual tol:  45286279.38289901 vs  0.0
# .... iteration:  19979
#                         -> actual tol:  45131003.3823309 vs  0.0
# .... iteration:  19980
#                         -> actual tol:  44965544.2376722 vs  0.0
# .... iteration:  19981
#                         -> actual tol:  44790159.25514461 vs  0.0
# .... iteration:  19982
#                         -> actual tol:  44605121.22690942 vs  0.0
# .... iteration:  19983
#                         -> actual tol:  44410718.4399677 vs  0.0
# .... iteration:  19984
#                         -> actual tol:  44207254.68781188 vs  0.0
# .... iteration:  19985
#                         -> actual tol:  43995049.28356416 vs  0.0
# .... iteration:  19986
#                         -> actual tol:  43774437.07312461 vs  0.0
# .... iteration:  19987
#                         -> actual tol:  43545768.446614355 vs  0.0
# .... iteration:  19988
#                         -> actual tol:  43309409.34613425 vs  0.0
# .... iteration:  19989
#                         -> actual tol:  43065741.2675666 vs  0.0
# .... iteration:  19990
#                         -> actual tol:  42815161.25382408 vs  0.0
# .... iteration:  19991
#                         -> actual tol:  42558081.87659579 vs  0.0
# .... iteration:  19992
#                         -> actual tol:  42294931.20325448 vs  0.0
# .... iteration:  19993
#                         -> actual tol:  42026152.7451709 vs  0.0
# .... iteration:  19994
#                         -> actual tol:  41752205.383232005 vs  0.0
# .... iteration:  19995
#                         -> actual tol:  41473563.265880406 vs  0.0
# .... iteration:  19996
#                         -> actual tol:  41190715.67448611 vs  0.0
# .... iteration:  19997
#                         -> actual tol:  40904166.85033164 vs  0.0
# .... iteration:  19998
#                         -> actual tol:  40614435.77694432 vs  0.0
# .... iteration:  19999
#                         -> actual tol:  40322055.91095202 vs  0.0
#   --> time = 6.88  min |  412.52 seconds
# ---------------------------------
# ------> CGM converged?   False
#               --> Fit correctly?   False
# ---------------------------------
#   ------------------------------------------> TOTAL ALGORITHM TIME = 9.99  min |  599.52 seconds
