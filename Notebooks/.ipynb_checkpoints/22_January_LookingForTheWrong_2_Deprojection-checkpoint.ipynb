# %% [markdown]
# ## Imports

# %%
import os
import sys
import numpy as np
import time
import scipy
import matplotlib.pyplot as plt
import time
from scipy.stats import binned_statistic
from scipy.interpolate import interp1d

# %%
# import the frank2d directory
current_dir =  os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

#frank2d
from frank2d import Frank2D
from constants import rad_to_arcsec, deg_to_rad
import constants
from plot import Plot
from fitting import IterativeSolverMethod
from preprocess_vis import Gridding
from geometry import Geometry

# frank1d
import frank
from frank.geometry import FixedGeometry, SourceGeometry, FitGeometryGaussian
from frank.radial_fitters import FrankFitter
from frank.utilities import UVDataBinner

# %% [markdown]
# ### Functions

# %%
def get_vis_profile(frank_object):
    u = frank_object._FT._Un
    v = frank_object._FT._Vn
    pixel_size = (u[1]-u[0])
    q = np.hypot(u, v)
    Vis = frank_object.sol_visibility
    q = q.flatten()
    Vis = Vis.flatten()
    N = frank_object._Nx
    bin = (np.max(q) - np.min(q))/N
    weights_gridded = frank_object._gridded_data['weights']
    Vis_binned, bin_edges, _ = binned_statistic(q, Vis, 'mean', N)
    Vis_Weights_binned, bin_edges, _ = binned_statistic(q, Vis*weights_gridded, 'sum', N)
    Weights_binned, bin_edges, _ = binned_statistic(q, weights_gridded, 'sum', N)
    q_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    return q_centers, Vis_Weights_binned/Weights_binned

# %%
def deproject(u, v, inc, pa, inverse=False):  
    inc *= const.deg_to_rad
    pa *= const.deg_to_rad

    cos_t = np.cos(pa)
    sin_t = np.sin(pa)

    if inverse:
        sin_t *= -1
        u = u / np.cos(inc)

    up = u * cos_t - v * sin_t
    vp = u * sin_t + v * cos_t

    if inverse:
        return up, vp
    else:
    #   Deproject
        wp = up * np.sin(inc)
        up = up * np.cos(inc)

        return up, vp

# %%
def sweep_profile(r, I, project=False, phase_shift=False, geom=None, axis=0,
                  xmax=None, ymax=None, dr=None, deproject = False ):
    r"""
    Sweep a 1D radial brightness profile over :math:`2 \pi` to yield a 2D
    brightness distribution. Optionally project this sweep by a supplied
    geometry.

    Parameters
    ----------
    r : array
        Radial coordinates at which the 1D brightness profile is defined
    I : array
        Brightness values at r
    project : bool, default = False
        Whether to project the swept profile by the supplied geom
    phase_shift : bool, default = False
        Whether to phase shift the projected profile by the supplied geom.
        If False, the source will be centered in the image
    geom : SourceGeometry object, default=None
        Fitted geometry (see frank.geometry.SourceGeometry). Here we use
        geom.inc [deg], geom.PA [deg], geom.dRA [arcsec], geom.dDec [arcsec] if
        project=True
    axis : int, default = 0
        Axis over which to interpolate the 1D profile
    xmax, ymax : float, optional, default = None
        Value setting the x- and y-bounds of the image (same units as r). The
        positive and negative bounds are both set to this value (modulo sign).
        If not provided, these will be set to r.max()
    dr : float, optional, default = None
        Pixel size (same units as r). If not provided, it will be set at the
        same spatial scale as r

    Returns
    -------
    I2D : array, shape = (len(r), len(r))
        2D brightness distribution (projected if project=True)
    xmax : float
        Maximum x-value of the 2D grid
    ymax : float
        Maximum y-value of the 2D grid

    Notes
    -----
    Sign convention: a negative geom.dRA shifts the source to the right
    in the image

    """
    if project or deproject:
        inc, pa = geom['inc'], geom['pa']
        inc *= constants.deg_to_rad
        pa *= constants.deg_to_rad

        cos_i = np.cos(inc)
        cos_pa, sin_pa = np.cos(pa), np.sin(pa)

    if xmax is None:
        xmax = r.max()
    if ymax is None:
        ymax = r.max()

    if dr is None:
        dr = np.mean(np.diff(r))

    x = np.linspace(-xmax, xmax, int(xmax/dr))
    y = np.linspace(-ymax, ymax, int(ymax/dr))
    print(len(x))

    if phase_shift:
        xi, yi = np.meshgrid(x + geom['dra'], y - geom['ddec'])
    else:
        xi, yi = np.meshgrid(x, y)

    if project:
        xp  = xi * cos_pa + yi * sin_pa
        yp  = -xi * sin_pa + yi * cos_pa
        xp /= cos_i
        r1D = np.hypot(xp, yp)
    elif deproject:
        xp = xi * cos_i
        x_unrot = xp * cos_pa - yi * sin_pa
        y_unrot = xp * sin_pa + yi * cos_pa
        r1D = np.hypot(x_unrot, y_unrot)
    else:
        r1D = np.hypot(xi, yi)

    im_shape = r1D.shape + I.shape[1:]
    print(im_shape)

    interp = interp1d(r, I, bounds_error=False, fill_value=0., axis=axis)
    I2D = interp(r1D.ravel()).reshape(*im_shape)

    return I2D, xmax, ymax

# %%
def deproject_profile(r, I, phase_shift=False, geom=None, axis=0, xmax=None, ymax=None, dr=None):
    inc, pa = geom['inc'], geom['pa']
    inc *= constants.deg_to_rad
    pa *= constants.deg_to_rad

    cos_i = np.cos(inc)
    cos_pa, sin_pa = np.cos(pa), np.sin(pa)

    if xmax is None:
        xmax = r.max()
    if ymax is None:
        ymax = r.max()

    if dr is None:
        dr = np.mean(np.diff(r))

    x = np.linspace(-xmax, xmax, int(xmax/dr))
    y = np.linspace(-ymax, ymax, int(ymax/dr))

    if phase_shift:
        xi, yi = np.meshgrid(x + geom['dra'], y - geom['ddec'])
    else:
        xi, yi = np.meshgrid(x, y)

    xp = xi * cos_i
    x_unrot = xp * cos_pa - yi * sin_pa
    y_unrot = xp * sin_pa + yi * cos_pa
    r1D = np.hypot(x_unrot, y_unrot)

    return r1D, I

# %% [markdown]
# ### Data

# %%
# Huang 2018 
inc = 34.97
pa = 85.76
dra = 1.9e-3
ddec = -2.5e-3
Rout = 1.5 #arcsecs

# UVtable
dir = "../../../data/"
data_file = dir +'AS209_continuum_prom_1chan_30s_keepflagsFalse.txt'

 # load data||
u, v, Re, Imag, Weights = np.loadtxt(data_file, unpack = True)
Vis = Re + Imag*1j

# %%
geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)
u_deproj, v_deproj, vis_deproj = geom.apply_correction(u, v, Vis)

# %% [markdown]
# ### Let's see the gridded visibilities

# %%
N = 300

# %%
m, c, l = -0.33, -0.1, 1e5

# %%
geom = Geometry(inc, pa, dra, ddec)
frank2d = Frank2D(N, Rout, geom)

# %%
frank2d.preprocess_vis(u, v, Vis, Weights)
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/preprocess_vis.py:46: RuntimeWarning: invalid value encountered in divide
#   vis_gridded_matrix =  vis_weights_sum_bin/weights_sum_bin
#   --> time = 0.02  min |  1.48 seconds
# Setting gridded data...

# %%
u_gridded, v_gridded, vis_gridded, weights_gridded = frank2d._gridded_data['u'], frank2d._gridded_data['v'], frank2d._gridded_data['vis'], frank2d._gridded_data['weights']

# %%
FT = frank2d._FT
x_labels = np.fft.fftshift(FT._u/1e6)
y_labels = np.fft.fftshift(FT._v/1e6)

num_ticks = 5
x_ticks_to_show = np.linspace(0, len(x_labels) - 1, num_ticks).astype(int)
y_ticks_to_show = np.linspace(0, len(y_labels) - 1, num_ticks).astype(int)

def format_labels(x):
    return f"{int(x):d}" if abs(x) > 1e-8 else "0"

# %% [markdown]
# ### Plots

# %%
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(F'Input, Frank2D N = {N}, log |Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_72933/3928879700.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)

# %%
frank2d.frank1d(u, v, Vis, Weights)
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/preprocess_vis.py:46: RuntimeWarning: invalid value encountered in divide
#   vis_gridded_matrix =  vis_weights_sum_bin/weights_sum_bin

# %%
vis_f1d = frank2d._frank1d_guess

# %%
plt.imshow(np.log(np.abs(np.fft.fftshift((vis_f1d).reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(F'Frank2D N = {N}, log |Visibilities|')
plt.colorbar()

# %%
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_f1d.reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(F'Frank2D N = {N}, log |Visibilities|')
plt.colorbar()

# %%
plt.imshow(np.log(np.abs(np.fft.fftshift((vis_f1d).reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)
plt.imshow(np.log(np.abs(np.fft.fftshift((vis_gridded).reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(F'Frank2D N = {N}, log |Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_70592/3226150350.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift((vis_gridded).reshape(frank2d._FT._Nx, frank2d._FT._Ny)))), origin='lower', vmin=-12, vmax=-2)

# %% [markdown]
# ### Running F2D

# %%
N = 400
m, c, l = -0.33, -0.1, 1e5

# %%
start_time = time.time()

#####
frank2d_deprojected = Frank2D(N, Rout, Geometry(inc, pa, dra, ddec, deproject = True))
frank2d_deprojected.set_kernel('Wendland', [m, c, l])
frank2d_deprojected.fit(u, v, Vis, Weights, method = 'bicgstab', rtol = 1e-15, frank1d_guess = False)

#####
print("--------------------------------------")
end_time = time.time()
execution_time = end_time - start_time
print(f'time = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 start_time = time.time()
#       3 #####
# ----> 4 frank2d_deprojected = Frank2D(N, Rout, Geometry(inc, pa, dra, ddec, deproject = True))
#       5 frank2d_deprojected.set_kernel('Wendland', [m, c, l])
#       6 frank2d_deprojected.fit(u, v, Vis, Weights, method = 'bicgstab', rtol = 1e-15, frank1d_guess = False)
#
# TypeError: __init__() got an unexpected keyword argument 'deproject'

# %%
frank2d_deprojected.fft()

# %%
vis_sol_deprojected = frank2d_deprojected.sol_visibility.reshape(N, N)

# %%
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_sol_deprojected))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])
plt.title(F'Frank2D N = {N}, solution for log |Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_25961/3391530539.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift(vis_sol_deprojected))), origin='lower', vmin=-12, vmax=-2)

# %%
Plot(frank2d_deprojected).get_image("Intensity model deprojected", size = 6)

# %%
def get_radial_profile(frank_object):
    x = frank_object._FT._Xn*rad_to_arcsec
    y = frank_object._FT._Yn*rad_to_arcsec
    r = np.hypot(x, y)
    I = frank_object.sol_intensity
    r = r
    I = I.flatten()
    N = frank_object._Nx
    bin = (np.max(r) - np.min(r))/(N)
    I_binned, bin_edges, _ = binned_statistic(r, I, 'mean', N)
    r_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    return r_centers, I_binned

# %%
r_f2d_deprojected, I_f2d_deprojected = get_radial_profile(frank2d_deprojected)

# %% [markdown]
# ### Projected scheme

# %%
start_time = time.time()

#####
frank2d = Frank2D(N, Rout, Geometry(inc, pa, dra, ddec))
frank2d.set_kernel('Wendland', [m, c, l])
frank2d.fit(u, v, Vis, Weights, method = 'bicgstab', rtol = 1e-15, frank1d_guess = False)

#####
print("--------------------------------------")
end_time = time.time()
execution_time = end_time - start_time
print(f'time = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
# Out:
# Setting kernel: Wendland...
# Gridding...
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/preprocess_vis.py:46: RuntimeWarning: invalid value encountered in divide
#   vis_gridded_matrix =  vis_weights_sum_bin/weights_sum_bin
#   --> time = 0.04  min |  2.48 seconds
# Setting gridded data...
# Setting fit with bicgstab ...
# Setting guess... Visibilities gridded
# Fitting...
#   *  Constructing linear operators...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 frank2d = Frank2D(N, Rout, Geometry(inc, pa, dra, ddec))
#       5 frank2d.set_kernel('Wendland', [m, c, l])
# ----> 6 frank2d.fit(u, v, Vis, Weights, method = 'bicgstab', rtol = 1e-15, frank1d_guess = False)
#       8 #####
#       9 print("--------------------------------------")
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d.py:104, in Frank2D.fit(self, u, v, Vis, Weights, type_kernel, kernel_params, rtol, method, frank1d_guess, hermitian, vis_component)
#     101 self.set_fit_method(type_kernel, kernel_params, method, rtol)
#     103 print("Fitting...")
# --> 104 vis_model = self._method.solve()
#     105 self.sol_visibility = vis_model
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/fitting.py:497, in IterativeSolverMethod.solve(self)
#     494 print("  *  Constructing linear operators...")
#     495 start_time = time.time()
# --> 497 self.create_sparse_system()
#     499 end_time = time.time()
#     500 execution_time = end_time - start_time
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/fitting.py:440, in IterativeSolverMethod.create_sparse_system(self)
#     437 indptr_b = [0]
#     439 for i in range(self._N2):
# --> 440     row = self._kernel_row(i)
#     441     weights = self._Weights
#     443     non_zero_indices = np.nonzero(row)[0]
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/gaussian_process.py:72, in Wendland.kernel(self, i)
#      69 amp = np.sqrt(self._power_spectrum_q1 * self.power_spectrum(self._q[i], self._m, self._c))
#      71 r_normalized = np.sqrt((self._uh-self._uh[i])**2 + (self._vh-self._vh[i])**2)
# ---> 72 factor = (1 - r_normalized)**self._j
#      73 factor[r_normalized > 1] = 0
#      75 return amp * factor * self.P_k(r_normalized, self._k)
#
# KeyboardInterrupt:

# %%
vis_sol = frank2d.sol_visibility.reshape(N, N)

# %%
us, vs = np.fft.fftshift(frank2d._FT._Un.reshape(frank2d._FT._Nx, frank2d._FT._Ny)).flatten(), np.fft.fftshift(frank2d._FT._Vn.reshape(frank2d._FT._Nx, frank2d._FT._Ny)).flatten()
viss = np.fft.fftshift(vis_sol).flatten()

# %%
plt.pcolormesh(vs.reshape(N,N), us.reshape(N,N), np.log(np.abs(viss.reshape(N,N))), cmap="viridis", vmin=-12, vmax=-2)
plt.xlabel(r'u [ $\lambda$]')
plt.ylabel(r'v [ $\lambda$]')
plt.gca().set_aspect('equal') 
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_71834/4055328726.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(vs.reshape(N,N), us.reshape(N,N), np.log(np.abs(viss.reshape(N,N))), cmap="viridis", vmin=-12, vmax=-2)

# %%
u_d, v_d,_ = Geometry(inc, pa, dra, ddec).deproject(us, vs)

# %%
plt.pcolormesh(v_d.reshape(N,N), u_d.reshape(N,N), np.log(np.abs(viss.reshape(N,N))), cmap="viridis", vmin=-12, vmax=-2)
plt.colorbar()
plt.xlabel(r'u [ $\lambda$]')
plt.ylabel(r'v [ $\lambda$]')
plt.gca().set_aspect('equal') 
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_71834/410955889.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(v_d.reshape(N,N), u_d.reshape(N,N), np.log(np.abs(viss.reshape(N,N))), cmap="viridis", vmin=-12, vmax=-2)

# %%
r_d = np.hypot(u_d, v_d)
visibilities = viss

r_min = 0.0
r_max = np.max(r)
dr = np.abs(frank2d._FT._v[1]- frank2d._FT._v[0]) # Ancho del bin (en unidades de 1e6 λ)
rbins = np.arange(r_min, r_max + dr, dr)
r_d_vals = 0.5 * (rbins[:-1] + rbins[1:])  # Centros de los bins

# Calcular estadística binned
vis_profile, _, _ = binned_statistic(
    r_d,  # Radio elíptico a usar para binning
    visibilities,  # Valores (|V|) a promediar
    statistic='mean',  # Usar la media
    bins=rbins  # Bins definidos
)

vis_profile_w, _, _ = binned_statistic(
    r_d,
    visibilities*weights_gridded,  # Valores (|V|) a promediar
    statistic='sum',  # Usar la media
    bins=rbins  # Bins definidos
)

weights_binned, _, _ = binned_statistic(r_d, weights_gridded, 'sum', rbins)
weights_binned = np.nan_to_num(weights_binned, nan=0)

vis_profile_weighted =  vis_profile_w/weights_binned

# %%
# Graficar el perfil radial
plt.plot(r_d_vals, np.abs(vis_profile), marker = 'x')
plt.xlabel(r"q ($\times 1e6 \lambda$)")
plt.ylabel(r"|V| Jy")
plt.title(" visibility profile")
plt.ylim(1e-4, 0.25)
plt.xlim(1e4, 6e6)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.show()

# %%
frank2d.fft()
# Out:
# Inverting with 2fft ...
#   --> time = 0.00  min |  0.00 seconds

# %%
frank2d._FT._Xn
# Out:
# array([-7.27220522e-06, -7.27220522e-06, -7.27220522e-06, ...,
#         7.22372385e-06,  7.22372385e-06,  7.22372385e-06])

# %%
x , y = frank2d._FT._Xn*rad_to_arcsec, frank2d._FT._Yn*rad_to_arcsec

# %%
plt.pcolormesh(x.reshape(N,N), y.reshape(N,N), frank2d.sol_intensity, cmap = 'magma')
plt.xlabel(r'x [ $arcsecs$]')
plt.ylabel(r'y [ $arcsecs$]')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.colorbar()
plt.gca().set_aspect('equal') 
plt.show()

# %%
inc_r = inc*constants.deg_to_rad
pa_r = pa*constants.deg_to_rad

cos_i = np.cos(inc_r)
cos_pa, sin_pa = np.cos(pa_r), np.sin(pa_r)


x_d = (x * cos_pa + y * sin_pa) / cos_i
y_d = (x *-sin_pa + y * cos_pa)

# %%
plt.pcolormesh(x_d.reshape(N,N), y_d.reshape(N,N), frank2d.sol_intensity, cmap = 'magma')
plt.xlabel(r'x [ $arcsecs$]')
plt.ylabel(r'y [ $arcsecs$]')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.colorbar()
plt.gca().set_aspect('equal') 
plt.show()

# %%
Plot(frank2d, Geometry(inc, pa, dra, ddec)).get_image_intensity(deprojected = True, fig_size = 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 Plot(frank2d, Geometry(inc, pa, dra, ddec)).get_image_intensity(deprojected = True, fig_size = 5)
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/plot.py:25, in Plot.get_image_intensity(self, title, fig_size, add_fourier_resolution, log_norm, deprojected)
#      22 I = frank2d.sol_intensity.reshape(Nx, Ny)
#      24 if deprojected:
# ---> 25     inc_r = self._geometry.inc*deg_to_rad
#      26     pa_r = self._geometry.pa*deg_to_rad
#      28     cos_i = np.cos(inc_r)
#
# AttributeError: 'Geometry' object has no attribute 'inc'

# %% [markdown]
# ### Trying the FITS approach

# %%
from astropy.io import fits
import numpy as np

# Supongamos que 'image_data' es tu matriz de intensidades (Jy/sr)
image_data = frank2d.sol_intensity.reshape(N, N)  # Ejemplo, ya que mencionaste esta variable

# Crear un PrimaryHDU (imagen FITS)
hdu = fits.PrimaryHDU(image_data)
pixel_size = frank2d._FT._dx*rad_to_arcsec

# Crear un Header para definir la escala de píxeles y la orientación
header = hdu.header
header['CDELT1'] = -pixel_size/3600   # Tamaño de píxel en grados (negativo si el eje decrece)
header['CDELT2'] = pixel_size/3600   # Tamaño de píxel en grados
header['CRPIX1'] = image_data.shape[1] / 2  # Centro de la imagen en X
header['CRPIX2'] = image_data.shape[0] / 2  # Centro de la imagen en Y
header['CRVAL1'] = 0  # Coordenada del centro (RA)
header['CRVAL2'] = 0  # Coordenada del centro (Dec)
header['CTYPE1'] = 'RA---TAN'  # Tipo de proyección
header['CTYPE2'] = 'DEC--TAN'
header['BUNIT'] = 'Jy/sr'  # Unidades de la imagen

# Guardar la imagen como un archivo FITS
fits_filename = "image.fits"
hdu.writeto(fits_filename, overwrite=True)

print(f"Archivo FITS guardado: {fits_filename}")
# Out:
# Archivo FITS guardado: image.fits

# %%
import gofish

# Cargar la imagen FITS en gofish
cube = gofish.imagecube(fits_filename)

inc = inc 
PA = pa-90

rvals = np.linspace(0, Rout, 120)

# Obtener el perfil radial
x, y, dy = cube.radial_profile(rvals = rvals, inc=inc, PA=PA)

fig, ax = plt.subplots()
ax.errorbar(x, y, dy, fmt=' ', capsize=1.25, capthick=1.25, color='k', lw=1.0)
ax.step(x, y, where='mid', color='k', lw=1.0)
ax.set_xlim(x.min(), x.max())
ax.set_xlabel('Radius (arcsec)')
ax.set_ylabel('Brightness Intensity (Jy/sr)')
# Out:
# WARNING: No beam values found. Assuming pixel as beam.
# WARNING: Provided cube is only 2D. Shifting not available.
# WARNING: Attached data is not 3D, so shifting cannot be applied.
# 	 Reverting to standard azimuthal averaging; will ignore `unit` argument.
# Text(0, 0.5, 'Brightness Intensity (Jy/sr)')

# %% [markdown]
# ### Frank1d

# %%
# Frank 1D Parameters
n_pts = 300
alpha = 1.3
w_smooth = 1e-3

geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)
FF = FrankFitter(Rout, n_pts, geom, alpha = alpha, weights_smooth = w_smooth)
sol = FF.fit(u, v, Vis, Weights)

# %% [markdown]
# #### Comparison

# %%
plt.figure(figsize=(7,4))
plt.plot(sol.r, sol.mean, 'black',label =f'frank1d deprojected: N = {n_pts}')
plt.plot(x, y, label = f'frank2d deprojected: N = {N}')
plt.xlabel('r ["]')
plt.xlim(0,1.5)      
plt.ylim(1.5e7, 1e11)
plt.ylabel(r'I [Jy $sr^{-1}$]')
plt.legend()
plt.yscale("log")
plt.show()

# %%
u_gridded_d, v_gridded_d, _= Geometry(inc, pa, dra, ddec).deproject(u_gridded, v_gridded)

# %%
# Variables plot.
cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths=[1e3, 1e5]
baselines = np.hypot(u_deproj, v_deproj)         
grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
                           np.log10(max(baselines.max(), baselines[-1])),
                           10**4)


plt.figure(figsize=(10,7))
# ---------------------------------------------------------------------------------------------
# Raw visibilities
for i in range(len(bin_widths)):
            binned_vis = UVDataBinner(baselines, vis_deproj, Weights, bin_widths[i])
            plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[i],
                         marker=ms[i], ls='None', 
                         label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[i]/1e3))

# ---------------------------------------------------------------------------------------------
# Gridded visibilities
#baselines_gridded_d = np.hypot(u_gridded_d, v_gridded_d)  
#binned_vis_gridded = UVDataBinner(baselines_gridded_d, vis_gridded, weights_gridded, bin_widths[1])
#plt.plot(binned_vis_gridded.uv, np.abs(binned_vis_gridded.V), c='pink',
#             marker=ms[1], ls='None', 
#             label=r'Input weighted and gridded: Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[1]/1e3))


# ---------------------------------------------------------------------------------------------
#frank1d
vis_fit_1d = sol.predict_deprojected(sol.q)
baselines_fit_1d = sol.q
plt.plot(baselines_fit_1d, np.abs(vis_fit_1d), color = "green", label = r'frank1d')

# ---------------------------------------------------------------------------------------------
#frank2d

plt.plot(r_d_vals, vis_profile, color = 'blue',label = f'frank2d: N = {N}, bicgstab, Wendland')

binned_vis2 = UVDataBinner(r_d_vals, vis_profile_weighted, np.ones_like(weights_binned), bin_widths[1])
plt.plot(binned_vis2.uv, np.abs(binned_vis2.V), c = 'red',
             marker=ms[1], ls='None', 
             label=r'frank2d weighted, {:.0f} k$\lambda$ bins'.format(1e2/1e3))

plt.xlabel(r'baseline [$\lambda$]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e-4, 1)
plt.xlim(1e4, 6e6)
plt.ylabel('Re(V) [Jy]', size = 10)
plt.legend(fontsize =7)
plt.show()

# %%
I2D_deprojected, xmax_out_deprojected, ymax_out_deprojected = sweep_profile(sol.r, sol.mean, project= False, phase_shift = False, geom = {'inc': inc, 'pa':pa, 'dra':dra, 'ddec':ddec}, xmax = xmax, ymax = ymax, dr = dr)
# Out:
# 300
# (300, 300)

# %%
# Crear grilla para el gráfico
x_deprojected = np.linspace(-xmax_out_deprojected, xmax_out_deprojected, I2D_deprojected.shape[1])
y_deprojected = np.linspace(-ymax_out_deprojected, ymax_out_deprojected, I2D_deprojected.shape[0])

# Gráfico con imshow
plt.figure(figsize=(4, 4))
extent = [-xmax_out_deprojected, xmax_out_deprojected, -ymax_out_deprojected, ymax_out_deprojected]  # Extensión del gráfico
plt.imshow(I2D_deprojected, extent=extent, origin='lower', cmap='inferno', aspect='auto')
plt.colorbar(label='Brightness', shrink= 0.8)
plt.xlabel('x ["]')
plt.ylabel('y ["]')
plt.title('2D Brightness Distribution Deprojected', size= 7)
plt.gca().set_aspect('equal') 
plt.show()

# %% [markdown]
# #### Projected profile

# %%
I2D, xmax_out, ymax_out = sweep_profile(sol.r, sol.mean, project= True, phase_shift = False, geom = {'inc': inc, 'pa':pa, 'dra':dra, 'ddec':ddec}, xmax = xmax, ymax = ymax, dr = dr)
# Out:
# 300
# (300, 300)

# %%
# Crear grilla para el gráfico
x = np.linspace(-xmax_out, xmax_out, I2D.shape[1])
y = np.linspace(-ymax_out, ymax_out, I2D.shape[0])

# Gráfico con imshow
plt.figure(figsize=(6, 6))
extent = [xmax_out, -xmax_out, -ymax_out, ymax_out]  # Extensión del gráfico
plt.imshow(I2D, extent=extent, origin='lower', cmap='inferno', aspect='auto')
plt.colorbar(label='Brightness', shrink= 0.8)
plt.xlabel('x ["]')
plt.ylabel('y ["]')
plt.title('Frank1D Projected', size = 12)
plt.gca().set_aspect('equal') 
plt.show()

# %%
r1d, I1d = radial_profile(x, y, I2D)

# %%
from matplotlib.patches import Ellipse

percentage = 0.3

# Configuración de la elipse
PA = pa - 90  # Ángulo de posición en grados
inc = inc  # Inclinación en grados

# Coordenadas de la elipse
center_x = len(x_labels) // 2  # Centro de la matriz en x
center_y = len(y_labels) // 2  # Centro de la matriz en y

# Tamaño de la elipse
a = percentage * len(x_labels) / 2  # Semieje mayor (en píxeles)
cos_inc = np.cos((inc)*deg_to_rad)
b = a * cos_inc  # Semieje menor proyectado por la inclinación

# Crear la elipse
ellipse = Ellipse(
    (center_x, center_y),  # Centro de la elipse en coordenadas de la matriz
    width=2 * a,  # Diámetro mayor
    height=2 * b,  # Diámetro menor
    angle=PA,  # Rotación de la elipse (en grados)
    edgecolor="red",  # Color del borde
    facecolor="none",  # Sin relleno
    linewidth=2,  # Grosor de la línea
)

plt.imshow(np.log(np.abs(np.fft.fftshift(frank2d.sol_visibility.reshape(N,N)))), origin='lower', vmin=-12, vmax=-2)
plt.xticks(ticks=x_ticks_to_show, labels=[format_labels(x) for x in np.array(x_labels)[x_ticks_to_show]])
plt.yticks(ticks=y_ticks_to_show, labels=[format_labels(y) for y in np.array(y_labels)[y_ticks_to_show]])

plt.gca().set_aspect('equal')  

# Añadir la elipse a la gráfica
plt.gca().add_patch(ellipse)

plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(F'Output, log |Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_61546/3963573759.py:29: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift(frank2d.sol_visibility.reshape(N,N)))), origin='lower', vmin=-12, vmax=-2)

# %%
U, V = np.fft.fftshift(frank2d._FT._Un.reshape(frank2d._FT._Nx, frank2d._FT._Ny)), np.fft.fftshift(frank2d._FT._Vn.reshape(frank2d._FT._Nx, frank2d._FT._Ny))

# %%
# Aplanar las matrices para pasar a binned_statistic
R_ellipse_flat = R_ellipse.flatten()
visibilities = np.fft.fftshift(vis_sol).flatten()

# Definir bins radiales (radio elíptico)
r_min = 0.0
r_max = np.max(R_ellipse)
dr = 0.1e2  # Ancho del bin (en unidades de 1e6 λ)
rbins = np.arange(r_min, r_max + dr, dr)
rvals2 = 0.5 * (rbins[:-1] + rbins[1:])  # Centros de los bins

# Calcular estadística binned
radial_profile2, _, _ = binned_statistic(
    R_ellipse_flat,  # Radio elíptico a usar para binning
    visibilities,  # Valores (|V|) a promediar
    statistic='mean',  # Usar la media
    bins=rbins  # Bins definidos
)

weights_binned, _, _ = binned_statistic(R_ellipse_flat, weights_gridded, 'sum', rbins)
weights_binned = np.nan_to_num(weights_binned, nan=0)

# Graficar el perfil radial
plt.plot(rvals2, radial_profile2.real, marker=".")
plt.xlabel(r"Radio elíptico ($\times 1e6 \lambda$)")
plt.ylabel(r"Intensidad promedio |V|")
plt.title("Perfil radial elíptico")
plt.ylim(1e-4, 1)
plt.xlim(1e4, 6e6)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.show()

# %%
np.any(np.isnan(weights_binned))
# Out:
# False

# %% [markdown]
# ### Comparing with CLEAN

# %%
# Obtain the radial profiles convolved to a circular beam.
from gofish import imagecube

infile_1mm = dir + 'AS209_1mm_13s_conv_circ.fits'
#2D->1D
cube_1mm = imagecube(infile_1mm)
x_1mm,y_1mm,dy_1mm = cube_1mm.radial_profile(inc=inc, PA=pa, x0=dra, y0=ddec)
# Out:
# WARNING: Provided cube is only 2D. Shifting not available.
# WARNING: Attached data is not 3D, so shifting cannot be applied.
# 	 Reverting to standard azimuthal averaging; will ignore `unit` argument.

# %%
from frank.utilities import convolve_profile

clean_beam_1mm = {'bmaj':0.0373, 'bmin':0.0373, 'beam_pa':31.040}
area_1mm = clean_beam_1mm['bmaj']*clean_beam_1mm['bmin']*np.pi/4./np.log(2.)*(1/rad_to_arcsec)**2

convolved_1mm_frank2d = convolve_profile(r, I, inc, pa, clean_beam_1mm)*area_1mm
convolved_1mm_frank1d = convolve_profile(sol.r, sol.mean, inc, pa, clean_beam_1mm)*area_1mm

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_1mm, y_1mm, "black", label = "CLEAN")
plt.fill_between(x_1mm, y_1mm-dy_1mm, y_1mm+dy_1mm,alpha=0.7)
plt.plot(sol.r, convolved_1mm_frank1d, "red", label=r'frank1d' + ', N = ' +str(n_pts))
plt.plot(r,convolved_1mm_frank2d, "blue", label=r'frank2d' + ', N = ' +str(N))
plt.title(r'AS209 1mm', size=10)
plt.ylabel("log(I) [Jy/beam]", size=10)
plt.xlabel('r ["]', size=10)
plt.legend(fontsize=10)
#plt.yscale('log')
#plt.ylim(0.1e-5, 0.5e-2)
plt.xlim(0,1.2)
plt.show()
