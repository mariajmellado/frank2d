# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
current_dir =  os.getcwd()
# replace this following line in the path your frank2d files are.
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# frank2d
from frank2d import Frank2D
from frank2d.geometry import Geometry
from frank2d.plot import Plot
from frank2d.posterior_optimization import *
from frank2d.constants import rad_to_arcsec, deg_to_rad

# %%
# Huang 2018 
AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
HD143006 = {'inc': 18.6, 'pa': 169, 'dra':-5.9e-3, 'ddec':21.7e-3, 'rout': 0.518*3, 'disk_name': 'HD143006'}

# %%
def f2d(data):
    dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
    disk_name = data['disk_name']
    data_file = dir +"uvtable_" + disk_name + "_continuum.npz"
    
    inc = data['inc']
    pa = data['pa']
    dra = data['dra']
    ddec = data['ddec']
    rout = data['rout']

    # Frank Parameters
    N = 300
    
    # Load data
    file = np.load(data_file)
    u, v, Re, Im, Weights = file['u'], file['v'], file['Re'], file['Im'], file['w']
    Vis = Re + Im*1j
    
    uvtable = {'u': u, 'v': v, 'vis': Vis, 'weights': Weights }

    dir_fits =  "/Users/mariajmelladot/Desktop/Frank2D/data/fits/"
    disk_fits = disk_name + '_continuum.fits'
    fits_file = dir_fits + disk_fits

    geom = Geometry(inc, pa, dra, ddec)
    frank2d = Frank2D(N, rout, geom)
    
    return frank2d, geom, uvtable, fits_file

# %% [markdown]
# # AS209

# %%
f2d_AS209, geom_AS209, uvtable_AS209, fits_1mm_AS209 = f2d(AS209)

# %%
#start_time = time.time()

params_AS209 =  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_AS209.fit(u = uvtable_AS209['u'], v = uvtable_AS209['v'], Vis = uvtable_AS209['vis'], Weights = uvtable_AS209['weights'], 
              kernel_params = params_AS209, rtol = 1e-8 )

#end_time = time.time()
#print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")
# Out:
# Shifted grid..
# Setting gridded data...
# Setting GP Kernel Wendland...
# Creating sparse linear system...
# --> time = 0.07  min |  4.31 seconds
# Solving linear system...
#          * rtol: 1e-08
#          * final tolerance: 2.881751982790495
# Final tolerance :  2.881751982790495
# .... iteration:  0
#                         -> actual tol:  288175198.2790495 vs  2.881751982790495
# .... iteration:  1
#                         -> actual tol:  39773051.282940544 vs  2.881751982790495
# .... iteration:  2
#                         -> actual tol:  30605898.285020255 vs  2.881751982790495
# .... iteration:  3
#                         -> actual tol:  31458951.244836483 vs  2.881751982790495
# .... iteration:  4
#                         -> actual tol:  32660086.132000692 vs  2.881751982790495
# .... iteration:  5
#                         -> actual tol:  32037725.273025826 vs  2.881751982790495
# .... iteration:  6
#                         -> actual tol:  68809248.88808323 vs  2.881751982790495
# .... iteration:  7
#                         -> actual tol:  30549785.13818835 vs  2.881751982790495
# .... iteration:  8
#                         -> actual tol:  15619056.223080724 vs  2.881751982790495
# .... iteration:  9
#                         -> actual tol:  15106613.745141823 vs  2.881751982790495
# .... iteration:  10
#                         -> actual tol:  15353843.130768433 vs  2.881751982790495
# .... iteration:  11
#                         -> actual tol:  15640737.57117201 vs  2.881751982790495
# .... iteration:  12
#                         -> actual tol:  14915324.546804238 vs  2.881751982790495
# .... iteration:  13
#                         -> actual tol:  14578692.228055913 vs  2.881751982790495
# .... iteration:  14
#                         -> actual tol:  24140817.84654432 vs  2.881751982790495
# .... iteration:  15
#                         -> actual tol:  10117098.85397686 vs  2.881751982790495
# .... iteration:  16
#                         -> actual tol:  9843312.237925224 vs  2.881751982790495
# .... iteration:  17
#                         -> actual tol:  15797903.608991489 vs  2.881751982790495
# .... iteration:  18
#                         -> actual tol:  17004165.99834748 vs  2.881751982790495
# .... iteration:  19
#                         -> actual tol:  7765402.093841845 vs  2.881751982790495
# .... iteration:  20
#                         -> actual tol:  6278538.515631121 vs  2.881751982790495
# .... iteration:  21
#                         -> actual tol:  5834893.7678317195 vs  2.881751982790495
# .... iteration:  22
#                         -> actual tol:  5531678.711482682 vs  2.881751982790495
# .... iteration:  23
#                         -> actual tol:  5518203.325102418 vs  2.881751982790495
# .... iteration:  24
#                         -> actual tol:  6030954.244375523 vs  2.881751982790495
# .... iteration:  25
#                         -> actual tol:  5026775.693373072 vs  2.881751982790495
# .... iteration:  26
#                         -> actual tol:  4597030.847021723 vs  2.881751982790495
# .... iteration:  27
#                         -> actual tol:  4406453.377553039 vs  2.881751982790495
# .... iteration:  28
#                         -> actual tol:  4284102.501449169 vs  2.881751982790495
# .... iteration:  29
#                         -> actual tol:  4281627.241885322 vs  2.881751982790495
# .... iteration:  30
#                         -> actual tol:  3740118.3992752032 vs  2.881751982790495
# .... iteration:  31
#                         -> actual tol:  3737669.271781657 vs  2.881751982790495
# .... iteration:  32
#                         -> actual tol:  3317259.170118467 vs  2.881751982790495
# .... iteration:  33
#                         -> actual tol:  3112067.502338968 vs  2.881751982790495
# .... iteration:  34
#                         -> actual tol:  2931443.1003475767 vs  2.881751982790495
# .... iteration:  35
#                         -> actual tol:  2984253.9880310725 vs  2.881751982790495
# .... iteration:  36
#                         -> actual tol:  2782829.921570151 vs  2.881751982790495
# .... iteration:  37
#                         -> actual tol:  2716497.4160828236 vs  2.881751982790495
# .... iteration:  38
#                         -> actual tol:  2696290.8448694437 vs  2.881751982790495
# .... iteration:  39
#                         -> actual tol:  2661757.6753322063 vs  2.881751982790495
# .... iteration:  40
#                         -> actual tol:  3506573.7677817107 vs  2.881751982790495
# .... iteration:  41
#                         -> actual tol:  5134915.624111053 vs  2.881751982790495
# .... iteration:  42
#                         -> actual tol:  4887189.78355628 vs  2.881751982790495
# .... iteration:  43
#                         -> actual tol:  5996807.5007459745 vs  2.881751982790495
# .... iteration:  44
#                         -> actual tol:  1083430.0173120738 vs  2.881751982790495
# .... iteration:  45
#                         -> actual tol:  736594.2233488783 vs  2.881751982790495
# .... iteration:  46
#                         -> actual tol:  664083.7985923708 vs  2.881751982790495
# .... iteration:  47
#                         -> actual tol:  712757.8827286612 vs  2.881751982790495
# .... iteration:  48
#                         -> actual tol:  730605.5107966884 vs  2.881751982790495
# .... iteration:  49
#                         -> actual tol:  713498.0064027794 vs  2.881751982790495
# .... iteration:  50
#                         -> actual tol:  694855.785948788 vs  2.881751982790495
# .... iteration:  51
#                         -> actual tol:  695350.7350634142 vs  2.881751982790495
# .... iteration:  52
#                         -> actual tol:  1052637.836306778 vs  2.881751982790495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 #start_time = time.time()
#       3 params_AS209 =  {'m': -2, 'c': 1e8, 'l': 7e4}
# ----> 4 f2d_AS209.fit(u = uvtable_AS209['u'], v = uvtable_AS209['v'], Vis = uvtable_AS209['vis'], Weights = uvtable_AS209['weights'],
#       5               kernel_params = params_AS209, rtol = 1e-8 )
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/frank2d.py:332, in Frank2D.fit(self, u, v, Vis, Weights, type_kernel, kernel_params, method, x0, maxiter, rtol, hermitian)
#     329 if not self._set_fit_method:
#     330     self.set_fit_method(method, x0, maxiter, rtol)
# --> 332 self._solver.run()
#     333 self._sol_visibility_weighted = self._solver.sol
#     334 self._sol_visibility = self.build_full_visibility_model()
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/fitting.py:486, in IterativeSolverMethod.run(self)
#     484 print("Solving linear system...")
#     485 if self._x0 is None:
# --> 486     x, info = solver(self._A, self._b, M = self._A_precond, rtol = self._rtol, maxiter = self._maxiter)
#     487 else:
#     488     x, info = solver(self._A, self._b, M = self._A_precond, x0 = self._x0, rtol = self._rtol, maxiter = self._maxiter)
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/fitting.py:357, in IterativeSolverMethod.bicgstab(self, A, b, x0, rtol, atol, maxiter, M, callback)
#     354     return x, 0
#     356 shat = psolve(s)
# --> 357 t = matvec(shat)
#     358 omega = dotprod(t, s) / dotprod(t, t)
#     359 x += alpha*phat
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:258, in LinearOperator.matvec(self, x)
#     255 if x.shape != (N,) and x.shape != (N,1):
#     256     raise ValueError('dimension mismatch')
# --> 258 y = self._matvec(x)
#     260 if isinstance(x, np.matrix):
#     261     y = asmatrix(y)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:616, in _CustomLinearOperator._matvec(self, x)
#     615 def _matvec(self, x):
# --> 616     return self.__matvec_impl(x)
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/utilities.py:22, in linear_operator.<locals>.matvec(x)
#      21 def matvec(x):
# ---> 22     return matrix.dot(x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/_base.py:600, in _spbase.dot(self, other)
#     598     return self * other
#     599 else:
# --> 600     return self @ other
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/_base.py:908, in _spbase.__matmul__(self, other)
#     905 if isscalarlike(other):
#     906     raise ValueError("Scalar operands are not allowed, "
#     907                      "use '*' instead")
# --> 908 return self._matmul_dispatch(other)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/_base.py:793, in _spbase._matmul_dispatch(self, other)
#     790 if other.__class__ is np.ndarray:
#     791     # Fast path for the most common case
#     792     if other.shape == (N,):
# --> 793         return self._matmul_vector(other)
#     794     elif other.shape == (N, 1):
#     795         result = self._matmul_vector(other.ravel())
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/sparse/_compressed.py:395, in _cs_matrix._matmul_vector(self, other)
#     393 # csr_matvec or csc_matvec
#     394 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 395 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     397 return result[0] if self.ndim == 1 else result
#
# KeyboardInterrupt:

# %%
Plot_AS209 = Plot(f2d_AS209, geom_AS209)

# %%
Plot_AS209.visibility(fig_size = 4)

# %%
Plot_AS209.intensity(fig_size = 5, vmax = 4e10, gamma = 0.5)

# %%
Plot_AS209.visibility_profile(input = uvtable_AS209, weighted = True, frank1d = True)

# %%
Plot_AS209.intensity_profile(clean = True, fits_file = fits_1mm_AS209)

# %% [markdown]
# # Elias27

# %%
f2d_Elias27, geom_Elias27, uvtable_Elias27, fits_1mm_Elias27 = f2d(Elias27)

# %%
start_time = time.time()

params_Elias27 =  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_Elias27.fit(kernel_params = params_Elias27, rtol = 1e-6 )

end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")

# %%
Plot_Elias27 = Plot(f2d_Elias27, geom_Elias27)

# %%
Plot_Elias27.visibility(fig_size = 4)

# %%
Plot_Elias27.intensity(fig_size = 7, vmax = 4e10, gamma = 0.75)

# %% [markdown]
# # Elias24

# %%
f2d_Elias24, geom_Elias24, uvtable_Elias24, fits_1mm_Elias24 = f2d(Elias24)

# %%
start_time = time.time()

params_Elias24 =  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_Elias24.fit(u = uvtable_Elias24['u'], v = uvtable_Elias24['v'], Vis = uvtable_Elias24['vis'], Weights = uvtable_Elias24['weights'], 
                kernel_params = params_Elias24, rtol = 1e-8)

end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")

# %%
Plot_Elias24 = Plot(f2d_Elias24, geom_Elias24)

# %%
Plot_Elias24.visibility(fig_size = 4)

# %%
Plot_Elias24.intensity(fig_size = 5, vmax = 4e10, gamma = 0.75)

# %% [markdown]
# # IMLup

# %%
f2d_IMLup, geom_IMLup, uvtable_IMLup, fits_1mm_IMLup = f2d(IMLup)

# %%
start_time = time.time()

params_IMLup =  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_IMLup.fit(kernel_params = params_IMLup, rtol = 1e-7 )

end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")

# %%
Plot_IMLup = Plot(f2d_IMLup, geom_IMLup)

# %%
Plot_IMLup.visibility(fig_size = 4)

# %%
Plot_IMLup.intensity(fig_size = 4, vmax = 4e10, gamma = 0.75)

# %% [markdown]
# # HD143006

# %%
f2d_HD143006, geom_HD143006, uvtable_HD143006, fits_1mm_HD143006= f2d(HD143006)

# %%
start_time = time.time()

params_HD143006 =  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_HD143006.fit(kernel_params = params_HD143006, rtol = 1e-8 )

end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")

# %%
Plot_HD143006 = Plot(f2d_HD143006, geom_HD143006)

# %%
Plot_HD143006.visibility(fig_size = 4)

# %%
Plot_HD143006.intensity(fig_size = 4, vmax = 4e10, gamma = 0.75)

# %% [markdown]
# # HD163296

# %%
f2d_HD163296, geom_HD163296, uvtable_HD163296, fits_1mm_HD163296 = f2d(HD163296)

# %%
start_time = time.time()

params_HD163296=  {'m': -2, 'c': 1e8, 'l': 7e4}
f2d_HD163296.fit(kernel_params = params_HD163296, rtol = 1e-8 )

end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes | {(end_time - start_time):.2f} seconds.")

# %%
Plot_HD163296 = Plot(f2d_HD163296, geom_HD163296)

# %%
Plot_HD163296.visibility(fig_size = 4)

# %%
Plot_HD163296.intensity(fig_size = 4, vmax = 4e10, gamma = 0.75)
