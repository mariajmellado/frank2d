# %%
# Use Frank2D_PROD to run the simulated version of Frank2D in Frank1D.

# %%
import numpy as np 
import matplotlib.pyplot as plt

from frank.geometry import SourceGeometry
from frank.io import load_uvtable
from frank.radial_fitters import FrankFitter, FourierBesselFitter
from frank.utilities import UVDataBinner
from frank.constants import deg_to_rad

# %%
import pymoo

# %%
rad_to_arcsec = 3600 * 180 / np.pi

AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}
HD143006 = {'inc':18.6, 'pa':169 , 'dra':-5.9e-3, 'ddec':21.7e-3, 'rout':0.518*2, 'disk_name': 'HD143006'}

data = Elias27

dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum_gridded_N200.txt"


# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
r_out = data['rout']

# Frank Parameters
N = 50
 # load data
u, v, Re, Im, Weights = np.loadtxt(data_file, unpack = True)
Vis = Re + Im*1j

geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)

# %%
import time
start_time = time.time()
FF = FourierBesselFitter(r_out, N, geom)
sol = FF.fit(u, v, Vis, Weights)
total_time = time.time() - start_time
print("--- %s minutes ---", total_time/60, " or ", total_time, " seconds.")
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/statistical_models.py:278: RuntimeWarning: divide by zero encountered in log
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/statistical_models.py:278: RuntimeWarning: invalid value encountered in scalar multiply
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# ....................................OPTIMIZING..................................
# Minimizing
#
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
#
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 100000000.0 5
# Wendland kernel
# --- 0.02758774906396866 minutes to calculate S---
# --- 0.09130493551492691 minutes to calculate S_real---
#        --- 0.02777453511953354 calculate S_real_inv ---
#        --- 0.03240455314517021 calculate D ---
# --- 0.011498168110847473 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.023867879062891006 mu ---
#        --- 0.007599417120218277 determinant of S ---
#        --- 0.0059739649295806885 determinant of D ---
#         --- 9.685754776000977e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.6866e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.1377e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9616e+07
#  ----------------------------------------> - Log likelihood:  -2.4802e-01
# =================================================
# n_gen  |  n_eval  |     f_avg     |     f_min
# =================================================
#      1 |        1 | -2.480171E-01 | -2.480171E-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 1954533693.6443727 5
# Wendland kernel
# --- 0.03394066542387009 minutes to calculate S---
# --- 0.10064433142542839 minutes to calculate S_real---
#        --- 0.030484966933727264 calculate S_real_inv ---
#        --- 0.022440850734710693 calculate D ---
# --- 0.01449393481016159 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.026163768023252487 mu ---
#        --- 0.01310662180185318 determinant of S ---
#        --- 0.007858045399188995 determinant of D ---
#         --- 1.6763806343078613e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.5784e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.8809e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4795e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.998051248175459 565942610.5319353 5
# Wendland kernel
# --- 0.034971848130226135 minutes to calculate S---
# --- 0.1440538465976715 minutes to calculate S_real---
#        --- 0.029592249542474747 calculate S_real_inv ---
#        --- 0.09473172947764397 calculate D ---
# --- 0.024539336562156677 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.0457361675798893 mu ---
#        --- 0.01333320140838623 determinant of S ---
#        --- 0.009007696062326431 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.2136e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.5774e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9611e+07
#  ----------------------------------------> - Log likelihood:  -2.4797e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 37205069.525021866 5
# Wendland kernel
# --- 0.0414985828101635 minutes to calculate S---
# --- 0.13194067776203156 minutes to calculate S_real---
#        --- 0.03173790127038956 calculate S_real_inv ---
#        --- 0.035313330590724945 calculate D ---
# --- 0.019245777279138565 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.032557498663663864 mu ---
#        --- 0.008715566247701645 determinant of S ---
#        --- 0.01234491541981697 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3900e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8905e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9627e+07
#  ----------------------------------------> - Log likelihood:  -2.4808e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.8751874906235197 100000000.0 5
# Wendland kernel
# --- 0.05546463280916214 minutes to calculate S---
# --- 0.11156879737973213 minutes to calculate S_real---
#        --- 0.04104938358068466 calculate S_real_inv ---
#        --- 0.021273832768201828 calculate D ---
# --- 0.012896154075860977 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02243168279528618 mu ---
#        --- 0.009074483066797256 determinant of S ---
#        --- 0.007448367774486542 determinant of D ---
#         --- 9.685754776000977e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.1360e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.5456e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9611e+07
#  ----------------------------------------> - Log likelihood:  -2.4797e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9626625970619842 9667721120.489613 5
# Wendland kernel
# --- 0.02520473301410675 minutes to calculate S---
# --- 0.06915866583585739 minutes to calculate S_real---
#        --- 0.019010916352272034 calculate S_real_inv ---
#        --- 0.014979429543018341 calculate D ---
# --- 0.01052253320813179 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.017457783222198486 mu ---
#        --- 0.004872586578130722 determinant of S ---
#        --- 0.0047233328223228455 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0192e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0403e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4792e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9284503948863128 1132288423.6910663 5
# Wendland kernel
# --- 0.02020077034831047 minutes to calculate S---
# --- 0.0673309825360775 minutes to calculate S_real---
#        --- 0.014995750039815903 calculate S_real_inv ---
#        --- 0.013096664100885391 calculate D ---
# --- 0.008732113987207413 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015351317822933197 mu ---
#        --- 0.0046028681099414825 determinant of S ---
#        --- 0.004913918673992157 determinant of D ---
#         --- 1.1548399925231934e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.6723e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.9782e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4794e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 8560048007.429578 5
# Wendland kernel
# --- 0.020708397030830383 minutes to calculate S---
# --- 0.061010535806417465 minutes to calculate S_real---
#        --- 0.01695435121655464 calculate S_real_inv ---
#        --- 0.014356836676597595 calculate D ---
# --- 0.010565266013145447 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.023633617907762527 mu ---
#        --- 0.010013550519943237 determinant of S ---
#        --- 0.006846051663160324 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0021e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0250e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4793e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 62431684.172265224 5
# Wendland kernel
# --- 0.021198496222496033 minutes to calculate S---
# --- 0.05765806511044502 minutes to calculate S_real---
#        --- 0.01671905815601349 calculate S_real_inv ---
#        --- 0.013834204524755478 calculate D ---
# --- 0.014682549983263016 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02965964749455452 mu ---
#        --- 0.006831184029579163 determinant of S ---
#        --- 0.005011864006519318 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.5453e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.0199e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9620e+07
#  ----------------------------------------> - Log likelihood:  -2.4804e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 2984849242.1444693 5
# Wendland kernel
# --- 0.02145671471953392 minutes to calculate S---
# --- 0.06195186451077461 minutes to calculate S_real---
#        --- 0.014416951686143875 calculate S_real_inv ---
#        --- 0.012548532336950302 calculate D ---
# --- 0.008420798927545547 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01476367935538292 mu ---
#        --- 0.004163917154073715 determinant of S ---
#        --- 0.003836054354906082 determinant of D ---
#         --- 8.568167686462402e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.7054e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.9868e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4794e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.984795714158961 6945403815.308541 5
# Wendland kernel
# --- 0.01756148412823677 minutes to calculate S---
# --- 0.06766709685325623 minutes to calculate S_real---
#        --- 0.01688539609313011 calculate S_real_inv ---
#        --- 0.015444964170455933 calculate D ---
# --- 0.011765565723180771 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.018436219543218613 mu ---
#        --- 0.004269029945135117 determinant of S ---
#        --- 0.005987480282783508 determinant of D ---
#         --- 7.078051567077637e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0014e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0248e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4793e-01
#      2 |       11 | -2.479782E-01 | -2.480832E-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 18173157.68809569 5
# Wendland kernel
# --- 0.0201508030295372 minutes to calculate S---
# --- 0.0700579322874546 minutes to calculate S_real---
#        --- 0.021886199712753296 calculate S_real_inv ---
#        --- 0.019657135009765625 calculate D ---
# --- 0.013491284102201462 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.020829420536756516 mu ---
#        --- 0.005587749183177948 determinant of S ---
#        --- 0.005704469978809357 determinant of D ---
#         --- 1.1548399925231934e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.1750e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.7114e+04
#                                           * logdetD :  7.8998e+04
#                                           * jTDj :  4.9645e+07
#  ----------------------------------------> - Log likelihood:  -2.4818e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.7728833038507725 1132288423.6910663 5
# Wendland kernel
# --- 0.021627452224493027 minutes to calculate S---
# --- 0.07790498435497284 minutes to calculate S_real---
#        --- 0.02662508562207222 calculate S_real_inv ---
#        --- 0.018398664891719818 calculate D ---
# --- 0.011259917169809341 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.019197169691324234 mu ---
#        --- 0.005682762712240219 determinant of S ---
#        --- 0.005239430814981461 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0232e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0487e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4792e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 30261510.89766703 5
# Wendland kernel
# --- 0.02039586380124092 minutes to calculate S---
# --- 0.058341965079307556 minutes to calculate S_real---
#        --- 0.01976592093706131 calculate S_real_inv ---
#        --- 0.013403184711933136 calculate D ---
# --- 0.008850958198308945 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015062134712934494 mu ---
#        --- 0.004077348858118057 determinant of S ---
#        --- 0.003930412232875824 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3280e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8389e+04
#                                           * logdetD :  7.8993e+04
#                                           * jTDj :  4.9631e+07
#  ----------------------------------------> - Log likelihood:  -2.4811e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9995536664269125 1175213585.5665202 5
# Wendland kernel
# --- 0.01675286516547203 minutes to calculate S---
# --- 0.04323437809944153 minutes to calculate S_real---
#        --- 0.012323785573244095 calculate S_real_inv ---
#        --- 0.01072704792022705 calculate D ---
# --- 0.007460884749889374 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.012605533003807068 mu ---
#        --- 0.0036437474191188812 determinant of S ---
#        --- 0.0034183338284492493 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.4274e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.7552e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4796e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.855292450693934 3565849996.2801104 5
# Wendland kernel
# --- 0.015520952641963959 minutes to calculate S---
# --- 0.04197634756565094 minutes to calculate S_real---
#        --- 0.012321282178163528 calculate S_real_inv ---
#        --- 0.010671686381101608 calculate D ---
# --- 0.007653016597032547 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.012882687151432037 mu ---
#        --- 0.003576081246137619 determinant of S ---
#        --- 0.003561168909072876 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0280e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0504e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4792e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 4815670739.67744 5
# Wendland kernel
# --- 0.016578782349824905 minutes to calculate S---
# --- 0.04857354611158371 minutes to calculate S_real---
#        --- 0.014537021517753601 calculate S_real_inv ---
#        --- 0.012665215879678726 calculate D ---
# --- 0.008706498891115189 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015580065548419952 mu ---
#        --- 0.004296429455280304 determinant of S ---
#        --- 0.0038159340620040894 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.8489e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0106e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4794e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9985592165726027 565942610.5319353 5
# Wendland kernel
# --- 0.018053967505693436 minutes to calculate S---
# --- 0.05639813095331192 minutes to calculate S_real---
#        --- 0.01653381809592247 calculate S_real_inv ---
#        --- 0.01363450288772583 calculate D ---
# --- 0.012383852154016495 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.019210364669561386 mu ---
#        --- 0.004634920507669449 determinant of S ---
#        --- 0.004298854619264603 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.2118e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.5758e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9611e+07
#  ----------------------------------------> - Log likelihood:  -2.4797e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 1490272763.794081 5
# Wendland kernel
# --- 0.01900222897529602 minutes to calculate S---
# --- 0.04906122013926506 minutes to calculate S_real---
#        --- 0.01365095004439354 calculate S_real_inv ---
#        --- 0.012093596160411835 calculate D ---
# --- 0.008360099047422409 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01430080458521843 mu ---
#        --- 0.003921516239643097 determinant of S ---
#        --- 0.0037827491760253906 determinant of D ---
#         --- 6.332993507385254e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.4971e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.8131e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4795e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9114317965280283 62878885.60507095 5
# Wendland kernel
# --- 0.016739100217819214 minutes to calculate S---
# --- 0.04314693436026573 minutes to calculate S_real---
#        --- 0.012321867048740387 calculate S_real_inv ---
#        --- 0.01062823086977005 calculate D ---
# --- 0.007597636431455612 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.013570133596658707 mu ---
#        --- 0.0040000975131988525 determinant of S ---
#        --- 0.0035778507590293884 determinant of D ---
#         --- 8.568167686462402e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.8663e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.3111e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9613e+07
#  ----------------------------------------> - Log likelihood:  -2.4799e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 61333770.09015638 5
# Wendland kernel
# --- 0.01565394550561905 minutes to calculate S---
# --- 0.04711408540606499 minutes to calculate S_real---
#        --- 0.012859616428613663 calculate S_real_inv ---
#        --- 0.01165815070271492 calculate D ---
# --- 0.008185435086488724 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014415368437767029 mu ---
#        --- 0.0039771199226379395 determinant of S ---
#        --- 0.0034394972026348114 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.5399e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.0155e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9620e+07
#  ----------------------------------------> - Log likelihood:  -2.4804e-01
#      3 |       21 | -2.480377E-01 | -2.481844E-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 30061082.83824069 5
# Wendland kernel
# --- 0.015881039202213287 minutes to calculate S---
# --- 0.050219934433698654 minutes to calculate S_real---
#        --- 0.014160003513097763 calculate S_real_inv ---
#        --- 0.011827077716588974 calculate D ---
# --- 0.008703265339136124 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01475038006901741 mu ---
#        --- 0.004094265401363373 determinant of S ---
#        --- 0.0038629546761512756 determinant of D ---
#         --- 9.685754776000977e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3260e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8372e+04
#                                           * logdetD :  7.8993e+04
#                                           * jTDj :  4.9631e+07
#  ----------------------------------------> - Log likelihood:  -2.4811e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 38419349.784412205 5
# Wendland kernel
# --- 0.017440717667341232 minutes to calculate S---
# --- 0.04922102019190788 minutes to calculate S_real---
#        --- 0.014744453132152557 calculate S_real_inv ---
#        --- 0.01200065016746521 calculate D ---
# --- 0.008311782032251358 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014355264604091644 mu ---
#        --- 0.004145320504903793 determinant of S ---
#        --- 0.004154004156589508 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3996e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8986e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9626e+07
#  ----------------------------------------> - Log likelihood:  -2.4808e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.935231990719776 62878885.60507095 5
# Wendland kernel
# --- 0.017150968313217163 minutes to calculate S---
# --- 0.052442196756601334 minutes to calculate S_real---
#        --- 0.015093263238668442 calculate S_real_inv ---
#        --- 0.01321851834654808 calculate D ---
# --- 0.008586745709180832 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.017243213951587677 mu ---
#        --- 0.004424881190061569 determinant of S ---
#        --- 0.003675997257232666 determinant of D ---
#         --- 8.568167686462402e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.7806e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.2334e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9614e+07
#  ----------------------------------------> - Log likelihood:  -2.4800e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 29373245.630782776 5
# Wendland kernel
# --- 0.018974032253026962 minutes to calculate S---
# --- 0.0617331825196743 minutes to calculate S_real---
#        --- 0.017807401716709137 calculate S_real_inv ---
#        --- 0.016639046370983124 calculate D ---
# --- 0.009544268250465393 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01758066564798355 mu ---
#        --- 0.004026181995868683 determinant of S ---
#        --- 0.0037099458277225494 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3191e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8315e+04
#                                           * logdetD :  7.8993e+04
#                                           * jTDj :  4.9631e+07
#  ----------------------------------------> - Log likelihood:  -2.4811e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 27746252.38726913 5
# Wendland kernel
# --- 0.01737048104405403 minutes to calculate S---
# --- 0.053711898624897 minutes to calculate S_real---
#        --- 0.015214286744594574 calculate S_real_inv ---
#        --- 0.016736138612031937 calculate D ---
# --- 0.010484036058187485 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02173103392124176 mu ---
#        --- 0.006827466189861298 determinant of S ---
#        --- 0.005261916667222977 determinant of D ---
#         --- 1.043081283569336e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3020e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8172e+04
#                                           * logdetD :  7.8993e+04
#                                           * jTDj :  4.9633e+07
#  ----------------------------------------> - Log likelihood:  -2.4812e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 62632112.26413497 5
# Wendland kernel
# --- 0.019442886114120483 minutes to calculate S---
# --- 0.0721898041665554 minutes to calculate S_real---
#        --- 0.015659600496292114 calculate S_real_inv ---
#        --- 0.014938712120056152 calculate D ---
# --- 0.00895078107714653 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.017031218856573105 mu ---
#        --- 0.006088081747293472 determinant of S ---
#        --- 0.006478670984506607 determinant of D ---
#         --- 1.066550612449646e-05 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.5462e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.0207e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9620e+07
#  ----------------------------------------> - Log likelihood:  -2.4804e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9459841251916488 100000000.0 5
# Wendland kernel
# --- 0.018890615552663803 minutes to calculate S---
# --- 0.05668678134679794 minutes to calculate S_real---
#        --- 0.015384536236524582 calculate S_real_inv ---
#        --- 0.01356106624007225 calculate D ---
# --- 0.00870378315448761 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01448468491435051 mu ---
#        --- 0.004288628697395325 determinant of S ---
#        --- 0.003908120095729828 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.8811e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.3142e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9613e+07
#  ----------------------------------------> - Log likelihood:  -2.4799e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9106142789754115 2566481.7670329567 5
# Wendland kernel
# --- 0.016924984753131866 minutes to calculate S---
# --- 0.0463380292057991 minutes to calculate S_real---
#        --- 0.012144222855567932 calculate S_real_inv ---
#        --- 0.01075911894440651 calculate D ---
# --- 0.0075084008276462555 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.012806098908185959 mu ---
#        --- 0.0036866366863250732 determinant of S ---
#        --- 0.003370780497789383 determinant of D ---
#         --- 8.568167686462402e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.9096e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.5142e+04
#                                           * logdetD :  7.9033e+04
#                                           * jTDj :  4.9688e+07
#  ----------------------------------------> - Log likelihood:  -2.4841e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 46142271.336606696 5
# Wendland kernel
# --- 0.015682734549045563 minutes to calculate S---
# --- 0.04303554445505142 minutes to calculate S_real---
#        --- 0.013020232319831848 calculate S_real_inv ---
#        --- 0.010968487709760666 calculate D ---
# --- 0.007652804255485535 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01375092938542366 mu ---
#        --- 0.0042186155915260315 determinant of S ---
#        --- 0.0043460652232170105 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.4546e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.9444e+04
#                                           * logdetD :  7.8991e+04
#                                           * jTDj :  4.9623e+07
#  ----------------------------------------> - Log likelihood:  -2.4806e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.8751874906235197 6541373.8496846035 5
# Wendland kernel
# --- 0.022589683532714844 minutes to calculate S---
# --- 0.058127015829086304 minutes to calculate S_real---
#        --- 0.018728267401456833 calculate S_real_inv ---
#        --- 0.017994049936532974 calculate D ---
# --- 0.013035368174314499 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.021993733942508698 mu ---
#        --- 0.0067103467881679535 determinant of S ---
#        --- 0.005365118384361267 determinant of D ---
#         --- 7.078051567077637e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3179e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8638e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9628e+07
#  ----------------------------------------> - Log likelihood:  -2.4809e-01
#      4 |       31 | -2.481344E-01 | -2.484064E-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.7989885594822186 2563113.699026864 5
# Wendland kernel
# --- 0.025477979332208633 minutes to calculate S---
# --- 0.11370348185300827 minutes to calculate S_real---
#        --- 0.03589901700615883 calculate S_real_inv ---
#        --- 0.04029138758778572 calculate D ---
# --- 0.021309632807970047 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.03360423445701599 mu ---
#        --- 0.00716443732380867 determinant of S ---
#        --- 0.007696066051721573 determinant of D ---
#         --- 8.940696716308594e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3112e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8786e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9626e+07
#  ----------------------------------------> - Log likelihood:  -2.4808e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 37645204.71579328 5
# Wendland kernel
# --- 0.034238334745168686 minutes to calculate S---
# --- 0.1095113530755043 minutes to calculate S_real---
#        --- 0.01546221598982811 calculate S_real_inv ---
#        --- 0.015854783356189728 calculate D ---
# --- 0.010598551481962204 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01936383545398712 mu ---
#        --- 0.006649397313594818 determinant of S ---
#        --- 0.005877397954463959 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3935e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8935e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9627e+07
#  ----------------------------------------> - Log likelihood:  -2.4808e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9070096414142244 18432491.002167903 5
# Wendland kernel
# --- 0.02036295086145401 minutes to calculate S---
# --- 0.06676611676812172 minutes to calculate S_real---
#        --- 0.023199167102575302 calculate S_real_inv ---
#        --- 0.02290249615907669 calculate D ---
# --- 0.014464814215898514 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02608976885676384 mu ---
#        --- 0.005746282637119293 determinant of S ---
#        --- 0.006605498492717743 determinant of D ---
#         --- 7.078051567077637e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.5141e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.0188e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9619e+07
#  ----------------------------------------> - Log likelihood:  -2.4804e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 7518843.478622738 5
# Wendland kernel
# --- 0.027190450578927994 minutes to calculate S---
# --- 0.07644699886441231 minutes to calculate S_real---
#        --- 0.022646069526672363 calculate S_real_inv ---
#        --- 0.019286200404167175 calculate D ---
# --- 0.013020381331443787 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02220776677131653 mu ---
#        --- 0.0068336352705955505 determinant of S ---
#        --- 0.005307652056217194 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.9103e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.4908e+04
#                                           * logdetD :  7.9044e+04
#                                           * jTDj :  4.9699e+07
#  ----------------------------------------> - Log likelihood:  -2.4846e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.991561428813041 239729.59840959217 5
# Wendland kernel
# --- 0.04254565015435219 minutes to calculate S---
# --- 0.06648734956979752 minutes to calculate S_real---
#        --- 0.018867183476686478 calculate S_real_inv ---
#        --- 0.01632198691368103 calculate D ---
# --- 0.009975634515285492 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01726098358631134 mu ---
#        --- 0.004559587687253952 determinant of S ---
#        --- 0.005098685622215271 determinant of D ---
#         --- 1.1920928955078125e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -6.9070e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  7.6569e+04
#                                           * logdetD :  7.6292e+04
#                                           * jTDj :  4.7891e+07
#  ----------------------------------------> - Log likelihood:  -2.3945e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 5400390.831939679 5
# Wendland kernel
# --- 0.022645436227321625 minutes to calculate S---
# --- 0.06131621450185776 minutes to calculate S_real---
#        --- 0.022815432399511337 calculate S_real_inv ---
#        --- 0.01636675000190735 calculate D ---
# --- 0.008597403764724731 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014592785388231277 mu ---
#        --- 0.0042451173067092896 determinant of S ---
#        --- 0.003937330096960068 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.8110e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.4080e+04
#                                           * logdetD :  7.9111e+04
#                                           * jTDj :  4.9743e+07
#  ----------------------------------------> - Log likelihood:  -2.4869e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9995660431981623 2149067340.862797 5
# Wendland kernel
# --- 0.01755252107977867 minutes to calculate S---
# --- 0.05379596725106239 minutes to calculate S_real---
#        --- 0.01395401731133461 calculate S_real_inv ---
#        --- 0.013109467923641205 calculate D ---
# --- 0.008519399911165237 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014494627714157104 mu ---
#        --- 0.0042162127792835236 determinant of S ---
#        --- 0.0037246346473693848 determinant of D ---
#         --- 8.940696716308594e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.6084e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.9060e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4795e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 27761902.685591616 5
# Wendland kernel
# --- 0.016997143626213074 minutes to calculate S---
# --- 0.04924813285470009 minutes to calculate S_real---
#        --- 0.013513900339603424 calculate S_real_inv ---
#        --- 0.015015780925750732 calculate D ---
# --- 0.012404397130012512 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.021262966096401215 mu ---
#        --- 0.00515451654791832 determinant of S ---
#        --- 0.003965113312005997 determinant of D ---
#         --- 1.043081283569336e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3021e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8173e+04
#                                           * logdetD :  7.8993e+04
#                                           * jTDj :  4.9633e+07
#  ----------------------------------------> - Log likelihood:  -2.4812e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9544290149078298 18167014.10871867 5
# Wendland kernel
# --- 0.01791664958000183 minutes to calculate S---
# --- 0.06817879900336266 minutes to calculate S_real---
#        --- 0.01525162160396576 calculate S_real_inv ---
#        --- 0.01355743408203125 calculate D ---
# --- 0.01045209914445877 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.017579350620508194 mu ---
#        --- 0.005251534283161163 determinant of S ---
#        --- 0.004856262356042862 determinant of D ---
#         --- 1.30385160446167e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3390e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8602e+04
#                                           * logdetD :  7.8992e+04
#                                           * jTDj :  4.9629e+07
#  ----------------------------------------> - Log likelihood:  -2.4809e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9693566761453773 27746252.38726913 5
# Wendland kernel
# --- 0.02384156733751297 minutes to calculate S---
# --- 0.05502066761255264 minutes to calculate S_real---
#        --- 0.01947818323969841 calculate S_real_inv ---
#        --- 0.012643538415431976 calculate D ---
# --- 0.009485200047492981 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015577849000692368 mu ---
#        --- 0.00430544838309288 determinant of S ---
#        --- 0.004144169390201569 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.4123e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.9173e+04
#                                           * logdetD :  7.8991e+04
#                                           * jTDj :  4.9625e+07
#  ----------------------------------------> - Log likelihood:  -2.4807e-01
#      5 |       41 | -2.482394E-01 | -2.486906E-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 3816698.438022179 5
# Wendland kernel
# --- 0.018213480710983276 minutes to calculate S---
# --- 0.055084582418203354 minutes to calculate S_real---
#        --- 0.013895347714424133 calculate S_real_inv ---
#        --- 0.012486230581998825 calculate D ---
# --- 0.008521795272827148 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014609500765800476 mu ---
#        --- 0.003949936479330063 determinant of S ---
#        --- 0.003550715744495392 determinant of D ---
#         --- 9.685754776000977e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.7069e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.3213e+04
#                                           * logdetD :  7.9238e+04
#                                           * jTDj :  4.9707e+07
#  ----------------------------------------> - Log likelihood:  -2.4851e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 27646459.118488546 5
# Wendland kernel
# --- 0.01805366948246956 minutes to calculate S---
# --- 0.06273693218827248 minutes to calculate S_real---
#        --- 0.014044363051652908 calculate S_real_inv ---
#        --- 0.012343782931566238 calculate D ---
# --- 0.008426718413829803 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015339519828557968 mu ---
#        --- 0.005494900047779083 determinant of S ---
#        --- 0.003848068416118622 determinant of D ---
#         --- 4.842877388000488e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -8.3009e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.8163e+04
#                                           * logdetD :  7.8993e+04
# ...
# Wendland kernel
# --- 0.01773810014128685 minutes to calculate S---
# --- 0.05147353559732437 minutes to calculate S_real---
#        --- 0.01512051746249199 calculate S_real_inv ---
#        --- 0.016987282782793045 calculate D ---
# --- 0.009563595056533813 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01930857077240944 mu ---
#        --- 0.005300834774971008 determinant of S ---
#        --- 0.004225179553031921 determinant of D ---
#         --- 1.0058283805847168e-07 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.3690e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.0438e+04
#                                           * logdetD :  7.9237e+04
#                                           * jTDj :  7.9945e+07
#  ----------------------------------------> - Log likelihood:  -3.9972e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.996968400954455 1166793.7906743826 5
# Wendland kernel
# --- 0.01824977993965149 minutes to calculate S---
# --- 0.05401076376438141 minutes to calculate S_real---
#        --- 0.014119070023298264 calculate S_real_inv ---
#        --- 0.01403621956706047 calculate D ---
# --- 0.008814148604869843 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014635652303695679 mu ---
#        --- 0.004104252904653549 determinant of S ---
#        --- 0.0037688836455345154 determinant of D ---
#         --- 6.332993507385254e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.3622e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.0349e+04
#                                           * logdetD :  7.9200e+04
#                                           * jTDj :  4.4035e+07
#  ----------------------------------------> - Log likelihood:  -2.2017e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9999315130918078 3084810.3185280496 5
# Wendland kernel
# --- 0.016818147152662277 minutes to calculate S---
# --- 0.045848745852708817 minutes to calculate S_real---
#        --- 0.012989386916160583 calculate S_real_inv ---
#        --- 0.011895298957824707 calculate D ---
# --- 0.007913116365671158 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.013003069907426834 mu ---
#        --- 0.003971114754676819 determinant of S ---
#        --- 0.0035693012177944183 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.6432e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.2683e+04
#                                           * logdetD :  7.9326e+04
#                                           * jTDj :  4.9714e+07
#  ----------------------------------------> - Log likelihood:  -2.4855e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 1504372.119544537 5
# Wendland kernel
# --- 0.016673747450113297 minutes to calculate S---
# --- 0.04651801660656929 minutes to calculate S_real---
#        --- 0.014420982450246811 calculate S_real_inv ---
#        --- 0.012812599539756775 calculate D ---
# --- 0.008905984461307526 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.014782078564167023 mu ---
#        --- 0.00433686375617981 determinant of S ---
#        --- 0.004125531762838364 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.4276e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.0885e+04
#                                           * logdetD :  7.9360e+04
#                                           * jTDj :  8.0107e+07
#  ----------------------------------------> - Log likelihood:  -4.0053e-01
#     10 |       91 | -3.026427E-01 | -4.005255E-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9562130791939376 8119331517.119822 5
# Wendland kernel
# --- 0.018228083848953247 minutes to calculate S---
# --- 0.05331510305404663 minutes to calculate S_real---
#        --- 0.015068404376506805 calculate S_real_inv ---
#        --- 0.013867463916540146 calculate D ---
# --- 0.009363748133182526 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.016179215162992477 mu ---
#        --- 0.00531427189707756 determinant of S ---
#        --- 0.004068750888109207 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -1.0163e+02
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  1.0380e+05
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4792e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.95718437091526 1182092633.1258419 5
# Wendland kernel
# --- 0.018360193818807602 minutes to calculate S---
# --- 0.05707896873354912 minutes to calculate S_real---
#        --- 0.01569788157939911 calculate S_real_inv ---
#        --- 0.013681299984455109 calculate D ---
# --- 0.009255897253751755 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015858396887779236 mu ---
#        --- 0.004686422646045685 determinant of S ---
#        --- 0.004354313015937805 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -9.5817e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  9.8951e+04
#                                           * logdetD :  7.8990e+04
#                                           * jTDj :  4.9610e+07
#  ----------------------------------------> - Log likelihood:  -2.4795e-01
# ......................................... Calculating likelihood with m, c, log(l):  -2.0 1504753.5236153437 5
# Wendland kernel
# --- 0.01789131388068199 minutes to calculate S---
# --- 0.046294935047626495 minutes to calculate S_real---
#        --- 0.01355881616473198 calculate S_real_inv ---
#        --- 0.011231798678636551 calculate D ---
# --- 0.008085288107395172 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.016814470291137695 mu ---
#        --- 0.004448212683200836 determinant of S ---
#        --- 0.0035862214863300323 determinant of D ---
#         --- 4.842877388000488e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.4276e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.0886e+04
#                                           * logdetD :  7.9360e+04
#                                           * jTDj :  7.9304e+07
#  ----------------------------------------> - Log likelihood:  -3.9651e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9996733029714262 817096.3249611305 5
# Wendland kernel
# --- 0.014810636639595032 minutes to calculate S---
# --- 0.04386693611741066 minutes to calculate S_real---
#        --- 0.012201886624097824 calculate S_real_inv ---
#        --- 0.011038020253181458 calculate D ---
# --- 0.010132521390914917 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015638314187526703 mu ---
#        --- 0.004013534635305405 determinant of S ---
#        --- 0.0036204643547534943 determinant of D ---
#         --- 5.21540641784668e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.2456e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  7.9370e+04
#                                           * logdetD :  7.8685e+04
#                                           * jTDj :  4.5079e+07
#  ----------------------------------------> - Log likelihood:  -2.2539e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.8925189406245937 1021909.8722270187 5
# Wendland kernel
# --- 0.016345199197530746 minutes to calculate S---
# --- 0.049308933317661285 minutes to calculate S_real---
#        --- 0.01545703038573265 calculate S_real_inv ---
#        --- 0.014131344854831696 calculate D ---
# --- 0.009974882006645203 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.01654493436217308 mu ---
#        --- 0.005353603512048721 determinant of S ---
#        --- 0.004779987037181854 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.6985e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.3431e+04
#                                           * logdetD :  7.9206e+04
#                                           * jTDj :  4.9676e+07
#  ----------------------------------------> - Log likelihood:  -2.4836e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.999819938733815 1444026.4257897367 5
# Wendland kernel
# --- 0.020435210317373276 minutes to calculate S---
# --- 0.05933399870991707 minutes to calculate S_real---
#        --- 0.015808865427970886 calculate S_real_inv ---
#        --- 0.01419481635093689 calculate D ---
# --- 0.010156366974115372 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.016836848109960556 mu ---
#        --- 0.004799313843250275 determinant of S ---
#        --- 0.004480235278606415 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.4159e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.0789e+04
#                                           * logdetD :  7.9338e+04
#                                           * jTDj :  4.5993e+07
#  ----------------------------------------> - Log likelihood:  -2.2996e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.99933633577666 805982.4892018089 5
# Wendland kernel
# --- 0.020252257585525513 minutes to calculate S---
# --- 0.05918613076210022 minutes to calculate S_real---
#        --- 0.015081048011779785 calculate S_real_inv ---
#        --- 0.013426613062620163 calculate D ---
# --- 0.009129650890827179 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.015192568302154541 mu ---
#        --- 0.00422518327832222 determinant of S ---
#        --- 0.003994211554527283 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.2427e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  7.9347e+04
#                                           * logdetD :  7.8665e+04
#                                           * jTDj :  5.7586e+07
#  ----------------------------------------> - Log likelihood:  -2.8792e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9807267071919612 1504372.119544537 5
# Wendland kernel
# --- 0.01676809787750244 minutes to calculate S---
# --- 0.04437531903386116 minutes to calculate S_real---
#        --- 0.012472186237573624 calculate S_real_inv ---
#        --- 0.011580199003219604 calculate D ---
# --- 0.008304417133331299 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.013493265956640244 mu ---
#        --- 0.003824930638074875 determinant of S ---
#        --- 0.003607451915740967 determinant of D ---
#         --- 6.705522537231445e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.4969e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.1515e+04
#                                           * logdetD :  7.9437e+04
#                                           * jTDj :  5.2565e+07
#  ----------------------------------------> - Log likelihood:  -2.6282e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.967395492459425 1166793.7906743826 5
# Wendland kernel
# --- 0.015813596546649933 minutes to calculate S---
# --- 0.043901100754737854 minutes to calculate S_real---
#        --- 0.011416580528020859 calculate S_real_inv ---
#        --- 0.011320352554321289 calculate D ---
# --- 0.007959634065628052 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.013486184179782867 mu ---
#        --- 0.0037620626389980316 determinant of S ---
#        --- 0.003759250044822693 determinant of D ---
#         --- 4.842877388000488e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.4687e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.1315e+04
#                                           * logdetD :  7.9434e+04
#                                           * jTDj :  -4.0987e+07
#  ----------------------------------------> - Log likelihood:  2.0495e-01
# ......................................... Calculating likelihood with m, c, log(l):  -1.9046828318771865 1029715.8233297173 5
# Wendland kernel
# --- 0.017277762293815613 minutes to calculate S---
# --- 0.05841648206114769 minutes to calculate S_real---
#        --- 0.018033336848020554 calculate S_real_inv ---
#        --- 0.020322062075138092 calculate D ---
# --- 0.01253703236579895 minutes calculate mu---
# Is the result correct?:  True
#        --- 0.02034733071923256 mu ---
#        --- 0.00731983408331871 determinant of S ---
#        --- 0.00818609818816185 determinant of D ---
#         --- 8.195638656616211e-08 minutes to calculate log_likelihood ---
#  -------------------------------------> Summary:
#                                           * prior 1 :  -7.6570e+01
#                                           * prior 2 :  0.0000e+00
#                                           * logdetS :  8.3052e+04
#                                           * logdetD :  7.9268e+04
#                                           * jTDj :  4.9553e+07
#  ----------------------------------------> - Log likelihood:  -2.4775e-01
#     11 |      101 | -3.215925E-01 | -4.005255E-01
# Mejor valor (f* = -log L*): -0.40052553112155026
# Mejor (m, c): [-2.00000000e+00  1.50437212e+06]
# --- 16.914520513266325 minutes to minimizing ---
# --- 0.011519018560647964 minutes calculate mu---
# Is the result correct?:  True
# --- 16.939042299985886 minutes to minimize S---
# ....................................OPTIMIZING..................................
#                  --------------> BEST PARAMETERS: m, c, log_l -2.0 1504372.119544537 5
# --- %s minutes --- 19.436700701713562  or  1166.2020421028137  seconds.

# %%
print("iterations: ", len(sol._fit._loglikelihoods))
# Out:
# iterations:  101

# %%
FF._sol._fit.plot_stats_optimization()

# %%
len(sol.mean) # we corroborate the desire output has 25x25 points.
# Out:
# 2500

# %%
FF._GaussianModel.plot_stats_optimization()

# %%
I = sol.mean.real

# %%
I_reshape = I.reshape(N, N)

# %%
r_out_rad = r_out

# %%
import matplotlib.colors as colors
x_f1d = FF._DFT.Xn*rad_to_arcsec
y_f1d = FF._DFT.Yn*rad_to_arcsec

fig, ax = plt.subplots(figsize=(5, 5))
norm = colors.PowerNorm(gamma=0.45)
plot = ax.pcolormesh(x_f1d.reshape(N, N), y_f1d.reshape(N, N), I_reshape, cmap="magma", norm=norm)
cmap = plt.colorbar(plot)
plt.gca().invert_xaxis()
cmap.set_label(r'I [Jy $sr^{-1}$]', size = 15)
ax.set_title(r'$N^{2}$ points, with N = ' + str(N))
ax.set_xlabel("x ['']")
ax.set_ylabel("y ['']")
plt.gca().set_aspect(1)  
plt.show()

# %%
u_f1d = FF._DFT.Un
v_f1d = FF._DFT.Vn

fig, ax = plt.subplots(figsize=(5, 5))
plot = ax.pcolormesh(np.fft.fftshift(u_f1d.reshape(N, N))/1e6,
                     np.fft.fftshift(v_f1d.reshape(N, N))/1e6,
                     np.log(np.fft.fftshift(np.abs(np.fft.ifft2(I_reshape)))), cmap="magma")
cmap = plt.colorbar(plot)
cmap.set_label(r'I [Jy $sr^{-1}$]', size = 15)
ax.set_title(r'$N^{2}$ points, with N = ' + str(N))
ax.set_xlabel(r'u [1e6 $\lambda$]')
ax.set_ylabel(r'v [1e6 $\lambda$]')
plt.gca().set_aspect(1)  
plt.show()

# %%
from scipy.stats import binned_statistic


def get_vis_profile_binned(u, v, Vis, Weights, n_bins = 300, weighted = False):
    q = np.hypot(u, v)
    
    Vis_binned, bin_edges, _ = binned_statistic(q, Vis, 'mean', bins = n_bins)
    q_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    if weighted:
        Vis_Weights_binned, bin_edges, _ = binned_statistic(q, Vis*Weights, 'sum', bins = n_bins)
        Weights_binned, bin_edges, _ = binned_statistic(q, Weights, 'sum', bins = n_bins)
        Vis_Weights_binned = np.nan_to_num(Vis_Weights_binned, nan=0)
        return q_centers, Vis_Weights_binned/Weights_binned

    return q_centers, Vis_binned

# %%
#  Plot variables.
cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths = [1e3, 1e5]
baselines = np.hypot(u, v)         
grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
                           np.log10(max(baselines.max(), baselines[-1])),
                           10**4)

plt.figure(figsize=(14,5))

# Raw visibilities -------------------------------------------------------------------
binned_vis = UVDataBinner(baselines, Vis, Weights, bin_widths[0])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[0],
             marker=ms[0], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))

#frank1d
n_bins = N
vis_fit_1d = sol.predict(u_f1d, v_f1d)
baselines_centers, vis_fit = get_vis_profile_binned(u_f1d, v_f1d, vis_fit_1d, Weights, n_bins = n_bins, weighted = False)
plt.plot(baselines_centers, np.abs(vis_fit), color = "blue", ls ='--', label = r'fit')

binned_vis = UVDataBinner(baselines, Vis, Weights, bin_widths[1])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[1],
             marker=ms[1], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[1]/1e3))


plt.xlabel(r'baseline [$\lambda$]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(0.5e-4, 1)
plt.xlim(1e5, 6e6)
plt.ylabel('|V| [Jy]', size = 10)
plt.title(r'$Visibility_{Model}$ of Frank2D simulated in Frank1D with N = ' + str(N))
plt.legend(fontsize= 10)
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_38245/14993359.py:5: RuntimeWarning: divide by zero encountered in log10
#   grid = np.logspace(np.log10(min(baselines.min(), baselines[0])),
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/Frank2D_PROD/lib/python3.12/site-packages/numpy/_core/function_base.py:168: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/Frank2D_PROD/lib/python3.12/site-packages/numpy/_core/function_base.py:178: RuntimeWarning: invalid value encountered in add
#   y += start
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:224: RuntimeWarning: invalid value encountered in divide
#   bin_uv[idx] /= w
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:225: RuntimeWarning: invalid value encountered in divide
#   bin_vis[idx] /= w
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:250: RuntimeWarning: invalid value encountered in divide
#   err[idx2] /= bin_wgt[idx2]**2 * (1 - 1 / bin_n[idx2])

# %% [markdown]
# ## Review the deprojected case

# %%
# deproject
inc_rad = inc*deg_to_rad
pa_rad = pa*deg_to_rad

cos_t = np.cos(pa_rad)
sin_t = np.sin(pa_rad)

u_ = u * cos_t - v * sin_t
v_d = u * sin_t + v * cos_t
u_d = u_ * np.cos(inc_rad)

# %%
#  Plot variables.
cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths = [1e3, 1e5]
baselines_d = np.hypot(u_d, v_d)         
grid = np.logspace(np.log10(min(baselines_d.min(), baselines_d[0])),
                           np.log10(max(baselines_d.max(), baselines_d[-1])),
                           10**4)

plt.figure(figsize=(14,5))

# Raw visibilities -------------------------------------------------------------------
binned_vis = UVDataBinner(baselines_d, Vis, Weights, bin_widths[0])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[0],
             marker=ms[0], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))

binned_vis = UVDataBinner(baselines_d, Vis, Weights, bin_widths[1])
plt.plot(binned_vis.uv, np.abs(binned_vis.V), c=cs[1],
             marker=ms[1], ls='None', 
             label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[1]/1e3))
#frank1d
n_bins = 400
vis_fit_1d_d = sol.predict_deprojected(u_d, v_d)

baselines_centers_d, vis_fit_d = get_vis_profile_binned(u, v, vis_fit_d_shift, Weights, n_bins = n_bins)
plt.plot(baselines_centers_d, np.abs(vis_fit_d)/np.cos(inc_rad), color = "blue", ls ='--', label = r'frank1d')


plt.xlabel(r'baseline [$\lambda$]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(0.5e-4, 1)
plt.xlim(1e5, 6e6)
plt.ylabel('|V| [Jy]', size = 10)
plt.title(r'$Visibility_{Models}$ deprojected with ' + str(n_bins) + ' regular bins, Frank2D N = ' + str(N))
plt.legend(fontsize= 10)
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_38245/533191436.py:5: RuntimeWarning: divide by zero encountered in log10
#   grid = np.logspace(np.log10(min(baselines_d.min(), baselines_d[0])),
# /Users/mariajmelladot/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/utilities.py:259: RuntimeWarning: divide by zero encountered in divide
#   bin_vis_err[idx1].real = 1 / np.sqrt(bin_wgt[idx1])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 23
#      21 #frank1d
#      22 n_bins = 400
# ---> 23 vis_fit_1d_d = sol.predict_deprojected(u_d, v_d)
#      25 baselines_centers_d, vis_fit_d = get_vis_profile_binned(u, v, vis_fit_d_shift, Weights, n_bins = n_bins)
#      26 plt.plot(baselines_centers_d, np.abs(vis_fit_d)/np.cos(inc_rad), color = "blue", ls ='--', label = r'frank1d')
#
# File ~/Desktop/Frank2D/2_Frank2D_PROD/frankenstein2D/frank/radial_fitters.py:143, in FrankRadialFit.predict_deprojected(self, u, v, q, I, geometry, block_size, assume_optically_thick)
#     140 if I is None:
#     141     I = self.I
# --> 143 V = self._vis_map.predict_visibilities(I, q, u, v, q*0, geometry=geometry)
#     145 return V
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
