# %%
import os
import sys

# import the frank2d directory
current_dir =  os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

from frank2d import *
from optimization import *
from frank.utilities import UVDataBinner

# %%
rad_to_arcsec = 3600 * 180 / np.pi

AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}
HD143006 = {'inc':18.6, 'pa':169 , 'dra':-5.9e-3, 'ddec':21.7e-3, 'rout':0.518*2, 'disk_name': 'HD143006'}

data = HD143006

dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum_gridded_N200.txt"


# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
r_out = data['rout']

# Frank Parameters
N = 50
 # load data
u, v, Re, Im, Weights = np.loadtxt(data_file, unpack = True)
Vis = Re + Im*1j

geom = Geometry(inc= inc, pa= pa, dra= dra, ddec= ddec)

# %%
Weights
# Out:
# array([1.042516e+09, 1.484949e+09, 1.046247e+09, ..., 5.908208e+08,
#        8.730373e+08, 1.093258e+09])

# %%
# error 
plt.figure(figsize=(4, 2))
plt.plot(np.hypot(u, v), Weights**(-1), ls = '--')
plt.xlabel("baseline")
plt.ylabel(r'$\sigma^{2}$ = $\frac{1}{w}$')
plt.title("N matrix")
plt.show()

# weights 
plt.figure(figsize=(4, 2))
plt.plot(np.hypot(u, v), Weights, ls = '--')
plt.xlabel("baseline")
plt.ylabel(r'Weights')
plt.title(r'$N^{-1}$ matrix')
plt.show()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_61072/1189423384.py:3: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.plot(np.hypot(u, v), Weights**(-1), ls = '--')

# %%
import time
start_time = time.time()
FF = FourierBesselFitter(r_out, N, geom)
sol = FF.fit(u, v, Vis, Weights)
total_time = time.time() - start_time
print("--- %s minutes ---", total_time/60, " or ", total_time, " seconds.")
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/optimization.py:381: RuntimeWarning: divide by zero encountered in log
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/optimization.py:381: RuntimeWarning: invalid value encountered in scalar multiply
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# Minimum frequency in the data: 99548.65166365655
# Maximum frequency in the data: 3519576.3324674517
# --- %s minutes --- 0.6604099829991659  or  39.62459897994995  seconds.

# %%
GM = FF._GaussianModel

# %%
GM.optimize_posterior()
# Out:
# ....................................OPTIMIZING..................................
#                  --------------> Initial parameters: m, c, log_l: -2 8 5
#                  --------------> Bounds for m, log_c: (-4.1, -0.1) (1, 20)
#
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
#
# ......................................... Calculating likelihood with m, c, log(l):  -2.537026585767724 1084411463.640372 5
# --- 7.268124103546143 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -4.074589167175281 506274854954.5742 5
# --- 7.051239967346191 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.86131222957229 2.979585153458815e+17 5
# --- 3.6597611904144287 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -3.8384553129035703 1.7509112413050847e+18 5
# --- 7.725940942764282 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1499336017718371 15312506.446297038 5
# --- 3.7844810485839844 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.7442418883639208 45889718.3711617 5
# --- 3.8062641620635986 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -3.6888118679373223 57882.13331730251 5
# --- 7.231106996536255 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.0411150345031377 935.4360406143662 5
# --- 7.138412952423096 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.5361150690254668 229.32533202955153 5
# --- 4.075419902801514 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.2830976595176082 185247058376416.2 5
# --- 5.286417007446289 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -3.2394840534493676 5.218172635567056e+19 5
# --- 5.915868043899536 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.484879239075306 67219.40548725496 5
# --- 8.161773920059204 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -3.088853297822687 7934078519985.679 5
# --- 7.291198015213013 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4724085301978627 2.2267838936588188e+16 5
# --- 3.8429653644561768 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -3.363820094648651 5158581538.515454 5
# --- 8.103897094726562 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5074015269430987 24.184862101126797 5
# --- 7.7444329261779785 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.7460017674575408 1.2174789428130788e+16 5
# --- 3.6463778018951416 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.915390640325842 61450534239.71807 5
# --- 3.771582841873169 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.3679749927536129 364310398143823.56 5
# --- 3.9857139587402344 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.11307126815978874 2514630.501422385 5
# --- 4.115545272827148 seconds to calculate log_likelihood ---
# ==================================================================================================
# n_gen  |  n_eval  |     f_avg     |     f_min     |     sigma     | min_std  | max_std  |   axis
# ==================================================================================================
#      1 |       20 | -7.991856E+06 | -1.098775E+07 |  0.5000000000 |  0.50000 |  0.50001 |  1.00003
# ......................................... Calculating likelihood with m, c, log(l):  -0.5139732209206334 10.068689422019093 5
# --- 3.959771156311035 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.2638556488483461 5325995768804767.0 5
# --- 3.700944185256958 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.9757082763897706 18.716968509906646 5
# --- 7.784898996353149 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0510241040716841 353238191.0626176 5
# --- 3.9750521183013916 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.4463502988130026 2580505.153788147 5
# --- 7.5656421184539795 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.434236912568023 1850.4945655827005 5
# --- 7.599083185195923 seconds to calculate log_likelihood ---
#      2 |       26 | -7.155768E+06 | -1.098775E+07 |  0.3985998102 |  0.35630 |  0.35918 |  1.27675
# ......................................... Calculating likelihood with m, c, log(l):  -0.10704891720133869 2863849.9924544943 5
# --- 3.9612748622894287 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.14386117941918775 1351354790.7857728 5
# --- 4.152354001998901 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.056671154666002 50977193327.8787 5
# --- 4.1634509563446045 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.27549574382144293 21.635215463943887 5
# --- 4.1380369663238525 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.587970321114925 622.7926109985787 5
# --- 7.565022945404053 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.15701431879633443 1392.607705638608 5
# --- 3.860722064971924 seconds to calculate log_likelihood ---
#      3 |       32 | -8.907422E+06 | -1.098775E+07 |  0.4636155112 |  0.39148 |  0.51102 |  1.79404
# ......................................... Calculating likelihood with m, c, log(l):  -0.14641170311197538 13249.16538179271 5
# --- 4.13207483291626 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.11220698936081863 464255990.55918294 5
# --- 3.97236704826355 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.7908689373049875 178.03391665687332 5
# --- 4.086468935012817 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.7776184812369396 58247126546504.695 5
# --- 3.8759989738464355 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.9105970061430955 96514.54196843281 5
# --- 7.805003881454468 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.7011646507873501 14614192285.388334 5
# --- 3.9507269859313965 seconds to calculate log_likelihood ---
#      4 |       38 | -1.071898E+07 | -1.098775E+07 |  0.4404618083 |  0.32634 |  0.52355 |  2.34816
# ......................................... Calculating likelihood with m, c, log(l):  -4.0974886272723605 1018362108.9672189 5
# --- 7.653166055679321 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.4629222253793217 25376647.69909189 5
# --- 3.670992851257324 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.10093631760263522 29.979768970049612 5
# --- 3.8142411708831787 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9838943752436653 10.00407294020464 5
# --- 4.021960735321045 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.4061809100899083 6430.924233088048 5
# --- 8.02982497215271 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.062300502981571 57813116.606784254 5
# --- 3.7776198387145996 seconds to calculate log_likelihood ---
#      5 |       44 | -7.132545E+06 | -1.098775E+07 |  0.3537081197 |  0.24001 |  0.37364 |  2.44348
# ......................................... Calculating likelihood with m, c, log(l):  -2.8732906935815707 11879900.315401236 5
# --- 8.703582286834717 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.8637909599053386 127.772542030514 5
# --- 4.420076131820679 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.10011137832438388 24746.95805405119 5
# --- 4.383221864700317 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.678765783934177 12.687642518192858 5
# --- 4.500345230102539 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.110161310155561 40.681270766153176 5
# --- 4.3871989250183105 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.5285659294193894 667.1025784157817 5
# --- 4.396344184875488 seconds to calculate log_likelihood ---
#      6 |       50 | -8.915647E+06 | -1.098775E+07 |  0.3024237686 |  0.16696 |  0.28014 |  2.14722
# ......................................... Calculating likelihood with m, c, log(l):  -1.1527917560712928 24.856507149057272 5
# --- 8.818509101867676 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -2.3918762383745857 13.534442719249206 5
# --- 8.489187955856323 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.2589899304898968 23.97202750481845 5
# --- 4.622491121292114 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.10228313060024652 494.14088666843907 5
# --- 4.619550943374634 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4923142833433345 64.91480613995095 5
# --- 8.975997924804688 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.3365119335316935 525.2374700870206 5
# --- 4.360936880111694 seconds to calculate log_likelihood ---
#      7 |       56 | -8.761018E+06 | -1.098775E+07 |  0.2332439718 |  0.11789 |  0.18936 |  2.02959
# ......................................... Calculating likelihood with m, c, log(l):  -0.212229357274905 4496.483077961668 5
# --- 4.402746915817261 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.260354627315055 12545278.875768283 5
# --- 4.3995630741119385 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.6432003999133733 14.172454225712476 5
# --- 4.422086954116821 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.8973393180926652 50.32280387205001 5
# --- 8.55798888206482 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.2565768301412401 185.43020734489443 5
# --- 4.433106899261475 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.6025031226957425 104.6797923038318 5
# --- 4.406182289123535 seconds to calculate log_likelihood ---
#      8 |       62 | -8.898839E+06 | -1.098775E+07 |  0.1908930448 |  0.08828 |  0.13189 |  1.78412
# ......................................... Calculating likelihood with m, c, log(l):  -0.9475081105422674 13.699405884750918 5
# --- 4.379893064498901 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.34278357453604835 15.354966317959908 5
# --- 4.490305185317993 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.4000778946039989 28.686617711996746 5
# --- 4.498769998550415 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.1935633675379247 16.317694979360674 5
# --- 4.578541040420532 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.8457027581364529 13.971399929504708 5
# --- 5.0665130615234375 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3954518446428952 14.445920994803926 5
# --- 8.998750925064087 seconds to calculate log_likelihood ---
#      9 |       68 | -1.072393E+07 | -1.098775E+07 |  0.2118402008 |  0.09123 |  0.16431 |  2.13869
# ......................................... Calculating likelihood with m, c, log(l):  -1.0271611708557562 11.075887249768972 5
# --- 4.390393972396851 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3769874230392056 11.400821800303774 5
# --- 8.884071111679077 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.6319739223333687 33.27818046965291 5
# --- 8.549906015396118 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.7790346145570122 11.682365407415684 5
# --- 8.496968030929565 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9772913557117255 10.950550645923188 5
# --- 4.499497890472412 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9334465607391551 692.6415202782906 5
# --- 4.823825359344482 seconds to calculate log_likelihood ---
#     10 |       74 | -8.148406E+06 | -1.098775E+07 |  0.1635648908 |  0.06701 |  0.10649 |  2.03193
# ......................................... Calculating likelihood with m, c, log(l):  -1.0148780373163917 13.259961932550366 5
# --- 4.6353960037231445 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.179269682351014 37.743750159194235 5
# --- 4.742983341217041 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.146330288181868 45.865979642152794 5
# --- 4.471980094909668 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.8960446653984726 10.024952238875347 5
# --- 4.64788818359375 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4964173751906018 27.498562909719972 5
# --- 9.059657096862793 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.594905298695791 15.827074163454547 5
# --- 4.451618909835815 seconds to calculate log_likelihood ---
#     11 |       80 | -1.087015E+07 | -1.161948E+07 |  0.1643965139 |  0.06402 |  0.10465 |  1.97171
# ......................................... Calculating likelihood with m, c, log(l):  -1.683475720852567 85.12803673079182 5
# --- 8.68819808959961 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.8403091952268134 764.5962582658608 5
# --- 8.505002975463867 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.42605569280267863 11.663866183498131 5
# --- 4.328804969787598 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.6760518933692086 10.101209907075463 5
# --- 8.616823196411133 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5682671947539881 16.487928198150417 5
# --- 8.532158136367798 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4566985749910377 21.718793926254612 5
# --- 8.66287636756897 seconds to calculate log_likelihood ---
#     12 |       86 | -7.372220E+06 | -1.161948E+07 |  0.1610335912 |  0.06642 |  0.09567 |  1.76494
# ......................................... Calculating likelihood with m, c, log(l):  -1.1140308484319994 131.48153177785235 5
# --- 4.4395997524261475 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.7010325827108495 637.9859151624702 5
# --- 4.407151222229004 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3839957418419169 23.156607743150133 5
# --- 8.713063955307007 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5749645485011867 21.36017423542547 5
# --- 9.307211875915527 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.6858916996376592 34.00030795297335 5
# --- 4.423291921615601 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2714572874293766 276.3511969424177 5
# --- 4.36995005607605 seconds to calculate log_likelihood ---
#     13 |       92 | -1.039559E+07 | -1.161948E+07 |  0.2151252073 |  0.10808 |  0.11455 |  1.31161
# ......................................... Calculating likelihood with m, c, log(l):  -0.8129493595611677 1169.3922199294132 5
# --- 4.438280820846558 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.9924201030222437 115.42936057481167 5
# --- 8.509389162063599 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9400360524416 94.59725881807111 5
# --- 4.36264705657959 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9854733051923206 271.5906804000483 5
# --- 4.362323999404907 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2522121010316263 3820.704943971438 5
# --- 4.403063058853149 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3902094089880745 14.014641406960493 5
# --- 9.179131984710693 seconds to calculate log_likelihood ---
#     14 |       98 | -8.845163E+06 | -1.161948E+07 |  0.2263303334 |  0.09930 |  0.11599 |  1.27903
# ......................................... Calculating likelihood with m, c, log(l):  -0.4152684872546475 397.18430925671123 5
# --- 4.682366132736206 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.41394989899768 198506.3987364877 5
# --- 4.655062913894653 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3134985012403733 253156.52954233257 5
# --- 4.486388206481934 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9156729696747896 11.058936784034422 5
# --- 4.682976722717285 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.7300178595012166 1437.8857292751966 5
# --- 4.79911994934082 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.47518803546101207 2164370.1177893463 5
# --- 4.494420051574707 seconds to calculate log_likelihood ---
#     15 |      104 | -1.070471E+07 | -1.161948E+07 |  0.1674870954 |  0.06100 |  0.08375 |  1.37351
# ......................................... Calculating likelihood with m, c, log(l):  -1.1545168015095375 17.899904965145712 5
# --- 8.553893089294434 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3120909570937527 16.32333726332094 5
# --- 8.572385787963867 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1047279474632599 585.5173469697206 5
# --- 4.355722904205322 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0145670439414975 3396.5558664604496 5
# --- 4.318199872970581 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0738651167748556 34265.14123187358 5
# --- 4.488978862762451 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1314528583604768 3611989.207812733 5
# --- 4.570735216140747 seconds to calculate log_likelihood ---
#     16 |      110 | -1.068974E+07 | -1.161948E+07 |  0.1299455758 |  0.04339 |  0.05631 |  1.31171
# ......................................... Calculating likelihood with m, c, log(l):  -0.9960450934750535 15.158443042902533 5
# --- 4.716376066207886 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.327173414921066 130.08756793799353 5
# --- 9.065850973129272 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1895988166771239 285.36531492741835 5
# --- 4.4182820320129395 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0463071115859912 51.647854552212046 5
# --- 4.642210960388184 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2271996940504013 10.007861728266432 5
# --- 8.915715217590332 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2320914178174012 381.92035887640145 5
# --- 4.784045219421387 seconds to calculate log_likelihood ---
#     17 |      116 | -1.071995E+07 | -1.161948E+07 |  0.1457768271 |  0.04632 |  0.06989 |  1.62758
# ......................................... Calculating likelihood with m, c, log(l):  -1.3132253168420802 16.61744466376171 5
# --- 9.308829069137573 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1977849629921509 24.999605274559958 5
# --- 8.639184951782227 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.394235437358423 22.530704789258536 5
# --- 8.681176662445068 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3319238218472784 14.020209574795947 5
# --- 9.692740201950073 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1533458225582494 33.880426189204805 5
# --- 4.795431852340698 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9934882796050366 90.3652460397927 5
# --- 4.697351932525635 seconds to calculate log_likelihood ---
#     18 |      122 | -1.071134E+07 | -1.173579E+07 |  0.1317318334 |  0.04198 |  0.04965 |  1.23444
# ......................................... Calculating likelihood with m, c, log(l):  -1.584112732380127 13.7091320866819 5
# --- 9.535953998565674 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1975117004508866 45.34067923430885 5
# --- 8.628412008285522 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9845957579164248 46877.61572289489 5
# --- 4.802388906478882 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1491855218448 152.10223388331752 5
# --- 4.371533155441284 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1205425055739844 46.90651560626595 5
# --- 4.436424016952515 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3108670132114182 113.89931505719473 5
# --- 8.722102642059326 seconds to calculate log_likelihood ---
#     19 |      128 | -1.069711E+07 | -1.173579E+07 |  0.1158199513 |  0.03408 |  0.04105 |  1.22457
# ......................................... Calculating likelihood with m, c, log(l):  -1.290772895158908 49.91485222501291 5
# --- 8.555416107177734 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2422370900499016 77.32948063933347 5
# --- 9.719619035720825 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9361583200440271 10.002574444806926 5
# --- 4.49655294418335 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.143157221971435 10.932524428099143 5
# --- 9.687376022338867 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2072421683264234 457.55126958312167 5
# --- 4.721836090087891 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2077832453292872 15.899213918984184 5
# --- 9.405330181121826 seconds to calculate log_likelihood ---
#     20 |      134 | -1.071675E+07 | -1.173579E+07 |  0.0942320035 |  0.02669 |  0.02927 |  1.28309
# ......................................... Calculating likelihood with m, c, log(l):  -1.2553575965517738 72.85689813234055 5
# --- 9.064390897750854 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2888879387739949 45.9243256484683 5
# --- 9.225756168365479 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.286739895502619 17.441161721321276 5
# --- 9.601984024047852 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0274577622198522 19.488195611353422 5
# --- 5.09297513961792 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3956262009140343 90.3150907279184 5
# --- 11.392745971679688 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2389736516344185 85.45866160160165 5
# --- 13.575819969177246 seconds to calculate log_likelihood ---
#     21 |      140 | -1.070238E+07 | -1.173579E+07 |  0.0871609023 |  0.02228 |  0.02572 |  1.26494
# ......................................... Calculating likelihood with m, c, log(l):  -1.34095205713307 65.30027675287158 5
# --- 13.427932739257812 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1966704085961122 107.00838980729856 5
# --- 7.072276830673218 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3821691020425502 61.450251332277965 5
# --- 13.548712253570557 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.34199625703002 36.2838485523227 5
# --- 12.48947787284851 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1225053933887144 42.7354925650226 5
# --- 5.651849031448364 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.328284910947462 230.5913486973806 5
# --- 8.836765050888062 seconds to calculate log_likelihood ---
#     22 |      146 | -1.069505E+07 | -1.173579E+07 |  0.0871586377 |  0.02145 |  0.02614 |  1.39908
# ......................................... Calculating likelihood with m, c, log(l):  -0.985853280173925 115.50371303521395 5
# --- 4.47099494934082 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3165915179623107 91.04231229159062 5
# --- 8.598197937011719 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1313919836901465 29.725035031080225 5
# --- 4.537734031677246 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.1166521668200038 166.48652102732962 5
# --- 4.458894968032837 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2540574791072836 114.63468852038731 5
# --- 4.4289960861206055 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4643010064440003 98.44464948842062 5
# --- 8.651262044906616 seconds to calculate log_likelihood ---
#     23 |      152 | -1.073320E+07 | -1.173579E+07 |  0.1318279221 |  0.03781 |  0.04049 |  1.17952
# ......................................... Calculating likelihood with m, c, log(l):  -1.5225933146083475 22.721440192235743 5
# --- 8.509411096572876 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3117308909484255 10.764098088555148 5
# --- 8.861339092254639 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4195648220034731 163.95336862384144 5
# --- 8.518888235092163 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3353194087261806 11.09933122229121 5
# --- 8.973062992095947 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2370695840805488 38.7228601748363 5
# --- 8.827064990997314 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4547061948508264 434.0376006560692 5
# --- 9.110115051269531 seconds to calculate log_likelihood ---
#     24 |      158 | -1.065317E+07 | -1.173579E+07 |  0.1464598172 |  0.04019 |  0.04229 |  1.41754
# ......................................... Calculating likelihood with m, c, log(l):  -1.5054250064896464 16.6815574748317 5
# --- 9.235413074493408 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4856558065046674 21.053073945419143 5
# --- 9.133986234664917 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3302694289360937 58.23348622776052 5
# --- 8.598447322845459 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4761560317011058 10.102376495343792 5
# --- 8.576658248901367 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5315759207750799 14.974053387785448 5
# --- 8.986680269241333 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3641951614442038 69.7326481425361 5
# --- 8.849284172058105 seconds to calculate log_likelihood ---
#     25 |      164 | -1.073434E+07 | -1.300853E+07 |  0.2343356807 |  0.06726 |  0.07184 |  1.35986
# ......................................... Calculating likelihood with m, c, log(l):  -1.5831342169630198 19.385654970490503 5
# --- 8.675709009170532 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.6465479039771274 12.04614360562008 5
# --- 8.981962203979492 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4501350644310267 27.37490320095287 5
# --- 8.528383016586304 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.583188714916362 23.262754480231028 5
# --- 8.486892938613892 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2862930126147423 10.90841273434369 5
# --- 8.82935094833374 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2382660639003897 10.022166803160212 5
# --- 8.664331674575806 seconds to calculate log_likelihood ---
#     26 |      170 | -5.799567E+06 | -1.300853E+07 |  0.2552667028 |  0.06600 |  0.07265 |  1.13935
# ......................................... Calculating likelihood with m, c, log(l):  -1.5173210748328585 11.956766466855303 5
# --- 8.592461109161377 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0474785305542915 13.126268988302604 5
# --- 4.412163734436035 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2551603233615762 10.009467258500981 5
# --- 8.582442998886108 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3283002645590192 86.80020392615698 5
# --- 8.874940872192383 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2897496785932288 15.541868525769138 5
# --- 9.372107028961182 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.0036841767925586 13.282745460230597 5
# --- 4.538423776626587 seconds to calculate log_likelihood ---
#     27 |      176 | -1.224662E+07 | -1.981085E+07 |  0.1911350636 |  0.04127 |  0.05139 |  1.24826
# ......................................... Calculating likelihood with m, c, log(l):  -1.2488640076372497 11.130329602953568 5
# --- 8.781084299087524 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4172754717391922 13.919774997066192 5
# --- 8.544005870819092 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4777616944711167 10.320687800502073 5
# --- 8.472568273544312 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4364943179869347 10.008903806253153 5
# --- 8.50185227394104 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.284915769543169 10.164344074517388 5
# --- 8.908921241760254 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -0.9666474290784408 14.349371347500266 5
# --- 4.367472887039185 seconds to calculate log_likelihood ---
#     28 |      182 | -1.017630E+07 | -1.981085E+07 |  0.2006843694 |  0.04397 |  0.05134 |  1.33176
# ......................................... Calculating likelihood with m, c, log(l):  -1.4878150310342932 13.98822295308626 5
# --- 8.466345071792603 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.2723851107715318 57.78407540700681 5
# --- 8.525360107421875 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.262403336949594 26.14272800791837 5
# --- 8.613368034362793 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5039168278060742 10.04369807773781 5
# --- 8.44309115409851 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4687857270574036 10.391412055409575 5
# --- 8.543606996536255 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4370354099991256 21.395820949095917 5
# --- 8.589532136917114 seconds to calculate log_likelihood ---
#     29 |      188 | -1.192241E+07 | -1.981085E+07 |  0.1754555729 |  0.03091 |  0.04633 |  1.62451
# ......................................... Calculating likelihood with m, c, log(l):  -1.5251458343164122 11.31804482696555 5
# --- 8.567728996276855 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.6086801053746869 10.136850458714969 5
# --- 8.493499755859375 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4220810939331714 10.607389139717235 5
# --- 8.876693964004517 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.59298452109651 10.033241028215553 5
# --- 9.069384098052979 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.4353470095735745 10.098712438039486 5
# --- 8.528203010559082 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.7036859040568317 19.511055530037673 5
# --- 8.433731079101562 seconds to calculate log_likelihood ---
#     30 |      194 |  2.574567E+07 | -2.679071E+07 |  0.1464522433 |  0.02324 |  0.03503 |  1.65784
# ......................................... Calculating likelihood with m, c, log(l):  -1.5434305759475246 10.901962941994741 5
# --- 8.633585214614868 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.3363632957069362 10.827246331969073 5
# --- 8.588757991790771 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5755243915095751 10.404002669725154 5
# --- 8.515939950942993 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.6697425598216156 10.407789077357847 5
# --- 8.491276979446411 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.5713292861746262 10.081653895542148 5
# --- 8.568236112594604 seconds to calculate log_likelihood ---
# ......................................... Calculating likelihood with m, c, log(l):  -1.654131342461287 10.046246672031062 5
# --- 9.274728059768677 seconds to calculate log_likelihood ---
#     31 |      200 | -5.885375E+06 | -2.679071E+07 |  0.1280712687 |  0.01967 |  0.02537 |  1.37208
#                  --------------> Best parameters founded for: m, c:  -1.59298452109651 10.033241028215553 5
# --- 22.544545916716256 minutes to minimizing ---
#                  --------------> Fitting with m, c, log_l: -1.59298452109651 10.033241028215553 5
# ....................................OPTIMIZING..................................

# %%
GM._optimization_res.X
# Out:
# array([-1.59298452,  1.00144125])

# %%
GM.plot_stats_optimization()

# %%
GM = FF._GaussianModel

# %%
print(GM._best)
# Out:
# [-1.59298452  1.00144125]

# %%
m_best = GM.m
log_c_best = GM.log_c

# %%
m_best
log_c_best
# Out:
# 1.0014412454136123

# %%
I = FF._GaussianModel._mu
I_reshape = I.reshape(N, N)
r_out_rad = r_out

import matplotlib.colors as colors

x_f1d = FF._DFT._Xn * rad_to_arcsec
y_f1d = FF._DFT._Yn * rad_to_arcsec
u_f1d = FF._DFT._Un
v_f1d = FF._DFT._Vn

fig, axs = plt.subplots(2, 1, figsize=(5, 8), constrained_layout=True)  # 1 columna, 2 filas
# --- Panel 1: Real plane ---
norm = colors.PowerNorm(gamma=0.5, vmin=0)

fig.suptitle(f'Best -> m = {m_best:.2f}, $log(c) $ =  {log_c_best:.2f} (N = ' + str(N) + ')' , fontsize=10)

plot1 = axs[0].pcolormesh(x_f1d.reshape(N, N),
                          y_f1d.reshape(N, N),
                          I_reshape, cmap="magma", norm=norm)
cbar1 = fig.colorbar(plot1, ax=axs[0], shrink = 0.9)
cbar1.set_label(r'$I_{model}$ [$Jy\, sr^{-1}$]', size=12)
axs[0].invert_xaxis()
axs[0].set_title(r'Real plane')
axs[0].set_xlabel("x ['']")
axs[0].set_ylabel("y ['']")
axs[0].set_aspect(1)

# --- Panel 2: Fourier plane ---
plot2 = axs[1].pcolormesh(np.fft.fftshift(u_f1d.reshape(N, N))/1e6,
                          np.fft.fftshift(v_f1d.reshape(N, N))/1e6,
                          np.log(np.fft.fftshift(np.abs(np.fft.ifft2(I_reshape)))),
                          cmap="magma")
cbar2 = fig.colorbar(plot2, ax=axs[1], shrink = 0.9)
cbar2.set_label(r'$\log(|Vis_{model}|)$ [$Jy^{2}$]', size=12)
axs[1].set_title(r'Fourier plane')
axs[1].set_xlabel(r'u [10$^{6}$ $\lambda$]')
axs[1].set_ylabel(r'v [10$^{6}$ $\lambda$]')
axs[1].set_aspect(1)

plt.show()

# %%
m = FF._GaussianModel._ms
log_c = FF._GaussianModel._cs
log_likelihood = np.array(FF._GaussianModel._loglikelihoods)

# %%
print(FF._GaussianModel.m, FF._GaussianModel.c)
# Out:
# -1.59298452109651 10.033241028215553

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as mtri

triang = mtri.Triangulation(m, log_c)

plt.figure()
tcf = plt.tricontourf(triang, log_likelihood, levels=30) 
plt.tricontour(triang, log_likelihood, levels=15, linewidths=0.5)  # líneas (opcional)
plt.scatter(m, log_c, s=6, alpha=0.5)  # muestra tus puntos
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
cbar = plt.colorbar(tcf)
cbar.set_label(r"$-\log \mathcal{L}$")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import corner
import matplotlib.pyplot as plt

samples = np.column_stack([m, log_c, log_likelihood])
labels  = [r"$m$", r"$\log_{10} c$", r"$\log \mathcal{L}$"]

fig = corner.corner(
    samples,
    labels=labels,
    show_titles=True,
    quantiles=[0.16, 0.50, 0.84],
    title_fmt=".2f",
    bins=30
)
plt.show()
# Out:
# WARNING:root:Too few points to create valid contours

# %%
FF._GaussianModel.one_fit([GM._best[0], GM._best[1]])
# Out:
#                  --------------> Fitting with m, c, log_l: -1.59298452109651 10.033241028215553 5
