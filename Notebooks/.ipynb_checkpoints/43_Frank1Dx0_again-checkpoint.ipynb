# %%
from May31_Frank2D_CPU import *

# %%
disk_name = 'AS209 1mm'
filename = 'uvtables/uvtable_AS209_continuum.npz'
disk_geometry = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3 }
Rout = 1.2*2
N = 300
maxiter= 20000
rtol = 1e-10

print("Running: " + disk_name +" ...." + " frank2d model with " + str(N)+ 'x'+str(N)+ " points" )
# Out:
# Running: AS209 1mm .... frank2d model with 300x300 points

# %%
inc = disk_geometry['inc']
pa = disk_geometry['pa']
dra = disk_geometry['dra']
ddec = disk_geometry['ddec']

# UVtable
dir = "../../../data/"
data_file = dir + filename

 # load data
data = np.load(data_file)
u, v, Re, Imag, Weights = data['u'], data['v'], data['Re'], data['Im'], data['w']
Vis = Re + Imag*1j

u, v, Vis, Weights =  u, v, Vis, Weights


geom = Geometry(inc, pa, dra, ddec)
frank2d = Frank2D(N, Rout, geom)

frank2d.preprocess_vis(u, v, Vis, Weights, hermitian= True)
u_gridded, v_gridded, vis_gridded, weights_gridded = frank2d._gridded_data['u'], frank2d._gridded_data['v'], frank2d._gridded_data['vis'], frank2d._gridded_data['weights']
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/preprocess_vis.py:46: RuntimeWarning: invalid value encountered in divide
#   vis_gridded_matrix =  vis_weights_sum_bin/weights_gridded_matrix
# Enforcing Hermitian symmetry...
#   --> time = 0.24  min |  14.26 seconds
# Setting gridded data...

# %%
from frank.radial_fitters import FrankFitter
from frank.geometry import SourceGeometry

alpha = 1.3
w_smooth = 1e-3
n_pts = 300

geom_f1d = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)
FF = FrankFitter(Rout, n_pts, geom_f1d, alpha = alpha, weights_smooth = w_smooth)
sol = FF.fit(u_gridded, v_gridded, vis_gridded, weights_gridded)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/frank/statistical_models.py:218: RuntimeWarning: divide by zero encountered in log
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# /opt/anaconda3/lib/python3.12/site-packages/frank/filter.py:175: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   tau = scipy.sparse.linalg.spsolve(Tij_pI, beta + np.log(pi))

# %%
vis_fit_1d = sol.predict(u_gridded, v_gridded, sol.mean, geometry = geom_f1d)

# %%
plt.imshow(np.log(np.abs(vis_fit_1d.reshape(N, N))))

# %%
extent=[u_gridded.min(), u_gridded.max(), v_gridded.min(), v_gridded.max()]
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_fit_1d.real.reshape(N, N)))), extent=extent, origin='lower', vmin=-8, vmax=-1, cmap='magma')
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(N, N)))), extent=extent, origin='lower', vmin=-8, vmax=-1, cmap = 'viridis')
plt.title(f'Frank1D N = {N}, solution for log |Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_80028/1520320944.py:3: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(N, N)))), extent=extent, origin='lower', vmin=-8, vmax=-1, cmap = 'viridis')

# %%
plt.figure()
plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(N, N)))), extent=extent, origin='lower', vmin=-12, vmax=-2)
plt.title(f'Frank2D: log |gridded Visibilities|')
plt.colorbar()
# Out:
# /var/folders/ng/vs__trg57hl3mtgq5kgkzj4h0000gn/T/ipykernel_80028/2256721134.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(np.fft.fftshift(vis_gridded.reshape(N, N)))), extent=extent, origin='lower', vmin=-12, vmax=-2)

# %%
start_time = time.time()

frank2d.preprocess_vis(u, v, Vis, Weights, hermitian= True)
u_gridded, v_gridded, vis_gridded, weights_gridded = frank2d._gridded_data['u'], frank2d._gridded_data['v'], frank2d._gridded_data['vis'], frank2d._gridded_data['weights']
sol = Frank2D_optimized(N, u_gridded, v_gridded, vis_gridded, weights_gridded,
                        maxiter = maxiter, rtol = rtol, 
                        kernel_params = {'m': -2, 'c': 1e8, 'l': 5e4}, 
                        x0 = vis_fit_1d)
frank2d.sol_visibility = sol
frank2d.fft()

end_time = time.time()
execution_time = end_time - start_time
print(f'  ------------------------------------------> TOTAL ALGORITHM TIME = {execution_time/60 :.2f}  min | {execution_time: .2f} seconds')
# Out:
# RUNNING WITH  {'m': -2, 'c': 100000000.0, 'l': 50000.0}
# DATA (90000,)
# ------> Creating linear operators
#   --> time = 4.22  min |  253.39 seconds
# ---------------------------------
# ------> Creating sparse system
#   --> time = 1.42  min |  85.34 seconds
# ---------------------------------
# ------> Running CGM
#      * BICGSTAB
#          * rtol: 1e-09
#          * final tolerance : 0.2881751982790493
# ....................... TOLERANCE:  0.2881751982790493
#          * maxiter:  20000
# .... iteration:  0
#                         -> actual tol:  238025809.63800776 vs  0.2881751982790493
# .... iteration:  1
#                         -> actual tol:  39734070.48675084 vs  0.2881751982790493
# .... iteration:  2
#                         -> actual tol:  27902070.178385872 vs  0.2881751982790493
# .... iteration:  3
#                         -> actual tol:  107248019.41877298 vs  0.2881751982790493
# .... iteration:  4
#                         -> actual tol:  18706287.534440756 vs  0.2881751982790493
# .... iteration:  5
#                         -> actual tol:  15207404.920295142 vs  0.2881751982790493
# .... iteration:  6
#                         -> actual tol:  13496844.283142084 vs  0.2881751982790493
# .... iteration:  7
#                         -> actual tol:  10157087.69660361 vs  0.2881751982790493
# .... iteration:  8
#                         -> actual tol:  7881300.115768695 vs  0.2881751982790493
# .... iteration:  9
#                         -> actual tol:  8254783.696164906 vs  0.2881751982790493
# .... iteration:  10
#                         -> actual tol:  5493052.7324295575 vs  0.2881751982790493
# .... iteration:  11
#                         -> actual tol:  5093112.071326203 vs  0.2881751982790493
# .... iteration:  12
#                         -> actual tol:  4396703.228103869 vs  0.2881751982790493
# .... iteration:  13
#                         -> actual tol:  4179178.7311709025 vs  0.2881751982790493
# .... iteration:  14
#                         -> actual tol:  4038336.13637111 vs  0.2881751982790493
# .... iteration:  15
#                         -> actual tol:  3569324.17812232 vs  0.2881751982790493
# .... iteration:  16
#                         -> actual tol:  23559817.25403479 vs  0.2881751982790493
# .... iteration:  17
#                         -> actual tol:  2076740.851752653 vs  0.2881751982790493
# .... iteration:  18
#                         -> actual tol:  1520173.9716612375 vs  0.2881751982790493
# .... iteration:  19
#                         -> actual tol:  1608520.7487572066 vs  0.2881751982790493
# .... iteration:  20
#                         -> actual tol:  546877.3714638951 vs  0.2881751982790493
# .... iteration:  21
#                         -> actual tol:  562502.0906726118 vs  0.2881751982790493
# .... iteration:  22
#                         -> actual tol:  558588.1290554606 vs  0.2881751982790493
# .... iteration:  23
#                         -> actual tol:  336131.7047748479 vs  0.2881751982790493
# .... iteration:  24
#                         -> actual tol:  279814.8663889399 vs  0.2881751982790493
# .... iteration:  25
#                         -> actual tol:  167171.2568755988 vs  0.2881751982790493
# .... iteration:  26
#                         -> actual tol:  142059.33166060754 vs  0.2881751982790493
# .... iteration:  27
#                         -> actual tol:  178836.52520278888 vs  0.2881751982790493
# .... iteration:  28
#                         -> actual tol:  138182.76214630206 vs  0.2881751982790493
# .... iteration:  29
#                         -> actual tol:  93372.92164222592 vs  0.2881751982790493
# .... iteration:  30
#                         -> actual tol:  88592.96929061098 vs  0.2881751982790493
# .... iteration:  31
#                         -> actual tol:  72651.41992307706 vs  0.2881751982790493
# .... iteration:  32
#                         -> actual tol:  69057.874132243 vs  0.2881751982790493
# .... iteration:  33
#                         -> actual tol:  440470.651256561 vs  0.2881751982790493
# .... iteration:  34
#                         -> actual tol:  296210.2020088208 vs  0.2881751982790493
# .... iteration:  35
#                         -> actual tol:  34877.60706217298 vs  0.2881751982790493
# .... iteration:  36
#                         -> actual tol:  25778.33843927391 vs  0.2881751982790493
# .... iteration:  37
#                         -> actual tol:  12092.909046141964 vs  0.2881751982790493
# .... iteration:  38
#                         -> actual tol:  10497.902117443493 vs  0.2881751982790493
# .... iteration:  39
#                         -> actual tol:  7909.70756458244 vs  0.2881751982790493
# .... iteration:  40
#                         -> actual tol:  7008.568737049331 vs  0.2881751982790493
# .... iteration:  41
#                         -> actual tol:  5980.810727290012 vs  0.2881751982790493
# .... iteration:  42
#                         -> actual tol:  5755.420314447645 vs  0.2881751982790493
# .... iteration:  43
#                         -> actual tol:  5707.4012328753 vs  0.2881751982790493
# .... iteration:  44
#                         -> actual tol:  5532.5886262296735 vs  0.2881751982790493
# .... iteration:  45
#                         -> actual tol:  5334.29749243984 vs  0.2881751982790493
# .... iteration:  46
#                         -> actual tol:  3930.2264954198636 vs  0.2881751982790493
# .... iteration:  47
#                         -> actual tol:  4724.254838350284 vs  0.2881751982790493
# .... iteration:  48
#                         -> actual tol:  2869.60335591567 vs  0.2881751982790493
# .... iteration:  49
#                         -> actual tol:  3372.4117012894008 vs  0.2881751982790493
# .... iteration:  50
#                         -> actual tol:  3607.0127140381574 vs  0.2881751982790493
# .... iteration:  51
#                         -> actual tol:  3332.8026903147043 vs  0.2881751982790493
# .... iteration:  52
#                         -> actual tol:  3810.094677974058 vs  0.2881751982790493
# .... iteration:  53
#                         -> actual tol:  2601.0033980988505 vs  0.2881751982790493
# .... iteration:  54
#                         -> actual tol:  1943.5857749134586 vs  0.2881751982790493
# .... iteration:  55
#                         -> actual tol:  1261.4508403882833 vs  0.2881751982790493
# .... iteration:  56
#                         -> actual tol:  914.4847793683202 vs  0.2881751982790493
# .... iteration:  57
#                         -> actual tol:  890.6922451859796 vs  0.2881751982790493
# .... iteration:  58
#                         -> actual tol:  877.1678499244571 vs  0.2881751982790493
# .... iteration:  59
#                         -> actual tol:  581.4946037972828 vs  0.2881751982790493
# .... iteration:  60
#                         -> actual tol:  565.0174507470523 vs  0.2881751982790493
# .... iteration:  61
#                         -> actual tol:  397.88443488432745 vs  0.2881751982790493
# .... iteration:  62
#                         -> actual tol:  420.98798414666595 vs  0.2881751982790493
# .... iteration:  63
#                         -> actual tol:  372.1344688156412 vs  0.2881751982790493
# .... iteration:  64
#                         -> actual tol:  343.8079550102382 vs  0.2881751982790493
# .... iteration:  65
#                         -> actual tol:  248.7142214186521 vs  0.2881751982790493
# .... iteration:  66
#                         -> actual tol:  192.1435430631828 vs  0.2881751982790493
# .... iteration:  67
#                         -> actual tol:  175.0461422644825 vs  0.2881751982790493
# .... iteration:  68
#                         -> actual tol:  175.4670403025129 vs  0.2881751982790493
# .... iteration:  69
#                         -> actual tol:  174.95768803808448 vs  0.2881751982790493
# .... iteration:  70
#                         -> actual tol:  170.5692972446843 vs  0.2881751982790493
# .... iteration:  71
#                         -> actual tol:  93.73712151641291 vs  0.2881751982790493
# .... iteration:  72
#                         -> actual tol:  302.6661107372735 vs  0.2881751982790493
# .... iteration:  73
#                         -> actual tol:  469.61214741166623 vs  0.2881751982790493
# .... iteration:  74
#                         -> actual tol:  178.0015392396565 vs  0.2881751982790493
# .... iteration:  75
#                         -> actual tol:  40.80405989187108 vs  0.2881751982790493
# .... iteration:  76
#                         -> actual tol:  34.16584801908781 vs  0.2881751982790493
# .... iteration:  77
#                         -> actual tol:  30.891077605533358 vs  0.2881751982790493
# .... iteration:  78
#                         -> actual tol:  27.69181767917298 vs  0.2881751982790493
# .... iteration:  79
#                         -> actual tol:  43.077271300358426 vs  0.2881751982790493
# .... iteration:  80
#                         -> actual tol:  21.284879434852655 vs  0.2881751982790493
# .... iteration:  81
#                         -> actual tol:  19.317211765703558 vs  0.2881751982790493
# .... iteration:  82
#                         -> actual tol:  18.849649056595354 vs  0.2881751982790493
# .... iteration:  83
#                         -> actual tol:  25.243678413084147 vs  0.2881751982790493
# .... iteration:  84
#                         -> actual tol:  11.464436684745953 vs  0.2881751982790493
# .... iteration:  85
#                         -> actual tol:  5.271865007010205 vs  0.2881751982790493
# .... iteration:  86
#                         -> actual tol:  4.055558037888111 vs  0.2881751982790493
# .... iteration:  87
#                         -> actual tol:  3.6110114299634977 vs  0.2881751982790493
# .... iteration:  88
#                         -> actual tol:  2.5197884783903124 vs  0.2881751982790493
# .... iteration:  89
#                         -> actual tol:  2.315542426844019 vs  0.2881751982790493
# .... iteration:  90
#                         -> actual tol:  2.200520617218289 vs  0.2881751982790493
# .... iteration:  91
#                         -> actual tol:  2.1705149700424893 vs  0.2881751982790493
# .... iteration:  92
#                         -> actual tol:  2.2458465863430015 vs  0.2881751982790493
# .... iteration:  93
#                         -> actual tol:  2.8618119862122673 vs  0.2881751982790493
# .... iteration:  94
#                         -> actual tol:  2.820950109455946 vs  0.2881751982790493
# .... iteration:  95
#                         -> actual tol:  2.3202046685521824 vs  0.2881751982790493
# .... iteration:  96
#                         -> actual tol:  1.6346313842459381 vs  0.2881751982790493
# .... iteration:  97
#                         -> actual tol:  1.3021365162883813 vs  0.2881751982790493
# .... iteration:  98
#                         -> actual tol:  1.264324355177351 vs  0.2881751982790493
# .... iteration:  99
#                         -> actual tol:  1.3268089673158174 vs  0.2881751982790493
# .... iteration:  100
#                         -> actual tol:  3.468713629235249 vs  0.2881751982790493
# .... iteration:  101
#                         -> actual tol:  1.4362652582534088 vs  0.2881751982790493
# .... iteration:  102
#                         -> actual tol:  0.6212297761380876 vs  0.2881751982790493
# .... iteration:  103
#                         -> actual tol:  0.32723501180839626 vs  0.2881751982790493
# converged by norm of s
# CGM with info:  0
#   --> time = 0.04  min |  2.42 seconds
# ---------------------------------
# ------> CGM converged?   True
#               --> Fit correctly?   True
#                                                      !!!!!!!!!!!!!!!!!!! CORRECT !!!!!!!!!!!!!!!!!!!
# ---------------------------------
# Inverting with 2fft ...
#   --> time = 0.00  min |  0.00 seconds
#   ------------------------------------------> TOTAL ALGORITHM TIME = 5.69  min |  341.21 seconds
