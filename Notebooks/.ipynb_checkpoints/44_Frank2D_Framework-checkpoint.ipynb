# %% [markdown]
# # Imports

# %%
import os
import sys

# %%
current_dir =  os.getcwd()

# Replace the following line in the path your frank2d files are.
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import time

# %%
# frank2d
from frank2d import Frank2D
from frank2d.geometry import Geometry
from frank2d.posterior_optimization import *
from frank2d.plot import Plot
from frank2d.constants import rad_to_arcsec

# frank1d
from frank.utilities import UVDataBinner

# %% [markdown]
# # Data

# %%
AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}

# %%
data = AS209

dir = "/Users/mariajmelladot/Desktop/Frank2D/data/uvtables/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum.npz"

# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
r_out = data['rout']

# %%
# Frank Parameters
N = 300
 # load data
file = np.load(data_file)
u, v, Re, Im, Weights = file['u'], file['v'], file['Re'], file['Im'], file['w']
Vis = Re + Im*1j

# %% [markdown]
# # Run F2D

# %%
geom = Geometry(inc, pa, dra, ddec)
frank2d = Frank2D(N, r_out, geom)

# %%
frank2d.process_vis(u, v, Vis, Weights)
# Out:
# Shifted grid..
# Setting gridded data...

# %%
# Let's review the input for frank2d.

# %%
input =  frank2d.gridded_data
u_g, v_g, vis_g, weights_g = input["u"], input["v"], input["vis"], input["weights"]
u_shifted, v_shifted = np.fft.fftshift(u_g.reshape(N, N)), np.fft.fftshift(v_g.reshape(N, N))
vis_shifted = np.fft.fftshift(vis_g.reshape(N, N))

plt.figure(figsize= (4, 4))
plt.pcolormesh(v_shifted,
               u_shifted,
               np.log(np.abs(vis_shifted)),
               cmap="viridis", vmin=-10, vmax=-2)
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(r'log |$Vis_{input}$|')
cmap = plt.colorbar(shrink=0.8)
cmap.set_label(r'V [Jy]', size=10)
plt.gca().set_aspect(1)
plt.show()

# %%
start_time = time.time()
kernel_params =  {'m': -2, 'c': 1e8, 'l': 5e4}
frank2d.fit(kernel_params = kernel_params, rtol = 1e-9 )
end_time = time.time()
print(f"F2D model in {(end_time - start_time)/60:.2f} minutes.")
# Out:
# Setting GP Kernel Wendland...
# Creating sparse linear system...
# --> time = 0.84  min |  50.16 seconds
# Solving linear system...
#          * rtol: 1e-09
#          * final tolerance: 0.2881751982790495
# Final tolerance :  0.2881751982790495
# .... iteration:  0
#                         -> actual tol:  288175198.2790495 vs  0.2881751982790495
# .... iteration:  1
#                         -> actual tol:  33828640.973787464 vs  0.2881751982790495
# .... iteration:  2
#                         -> actual tol:  37685844.191464685 vs  0.2881751982790495
# .... iteration:  3
#                         -> actual tol:  62636050.13926687 vs  0.2881751982790495
# .... iteration:  4
#                         -> actual tol:  16954480.821191546 vs  0.2881751982790495
# .... iteration:  5
#                         -> actual tol:  14028715.443084337 vs  0.2881751982790495
# .... iteration:  6
#                         -> actual tol:  12324829.791040309 vs  0.2881751982790495
# .... iteration:  7
#                         -> actual tol:  8915516.131303998 vs  0.2881751982790495
# .... iteration:  8
#                         -> actual tol:  7346444.268963236 vs  0.2881751982790495
# .... iteration:  9
#                         -> actual tol:  9614229.279173577 vs  0.2881751982790495
# .... iteration:  10
#                         -> actual tol:  4769836.10332881 vs  0.2881751982790495
# .... iteration:  11
#                         -> actual tol:  5876175.848048127 vs  0.2881751982790495
# .... iteration:  12
#                         -> actual tol:  4556561.205385926 vs  0.2881751982790495
# .... iteration:  13
#                         -> actual tol:  3449460.8448242433 vs  0.2881751982790495
# .... iteration:  14
#                         -> actual tol:  3189160.7430481873 vs  0.2881751982790495
# .... iteration:  15
#                         -> actual tol:  2668113.2657785383 vs  0.2881751982790495
# .... iteration:  16
#                         -> actual tol:  1959361.7368739687 vs  0.2881751982790495
# .... iteration:  17
#                         -> actual tol:  1747258.1930974766 vs  0.2881751982790495
# .... iteration:  18
#                         -> actual tol:  2345877.200449984 vs  0.2881751982790495
# .... iteration:  19
#                         -> actual tol:  1362406.3368043485 vs  0.2881751982790495
# .... iteration:  20
#                         -> actual tol:  619434.1056444714 vs  0.2881751982790495
# .... iteration:  21
#                         -> actual tol:  496838.99353124585 vs  0.2881751982790495
# .... iteration:  22
#                         -> actual tol:  469484.6165261055 vs  0.2881751982790495
# .... iteration:  23
#                         -> actual tol:  299738.42334722524 vs  0.2881751982790495
# .... iteration:  24
#                         -> actual tol:  296052.18819652905 vs  0.2881751982790495
# .... iteration:  25
#                         -> actual tol:  211340.5112736123 vs  0.2881751982790495
# .... iteration:  26
#                         -> actual tol:  193552.10787210308 vs  0.2881751982790495
# .... iteration:  27
#                         -> actual tol:  187051.21483603682 vs  0.2881751982790495
# .... iteration:  28
#                         -> actual tol:  238667.14554318407 vs  0.2881751982790495
# .... iteration:  29
#                         -> actual tol:  152775.70864526439 vs  0.2881751982790495
# .... iteration:  30
#                         -> actual tol:  138250.48804348006 vs  0.2881751982790495
# .... iteration:  31
#                         -> actual tol:  135389.0479430734 vs  0.2881751982790495
# .... iteration:  32
#                         -> actual tol:  92103.12513718485 vs  0.2881751982790495
# .... iteration:  33
#                         -> actual tol:  90184.9225236732 vs  0.2881751982790495
# .... iteration:  34
#                         -> actual tol:  46639.39141847047 vs  0.2881751982790495
# .... iteration:  35
#                         -> actual tol:  136066.47643263795 vs  0.2881751982790495
# .... iteration:  36
#                         -> actual tol:  74321.1954569691 vs  0.2881751982790495
# .... iteration:  37
#                         -> actual tol:  28867.01252881949 vs  0.2881751982790495
# .... iteration:  38
#                         -> actual tol:  33974.894721683886 vs  0.2881751982790495
# .... iteration:  39
#                         -> actual tol:  26134.404276443016 vs  0.2881751982790495
# .... iteration:  40
#                         -> actual tol:  10365.831998368245 vs  0.2881751982790495
# .... iteration:  41
#                         -> actual tol:  7694.567424791056 vs  0.2881751982790495
# .... iteration:  42
#                         -> actual tol:  7167.135797799941 vs  0.2881751982790495
# .... iteration:  43
#                         -> actual tol:  6920.808545080881 vs  0.2881751982790495
# .... iteration:  44
#                         -> actual tol:  6531.608117811488 vs  0.2881751982790495
# .... iteration:  45
#                         -> actual tol:  4514.670493968748 vs  0.2881751982790495
# .... iteration:  46
#                         -> actual tol:  3539.4701543128367 vs  0.2881751982790495
# .... iteration:  47
#                         -> actual tol:  3457.6889623514417 vs  0.2881751982790495
# .... iteration:  48
#                         -> actual tol:  3445.2673636722216 vs  0.2881751982790495
# .... iteration:  49
#                         -> actual tol:  3568.0543181202866 vs  0.2881751982790495
# .... iteration:  50
#                         -> actual tol:  2370.403414392321 vs  0.2881751982790495
# .... iteration:  51
#                         -> actual tol:  1874.0944674575653 vs  0.2881751982790495
# .... iteration:  52
#                         -> actual tol:  1841.6787664639721 vs  0.2881751982790495
# .... iteration:  53
#                         -> actual tol:  1286.2972346034533 vs  0.2881751982790495
# .... iteration:  54
#                         -> actual tol:  1082.6647798301512 vs  0.2881751982790495
# .... iteration:  55
#                         -> actual tol:  1130.5205140281375 vs  0.2881751982790495
# .... iteration:  56
#                         -> actual tol:  721.8887498828262 vs  0.2881751982790495
# .... iteration:  57
#                         -> actual tol:  492.1142090207846 vs  0.2881751982790495
# .... iteration:  58
#                         -> actual tol:  1390.593391970558 vs  0.2881751982790495
# .... iteration:  59
#                         -> actual tol:  2612.804046504826 vs  0.2881751982790495
# .... iteration:  60
#                         -> actual tol:  2130.141919343358 vs  0.2881751982790495
# .... iteration:  61
#                         -> actual tol:  851.6780591604531 vs  0.2881751982790495
# .... iteration:  62
#                         -> actual tol:  1691.958894146882 vs  0.2881751982790495
# .... iteration:  63
#                         -> actual tol:  240.09038857424608 vs  0.2881751982790495
# .... iteration:  64
#                         -> actual tol:  169.02481174369464 vs  0.2881751982790495
# .... iteration:  65
#                         -> actual tol:  156.21128598149863 vs  0.2881751982790495
# .... iteration:  66
#                         -> actual tol:  129.59200677515918 vs  0.2881751982790495
# .... iteration:  67
#                         -> actual tol:  106.61642623573987 vs  0.2881751982790495
# .... iteration:  68
#                         -> actual tol:  98.00522936592729 vs  0.2881751982790495
# .... iteration:  69
#                         -> actual tol:  93.11115748802928 vs  0.2881751982790495
# .... iteration:  70
#                         -> actual tol:  82.70205612342572 vs  0.2881751982790495
# .... iteration:  71
#                         -> actual tol:  106.49949612429484 vs  0.2881751982790495
# .... iteration:  72
#                         -> actual tol:  124.50657733710545 vs  0.2881751982790495
# .... iteration:  73
#                         -> actual tol:  90.61427983584557 vs  0.2881751982790495
# .... iteration:  74
#                         -> actual tol:  27.4686441971026 vs  0.2881751982790495
# .... iteration:  75
#                         -> actual tol:  26.530947470229147 vs  0.2881751982790495
# .... iteration:  76
#                         -> actual tol:  25.639511269706997 vs  0.2881751982790495
# .... iteration:  77
#                         -> actual tol:  24.68387931454644 vs  0.2881751982790495
# .... iteration:  78
#                         -> actual tol:  25.218653205717658 vs  0.2881751982790495
# .... iteration:  79
#                         -> actual tol:  12.401293654069454 vs  0.2881751982790495
# .... iteration:  80
#                         -> actual tol:  10.66591720111888 vs  0.2881751982790495
# .... iteration:  81
#                         -> actual tol:  5.55554828692963 vs  0.2881751982790495
# .... iteration:  82
#                         -> actual tol:  2.8635369729761306 vs  0.2881751982790495
# .... iteration:  83
#                         -> actual tol:  3.9349283260203447 vs  0.2881751982790495
# .... iteration:  84
#                         -> actual tol:  3.635617476729481 vs  0.2881751982790495
# .... iteration:  85
#                         -> actual tol:  2.4465331691936583 vs  0.2881751982790495
# .... iteration:  86
#                         -> actual tol:  0.9870554861962796 vs  0.2881751982790495
# .... iteration:  87
#                         -> actual tol:  0.6241114940829668 vs  0.2881751982790495
# .... iteration:  88
#                         -> actual tol:  0.3292457800143045 vs  0.2881751982790495
# .... iteration:  89
#                         -> actual tol:  0.30736254808733005 vs  0.2881751982790495
# .... iteration:  90
#                         -> actual tol:  0.3968899295692407 vs  0.2881751982790495
# .... iteration:  91
#                         -> actual tol:  0.4241518974782949 vs  0.2881751982790495
# .... iteration:  92
#                         -> actual tol:  0.36023106960265283 vs  0.2881751982790495
# .... iteration:  93
#                         -> actual tol:  0.32221577010743846 vs  0.2881751982790495
# .... iteration:  94
#                         -> actual tol:  0.30359262365281103 vs  0.2881751982790495
# .... iteration:  95
#                         -> actual tol:  0.2987897430818035 vs  0.2881751982790495
# .... iteration:  96
#                         -> actual tol:  0.25303151771654186 vs  0.2881751982790495
#  --------------------------------------> CGM converged in  96  iterations with tol  0.25303151771654186
# --> time = 0.03  min |  1.98 seconds
# -> CGM converged?   True
# -> Fit correctly?   True
# !!!!  Sucess  !!!!
# Building full visibility model...
# F2D model in 3.24 minutes.

# %% [markdown]
# ## Plot models

# %%
Plotting = Plot(frank2d, geom)

# %%
Plotting.visibility()

# %%
Plotting.intensity()

# %% [markdown]
# # Calculate log posterior with F1D approach
# Considerations:
# - Is important to remember that we are using F1D framework to do this, this is, directly solving I = Dj. For this, I use the module posterior_optimization.py, which contains the necessary functions from Frank1D to do so. We use only GaussianProcess class.
# - Because this framework process all the visibility input, we give it directly gridded visibilities.

# %%
# Create a (u, v, Vis, Weights) based on Frank2D Gridding.
N = 300
geom = Geometry(inc, pa, dra, ddec)
frank2d_ = Frank2D(N, r_out, geom)
frank2d_.process_vis(u, v, Vis, Weights)

data =  frank2d_.gridded_data
u_, v_, Vis_, Weights_ = data["u"], data["v"], data["vis"], data["weights"]
# Out:
# Shifted grid..
# Setting gridded data...

# %%
# Let's review the gridded visibilities first.
u_s, v_s = np.fft.fftshift(u_.reshape(N, N)), np.fft.fftshift(v_.reshape(N, N))
vis_s = np.fft.fftshift(Vis_.reshape(N, N))

plt.figure(figsize= (4, 4))
plt.pcolormesh(v_s,
               u_s,
               np.log(np.abs(vis_s)),
               cmap="viridis", vmin=-10, vmax=-2)
plt.xlabel(r'u [1e6 $\lambda$]')
plt.ylabel(r'v [1e6 $\lambda$]')
plt.title(r'log |$Vis_{gridded}$|')
cmap = plt.colorbar(shrink=0.8)
cmap.set_label(r'V [Jy]', size=10)
plt.gca().set_aspect(1)
plt.show()

# %%
# Let's review the power spectrum.
baselines = np.hypot(u_, v_)         
cs, ms = ['#a4a4a4', 'k'], ['.', 'x']
bin_widths=[1e3, 1e5]

binned_vis = UVDataBinner(baselines, Vis_, Weights_, bin_widths[0])
logx = np.log10(binned_vis.uv)
logy = np.log10(np.abs(binned_vis.V)**2)

binned_vis2 = UVDataBinner(baselines, Vis_, Weights_, bin_widths[1])
logx2 = np.log10(binned_vis2.uv)
logy2 = np.log10(np.abs(binned_vis2.V)**2)

def linear_power_spectrum(logx, m, c):
    return m*logx + np.log10(c)
    
m_array = np.array([-2, -3, -4, -6])
logc_array = np.array([8, 13, 18, 30])
c_array = 10**logc_array

# %%
plt.figure(figsize=(7, 3))
plt.plot(logx, logy, c=cs[0], marker=ms[0], ls='None', label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[0]/1e3))
plt.plot(logx2, logy2, c=cs[1], marker=ms[1], ls='None', label=r'Obs., {:.0f} k$\lambda$ bins'.format(bin_widths[1]/1e3))

for i in range(0, len(m_array)):
    plt.plot(logx2, linear_power_spectrum(logx2, m_array[i], c_array[i]), ls = '--', label = f'm = {m_array[i]: .1f}, log(c) = {logc_array[i]: .1f}')

plt.xlabel(r'log Baseline [$\lambda$]', size = 10)
plt.ylabel(r'log $|Vis_{Obs}|^{2}$ [Jy]', size = 10)
plt.legend(loc = 'best', fontsize = 'x-small')
plt.title("Power spectrum")
plt.ylim(-9, 0)
plt.xlim(5, 6.5)
plt.show()

# %% [markdown]
# ### Optimization

# %%
# The amount of collocation points is less.
N_f1d = 50

# %%
import time
start_time = time.time()
FF = FourierBesselFitter(r_out, N_f1d, geom)
sol = FF.fit(u_, v_, Vis_, Weights_)
total_time = time.time() - start_time
print("--- %s minutes ---", total_time/60, " minutes.")
# Out:
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/posterior_optimization.py:383: RuntimeWarning: divide by zero encountered in log
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# /Users/mariajmelladot/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/posterior_optimization.py:383: RuntimeWarning: invalid value encountered in scalar multiply
#   H0 = 0.5 * np.sum(np.log(w / (2 * np.pi)) - V * w * V)
# --- %s minutes --- 1.6404171466827393  minutes.

# %%
# In this object is everything.
GM = FF._GaussianModel
FT = GM._DFT

# %% [markdown]
# ### Let's calculate the $logP(\sigma | V)$

# %%
# Let's do just one fit with this discrete approach.
kernel_params = {"m": -2, "logc": 8, "logl": 5}
GM.one_fit(kernel_params)
# Out:
# -> Fitting with m, logc, logl: -2 8 5

# %%
# Plot the solution.

# Let's review the gridded visibilities first.
shape_f1d = (N_f1d, N_f1d)
u_f1d = FT._u_shifted.max()
v_f1d = FT._v_shifted.max()

I_f1d = GM.sol.reshape(shape_f1d).real
V_f1d = np.fft.fftshift(np.fft.ifft2(I_f1d))

plt.figure(figsize = (4, 4))

fig, axs = plt.subplots(1, 2, figsize=(9, 9))
axs = axs.ravel()

im0 = axs[0].imshow(np.log(np.abs(V_f1d) + 1e-12),  # evita log(0)
                    extent=[-u_f1d, u_f1d, -v_f1d, v_f1d],
                    cmap="magma")
axs[0].set_xlabel(r'u [1e6 $\lambda$]')
axs[0].set_ylabel(r'v [1e6 $\lambda$]')
axs[0].set_title(r'$\log\,|Vis_{Model}|$')
cbar0 = fig.colorbar(im0, ax=axs[0], shrink=0.3)
cbar0.set_label(r'V [Jy]', size=10)
axs[0].set_aspect('equal')

# Panel 2
im1 = axs[1].imshow(I_f1d,
                    extent=[-r_out, r_out, -r_out, r_out],
                    cmap="magma")
axs[1].set_xlabel(r'x ["]')
axs[1].set_ylabel(r'y ["]')
axs[1].set_title(r'$I_{Model}$')
cbar1 = fig.colorbar(im1, ax=axs[1], shrink=0.3)
cbar1.set_label(r'I [Jy/sr]', size=10)
axs[1].set_aspect('equal')

plt.tight_layout()

# %%
# Calculate -log posterior
GM.m_log_posterior()
# Out:
# --> Calculating m_log_posterior with m, logc, logl:  -2 8 5
# + 0.50 seconds for S_real_inv
# + 0.12 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# -126439742.8876037

# %% [markdown]
# ### Several $logP(\sigma | V)$

# %%
m_min, m_max = -6, -2
logc_min, logc_max = 8, 30

nx, ny = 3, 3
m = np.linspace(m_min, m_max, nx)
logc = np.linspace(logc_min, logc_max, ny)
X, Y = np.meshgrid(m, logc)

m_array = X.flatten()
log_c_array = Y.flatten()

# %%
minus_log_likelihood_array = []
intensity_array = []
logdetS_array = []
logdetD_array = []
jTDj_array = []

for i in range(0, len(m_array)):
    minus_log_likelihood = GM.m_log_posterior([m_array[i], log_c_array[i], 4])
    logdetS, logdetD, jTDj = GM.logdetS, GM.logdetD, GM.jTDj
    minus_log_likelihood_array.append(minus_log_likelihood)
    logdetS_array.append(logdetS)
    logdetD_array.append(logdetD)
    jTDj_array.append(jTDj)
    intensity_array.append(GM.sol)
    print(f"---------------------------- (m, log_c):({m_array[i]}, {log_c_array[i]}) with likelihood: {minus_log_likelihood: 2e}")
# Out:
# --> Calculating m_log_posterior with m, logc, logl:  -6.0 8.0 4
# + 0.48 seconds for S_real_inv
# + 4.18 seconds for mu
# + 0.18 seconds for log|S|
# + 0.17 seconds for |D|
# --> In total 0.17 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-6.0, 8.0) with likelihood:  1.493834e-07
# --> Calculating m_log_posterior with m, logc, logl:  -4.0 8.0 4
# + 0.51 seconds for S_real_inv
# + 4.12 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-4.0, 8.0) with likelihood:  2.617385e+02
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 8.0 4
# + 0.47 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-2.0, 8.0) with likelihood: -1.263851e+08
# --> Calculating m_log_posterior with m, logc, logl:  -6.0 19.0 4
# + 0.48 seconds for S_real_inv
# + 4.13 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-6.0, 19.0) with likelihood:  1.542674e+04
# --> Calculating m_log_posterior with m, logc, logl:  -4.0 19.0 4
# + 0.52 seconds for S_real_inv
# + 0.12 seconds for mu
# + 0.18 seconds for log|S|
# + 0.19 seconds for |D|
# --> In total 0.19 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-4.0, 19.0) with likelihood: -1.263880e+08
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 19.0 4
# + 0.52 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-2.0, 19.0) with likelihood: -1.263534e+08
# --> Calculating m_log_posterior with m, logc, logl:  -6.0 30.0 4
# + 0.51 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.18 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-6.0, 30.0) with likelihood: -1.268269e+08
# --> Calculating m_log_posterior with m, logc, logl:  -4.0 30.0 4
# + 0.53 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-4.0, 30.0) with likelihood: -1.263556e+08
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 30.0 4
# + 0.49 seconds for S_real_inv
# + 0.12 seconds for mu
# + 0.18 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# ---------------------------- (m, log_c):(-2.0, 30.0) with likelihood: -1.263218e+08

# %%
fig, axs = plt.subplots(2, 2, figsize=(9, 6), constrained_layout=True)
axs = axs.ravel()

norm = colors.CenteredNorm()

fig.suptitle(r'$-logP(\sigma | V) =  \frac{1}{2}log|S| -\frac{1}{2}log|D| - \frac{1}{2}jTDj$', fontsize=10)


Z0 = np.array(minus_log_likelihood_array).reshape(ny, nx) / 1e9
pcm0 = axs[0].pcolormesh(X, Y, Z0, shading='auto', cmap="magma")
axs[0].set_xlabel(r"$m$")
axs[0].set_ylabel(r"$\log_{10} c$")
cbar0 = fig.colorbar(pcm0, ax=axs[0], shrink=0.9)
cbar0.set_label(r"$-\log \mathcal{P}(\theta \mid X) \,/\,10^9$")

Z1 = np.array(logdetS_array).reshape(nx, ny)/1e9
pcm1 = axs[1].pcolormesh(X, Y, Z1, shading='auto', cmap="magma")
axs[1].set_xlabel(r"$m$")
axs[1].set_ylabel(r"$\log_{10} c$")
cbar1 = fig.colorbar(pcm1, ax=axs[1], shrink=0.9)
cbar1.set_label(r"$-log|S|/\,10^9$")

Z2 = np.array(logdetD_array).reshape(nx, ny)/1e9
pcm2 = axs[2].pcolormesh(X, Y, Z2, shading='auto', cmap="magma")
axs[2].set_xlabel(r"$m$")
axs[2].set_ylabel(r"$\log_{10} c$")
cbar2 = fig.colorbar(pcm2, ax=axs[2], shrink=0.9)
cbar2.set_label(r"$-log|D|/\,10^9$")

Z3 = np.array(jTDj_array).reshape(nx, ny)/1e9
pcm3 = axs[3].pcolormesh(X, Y, Z0, shading='auto', cmap="magma")
axs[3].set_xlabel(r"$m$")
axs[3].set_ylabel(r"$\log_{10} c$")
cbar3 = fig.colorbar(pcm3, ax=axs[3], shrink=0.9)
cbar3.set_label(r"$-jTDj/\,10^9$")

# %% [markdown]
# ## MAP value

# %% [markdown]
# ###  e.g. scipy minimizer

# %%
# this is a dummy run with maxiter = 10.

# %%
GM.optimize_posterior(method="scipy")
# Out:
# ....................................OPTIMIZING..................................
#  ---> Initial parameters: m, logc, logl: -2 8 5
#  ---> Bounds for m, logc, logl: (-6, -1.9) (7, 30) (5, 6.5)
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 8.0 5.0
# + 0.56 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.0000000298023224 8.0 5.0
# + 0.50 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.20 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 8.00000011920929 5.0
# + 0.50 seconds for S_real_inv
# + 0.13 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.0 8.0 5.000000074505806
# + 0.51 seconds for S_real_inv
# + 0.14 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |barrier param|CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------------|-------|
# |   1   |   4   |   0   | -1.2644e+08 | 1.00e+00 | 7.26e+05 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   0   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.629767527011366 8.002476182888774 5.401647043282568
# + 0.50 seconds for S_real_inv
# + 4.33 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.629767566197956 8.002476182888774 5.401647043282568
# + 0.51 seconds for S_real_inv
# + 4.32 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.629767527011366 8.002476302134962 5.401647043282568
# + 0.50 seconds for S_real_inv
# + 4.36 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.629767527011366 8.002476182888774 5.401647123773381
# + 0.50 seconds for S_real_inv
# + 4.36 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# |   2   |   8   |   1   | -1.3097e+08 | 7.00e+00 | 1.14e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -3.290005500949216 7.9012365848119455 5.638007362908618
# + 0.50 seconds for S_real_inv
# + 4.32 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.2900055499741185 7.9012365848119455 5.638007362908618
# + 0.52 seconds for S_real_inv
# + 4.75 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.290005500949216 7.901236702549546 5.638007362908618
# + 0.51 seconds for S_real_inv
# + 4.49 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.290005500949216 7.9012365848119455 5.638007446921474
# + 0.49 seconds for S_real_inv
# + 4.42 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# |   3   |  12   |   4   | -1.3097e+08 | 8.36e-01 | 1.14e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   1   |
# --> Calculating m_log_posterior with m, logc, logl:  -3.166956767643917 7.922956082817487 5.592534950363719
# + 0.49 seconds for S_real_inv
# + 4.72 seconds for mu
# + 0.17 seconds for log|S|
# + 0.17 seconds for |D|
# --> In total 0.17 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.1669568148352507 7.922956082817487 5.592534950363719
# + 0.52 seconds for S_real_inv
# + 4.55 seconds for mu
# + 0.18 seconds for log|S|
# + 0.17 seconds for |D|
# --> In total 0.17 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.166956767643917 7.922956200878733 5.592534950363719
# + 0.51 seconds for S_real_inv
# + 4.40 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -3.166956767643917 7.922956082817487 5.592535033698984
# + 0.49 seconds for S_real_inv
# + 4.46 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# |   4   |  16   |   5   | -1.3097e+08 | 4.18e-01 | 1.14e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.851563142556444 7.999200986393284 5.506511582361569
# + 0.49 seconds for S_real_inv
# + 4.45 seconds for mu
# + 0.18 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.8515631850480463 7.999200986393284 5.506511582361569
# + 0.49 seconds for S_real_inv
# + 4.52 seconds for mu
# + 0.17 seconds for log|S|
# + 0.18 seconds for |D|
# --> In total 0.18 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.851563142556444 7.999201105590667 5.506511582361569
# + 0.50 seconds for S_real_inv
# + 4.56 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.851563142556444 7.999200986393284 5.506511664414986
# + 0.49 seconds for S_real_inv
# + 4.46 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# |   5   |  20   |   6   | -1.3097e+08 | 2.09e-01 | 1.14e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.694727643931099 7.995898407427726 5.426004888584728
# + 0.49 seconds for S_real_inv
# + 4.46 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.6947276840856698 7.995898407427726 5.426004888584728
# + 0.50 seconds for S_real_inv
# + 4.55 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.694727643931099 7.995898526575897 5.426004888584728
# + 0.49 seconds for S_real_inv
# + 4.46 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.694727643931099 7.995898407427726 5.426004969438502
# + 0.49 seconds for S_real_inv
# + 4.51 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# |   6   |  24   |   7   | -1.6201e+08 | 2.09e-01 | 5.33e+08 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.8255161960348465 7.999143083394798 5.493915752795685
# + 0.48 seconds for S_real_inv
# + 4.52 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.8255162381383188 7.999143083394798 5.493915752795685
# + 0.49 seconds for S_real_inv
# + 4.49 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.8255161960348465 7.999143202591318 5.493915752795685
# + 0.49 seconds for S_real_inv
# + 4.61 seconds for mu
# + 0.17 seconds for log|S|
# + 0.15 seconds for |D|
# --> In total 0.15 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.8255161960348465 7.999143083394798 5.493915834661409
# + 0.49 seconds for S_real_inv
# + 4.74 seconds for mu
# + 0.17 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# |   7   |  28   |   8   | -1.6201e+08 | 1.04e-01 | 5.33e+08 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.759497220759192 7.998931848762833 5.46179336108505
# + 0.49 seconds for S_real_inv
# + 4.88 seconds for mu
# + 0.19 seconds for log|S|
# + 0.16 seconds for |D|
# --> In total 0.16 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.759497261878905 7.998931848762833 5.46179336108505
# + 0.50 seconds for S_real_inv
# + 3.89 seconds for mu
# + 0.14 seconds for log|S|
# + 0.13 seconds for |D|
# --> In total 0.13 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.759497220759192 7.998931967956206 5.46179336108505
# + 0.45 seconds for S_real_inv
# + 3.61 seconds for mu
# + 0.13 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.759497220759192 7.998931848762833 5.461793442472113
# + 0.43 seconds for S_real_inv
# + 3.69 seconds for mu
# + 0.14 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# |   8   |  32   |   9   | -1.6201e+08 | 4.37e-02 | 5.33e+08 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.7216043724596135 7.997391964477573 5.441274113016448
# + 0.44 seconds for S_real_inv
# + 3.63 seconds for mu
# + 0.14 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.721604413014679 7.997391964477573 5.441274113016448
# + 0.44 seconds for S_real_inv
# + 3.72 seconds for mu
# + 0.14 seconds for log|S|
# + 0.13 seconds for |D|
# --> In total 0.13 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.7216043724596135 7.997392083647999 5.441274113016448
# + 0.45 seconds for S_real_inv
# + 3.62 seconds for mu
# + 0.14 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.7216043724596135 7.997391964477573 5.44127419409775
# + 0.42 seconds for S_real_inv
# + 3.58 seconds for mu
# + 0.15 seconds for log|S|
# + 0.13 seconds for |D|
# --> In total 0.13 seconds for -logP(param|data)
# |   9   |  36   |  10   | -3.6183e+08 | 3.06e-01 | 4.58e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
# --> Calculating m_log_posterior with m, logc, logl:  -2.813894362484151 8.00620835186709 5.406807494806441
# + 0.50 seconds for S_real_inv
# + 3.66 seconds for mu
# + 0.14 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.8138944044144445 8.00620835186709 5.406807494806441
# + 0.46 seconds for S_real_inv
# + 4.57 seconds for mu
# + 0.18 seconds for log|S|
# + 0.17 seconds for |D|
# --> In total 0.17 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.813894362484151 8.00620847116889 5.406807494806441
# + 0.46 seconds for S_real_inv
# + 3.91 seconds for mu
# + 0.14 seconds for log|S|
# + 0.12 seconds for |D|
# --> In total 0.12 seconds for -logP(param|data)
# --> Calculating m_log_posterior with m, logc, logl:  -2.813894362484151 8.00620835186709 5.406807575374151
# + 0.38 seconds for S_real_inv
# + 3.59 seconds for mu
# + 0.13 seconds for log|S|
# + 0.11 seconds for |D|
# --> In total 0.11 seconds for -logP(param|data)
# |  10   |  40   |  12   | -3.6183e+08 | 1.39e-01 | 4.58e+09 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   2   |
#
# The maximum number of function evaluations is exceeded.
# Number of iterations: 10, function evaluations: 40, CG iterations: 12, optimality: 4.58e+09, constraint violation: 0.00e+00, execution time: 2.7e+02 s.
# Optimization failed: The maximum number of function evaluations is exceeded.
# --> Best parameters founded for: m, logc, logl:  -2.7216043724596135 7.997391964477573 5.441274113016448
# --- 4.739757247765859 minutes to minimizing ---
# ....................................OPTIMIZING..................................

# %%
GM.plot_stats_optimization()

# %%
m_best, logc_best, logl_best = GM._best
GM.one_fit({"m":m_best, "logc": logc_best, "logl": logl_best})
# Out:
# -> Fitting with m, logc, logl: -2.7216043724596135 7.997391964477573 5.441274113016448

# %%
fig.suptitle(f' m = {m_best:.2f}, $log(c) $ =  {logc_best:.2f}, $log(l) $ =  {logl_best:.2f} (N = ' + str(N) + ')' , fontsize=10)

# Plot the solution.

# Let's review the gridded visibilities first.
shape_f1d = (N_f1d, N_f1d)
u_f1d = FT._u_shifted.max()
v_f1d = FT._v_shifted.max()

I_f1d = GM.sol.reshape(shape_f1d).real
V_f1d = np.fft.fftshift(np.fft.ifft2(I_f1d))

plt.figure(figsize = (4, 4))

fig, axs = plt.subplots(1, 2, figsize=(9, 9))
axs = axs.ravel()

im0 = axs[0].imshow(np.log(np.abs(V_f1d) + 1e-12),  # evita log(0)
                    extent=[-u_f1d, u_f1d, -v_f1d, v_f1d],
                    cmap="magma")
axs[0].set_xlabel(r'u [1e6 $\lambda$]')
axs[0].set_ylabel(r'v [1e6 $\lambda$]')
axs[0].set_title(r'$\log\,|Vis_{Model}|$')
cbar0 = fig.colorbar(im0, ax=axs[0], shrink=0.3)
cbar0.set_label(r'V [Jy]', size=10)
axs[0].set_aspect('equal')

# Panel 2
im1 = axs[1].imshow(I_f1d,
                    extent=[-r_out, r_out, -r_out, r_out],
                    cmap="magma")
axs[1].set_xlabel(r'x ["]')
axs[1].set_ylabel(r'y ["]')
axs[1].set_title(r'$I_{Model}$')
cbar1 = fig.colorbar(im1, ax=axs[1], shrink=0.3)
cbar1.set_label(r'I [Jy/sr]', size=10)
axs[1].set_aspect('equal')

plt.tight_layout()

# %% [markdown]
# ### e.g emcee run

# %%
os.environ["OMP_NUM_THREADS"] = "4"

# %%
# this is a dummy run with steps = 10.

# %%
GM.optimize_posterior(method="emcee")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 GM.optimize_posterior(method="emcee")
#
# NameError: name 'GM' is not defined

# %%
samples = GM.samples
logp = GM.samples_logp

# %%
m = samples[:, 0]
logc = samples[:, 1]
logl = samples[:, 2]
logp = logp

imax = np.argmax(logp)

# %%
plt.figure(figsize=(5.2, 4.4))
sc = plt.scatter(m, logc, c=logp, s=10, alpha=0.7, cmap="viridis")
plt.plot(m[imax], logc[imax], marker="*", ms=15, color="red", label="MAP")
plt.colorbar(sc, label=r"$\log P(\theta|X)$")
plt.xlabel(r"$m$")
plt.ylabel(r"$\log_{10} c$")
plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize=(7, 5), sharey=True)
axs[0].scatter(m, logp, s=6, alpha=0.5)
axs[0].set_xlabel(r"$m$")
axs[0].set_ylabel(r"$\log P$")
axs[0].plot(m[imax], logp[imax], marker="*", ms=15, color="red", label="MAP")


axs[1].set_ylabel(r"$\log P$")
axs[1].scatter(logc, logp, s=6, alpha=0.5)
axs[1].plot(logc[imax], logp[imax], marker="*", ms=15, color="red", label="MAP")
axs[1].set_xlabel(r"$\log_{10} c$")


axs[2].set_ylabel(r"$\log P$")
axs[2].scatter(logl, logp, s=6, alpha=0.5)
axs[2].plot(logl[imax], logp[imax], marker="*", ms=15, color="red", label="MAP")
axs[2].set_xlabel(r"$\log_{10} l$")

plt.tight_layout(); plt.show()

# %%
import corner
flat_samples = GM.samples

corner.corner(
    flat_samples,
    labels=[r"$m$", r"$\log_{10} c$", r"$\log_{10} l$" ],
    quantiles=[0.16, 0.5, 0.84],
    show_titles=True,
    bins=20
)
plt.show()
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
m_best, log_c_best, logl_best = GM._best
GM.one_fit({"m":m_best, "logc": logc_best, "logl": logl_best})
# Out:
# -> Fitting with m, logc, logl: -2.0338089648572306 7.997391964477573 5.980236135765783

# %%
fig.suptitle(f' m = {m_best:.2f}, $log(c) $ =  {logc_best:.2f}, $log(l) $ =  {logl_best:.2f} (N = ' + str(N) + ')' , fontsize=10)

# Plot the solution.

# Let's review the gridded visibilities first.
shape_f1d = (N_f1d, N_f1d)
u_f1d = FT._u_shifted.max()
v_f1d = FT._v_shifted.max()

I_f1d = GM.sol.reshape(shape_f1d).real
V_f1d = np.fft.fftshift(np.fft.ifft2(I_f1d))

plt.figure(figsize = (4, 4))

fig, axs = plt.subplots(1, 2, figsize=(9, 9))
axs = axs.ravel()

im0 = axs[0].imshow(np.log(np.abs(V_f1d) + 1e-12),  # evita log(0)
                    extent=[-u_f1d, u_f1d, -v_f1d, v_f1d],
                    cmap="magma")
axs[0].set_xlabel(r'u [1e6 $\lambda$]')
axs[0].set_ylabel(r'v [1e6 $\lambda$]')
axs[0].set_title(r'$\log\,|Vis_{Model}|$')
cbar0 = fig.colorbar(im0, ax=axs[0], shrink=0.3)
cbar0.set_label(r'V [Jy]', size=10)
axs[0].set_aspect('equal')

# Panel 2
im1 = axs[1].imshow(I_f1d,
                    extent=[-r_out, r_out, -r_out, r_out],
                    cmap="magma")
axs[1].set_xlabel(r'x ["]')
axs[1].set_ylabel(r'y ["]')
axs[1].set_title(r'$I_{Model}$')
cbar1 = fig.colorbar(im1, ax=axs[1], shrink=0.3)
cbar1.set_label(r'I [Jy/sr]', size=10)
axs[1].set_aspect('equal')

plt.tight_layout()
