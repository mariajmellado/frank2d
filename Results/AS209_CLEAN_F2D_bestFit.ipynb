# %% [markdown]
# # Imports

# %%
import os
import sys

# %%
current_dir =  os.getcwd()
# replace this following line in the path your frank2d files are.
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# frank2d
from frank2d import Frank2D
from frank2d.geometry import Geometry
from frank2d.posterior_optimization import *
from frank2d.constants import rad_to_arcsec, deg_to_rad
from frank2d.plot import Plot

# frank1d
from frank.utilities import UVDataBinner

# %% [markdown]
# ## Functions

# %%
def calculate_resolution( clean_beam, current_beam):
    bmaj_as = clean_beam['bmaj']
    bmin_as = clean_beam['bmin']
    final_bmaj_as = np.sqrt(bmaj_as**2 - current_beam**2)
    final_bmin_as = np.sqrt(bmin_as**2 - current_beam**2)
    print(f"-> Final beam to convolve with: {final_bmaj_as} x {final_bmin_as} arcsec")
    final_resolution = {'bmaj': final_bmaj_as, 'bmin': final_bmin_as, 'beam_pa': clean_beam['beam_pa']}
    return final_resolution

# %%
def calculate_resolution2( clean_beam, current_beam):
    from radio_beam import Beam
    bmaj_clean = clean_beam['bmaj']
    bmin_clean = clean_beam['bmin']
    bpa_deg_clean = clean_beam['beam_pa']

    bmaj_current = current_beam['bmaj']
    bmin_current = current_beam['bmin']
    bpa_deg_current = current_beam['beam_pa']

    beam_orig =  Beam(major=bmaj_current*u.arcsec, minor=bmin_current*u.arcsec, pa=bpa_deg_current)
    beam_target = Beam(major=bmaj_clean*u.arcsec, minor=bmin_clean*u.arcsec, pa=bpa_deg_clean)

    beam_final = beam_target.deconvolve(beam_orig)

    #return values in a dict
    final_resolution = {'bmaj': beam_final.major.to(u.arcsec).value,
                        'bmin': beam_final.minor.to(u.arcsec).value,
                        'beam_pa': beam_final.pa.to(u.deg).value}

    return final_resolution

# %%
def edges(x):
    mids = (x[1:] + x[:-1]) / 2.0
    first = x[0]  - (x[1] - x[0]) / 2.0
    last  = x[-1] + (x[-1] - x[-2]) / 2.0
    return np.r_[first, mids, last]

# %%
def get_profile( x1, x2, f, bins, weighted = False, weights = None, fit_1d = False):
    from scipy.stats import binned_statistic
    
    if not fit_1d:
        r = np.hypot(x1, x2)
        r = r.ravel(order = 'C')
        f = f.ravel(order = 'C')
    else:
        r = x1

    if weighted:
        if weights is None:
            raise ValueError("Add weights.")
        F_W_binned, bin_edges, _ = binned_statistic(r, f*weights, 'sum', bins = bins)
        Weights_binned, bin_edges, _ = binned_statistic(r, weights, 'sum', bins = bins)

        f_1d = np.nan_to_num(F_W_binned, nan=0)
        f_1d = f_1d/Weights_binned
    else:
        f_1d, bin_edges, _ = binned_statistic(r, f, 'mean', bins = bins)
    
    r_1d = (bin_edges[:-1] + bin_edges[1:]) / 2
        
    return r_1d, f_1d

# %% [markdown]
# # Data

# %%
AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2*2, 'disk_name': 'AS209'}
IMLup = {'inc': 47.5, 'pa': 144.5, 'dra':-1.5e-3, 'ddec':1e-3, 'rout': 1.71*2, 'disk_name': 'IMLup'}
Elias27 = {'inc': 56.2, 'pa': 118.8, 'dra':-5e-3, 'ddec':-8e-3, 'rout': 1.88*2, 'disk_name': 'Elias27'}
HD163296 = {'inc':46.7, 'pa':133.33, 'dra':-2.8e-3, 'ddec':7.7e-3, 'rout':1.7*2, 'disk_name': 'HD163296' }
Elias24 = {'inc': 29, 'pa': 45.7, 'dra':110.8e-3, 'ddec':-386.8e-3, 'rout': 1.03*2, 'disk_name': 'Elias24'}
HD143006 = {'inc': 18.6, 'pa': 169, 'dra':-5.9e-3, 'ddec':21.7e-3, 'rout': 0.518*3, 'disk_name': 'HD143006'}

# %%
data = AS209

# UVtable
dir = "../../data/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum.npz"

# Load data
file = np.load(data_file)
u, v, Re, Im, Weights = file['u'], file['v'], file['Re'], file['Im'], file['w']
Vis = Re + Im*1j

# %%
# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
rout = data['rout']

# %%
imsize = 3000

# %%
cell = 2*rout/imsize  # arcsec
cell
# Out:
# 0.0015999999999999999

# %%
geom_f2d = Geometry(inc, pa, dra, ddec)

# %%
uvtable = {'u': u, 'v': v, 'vis': Vis, 'weights': Weights}

# %%
best = {'m': -1.3620942401288272, 'c': 4681.245509195992, 'l': 72454.18892316935}

# %%
frank2d = Frank2D(imsize, rout)

# %%
start_time = time.time()
frank2d.fit(data = uvtable, kernel_params = best, rtol = 1e-8 )

end_time = time.time()
print(f"xxxxxxxxxxxxxxxxxxxxxxxxx F2D with N = {imsize} took {end_time - start_time} seconds xxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.3620942401288272, 'c': 4681.245509195992, 'l': 72454.18892316935}
# ===>  Creating sparse linear system...
#         + time kernel = 0.03  min |  1.90 seconds
#         + Using preconditioner method:  jacobi
#         + time building system = 0.03  min |  1.96 seconds
# ===>  Solving linear system...
#          + maxiter =  50000  & rtol =  1e-08
#          + final tolerance :  2.881752289367308
#                         .... iteration:  0
#                               -> actual tol  2.88e+08  versus  2.88e+00
#                         .... iteration:  1
#                               -> actual tol  2.63e+07  versus  2.88e+00
#                         .... iteration:  2
#                               -> actual tol  2.32e+07  versus  2.88e+00
#                         .... iteration:  3
#                               -> actual tol  2.32e+07  versus  2.88e+00
#                         .... iteration:  4
#                               -> actual tol  2.30e+07  versus  2.88e+00
#                         .... iteration:  5
#                               -> actual tol  2.22e+07  versus  2.88e+00
#                         .... iteration:  6
#                               -> actual tol  2.39e+07  versus  2.88e+00
#                         .... iteration:  7
#                               -> actual tol  3.08e+07  versus  2.88e+00
#                         .... iteration:  8
#                               -> actual tol  6.30e+07  versus  2.88e+00
#                         .... iteration:  9
#                               -> actual tol  1.43e+07  versus  2.88e+00
#                         .... iteration:  10
#                               -> actual tol  1.20e+07  versus  2.88e+00
#                         .... iteration:  11
#                               -> actual tol  1.14e+07  versus  2.88e+00
#                         .... iteration:  12
#                               -> actual tol  1.14e+07  versus  2.88e+00
#                         .... iteration:  13
#                               -> actual tol  1.09e+07  versus  2.88e+00
#                         .... iteration:  14
#                               -> actual tol  1.08e+07  versus  2.88e+00
#                         .... iteration:  15
#                               -> actual tol  1.46e+07  versus  2.88e+00
#                         .... iteration:  16
#                               -> actual tol  1.02e+07  versus  2.88e+00
#                         .... iteration:  17
#                               -> actual tol  9.17e+06  versus  2.88e+00
#                         .... iteration:  18
#                               -> actual tol  9.16e+06  versus  2.88e+00
#                         .... iteration:  19
#                               -> actual tol  9.53e+06  versus  2.88e+00
#                         .... iteration:  20
#                               -> actual tol  6.23e+06  versus  2.88e+00
#                         .... iteration:  21
#                               -> actual tol  6.57e+06  versus  2.88e+00
#                         .... iteration:  22
#                               -> actual tol  6.99e+06  versus  2.88e+00
#                         .... iteration:  23
#                               -> actual tol  5.42e+06  versus  2.88e+00
#                         .... iteration:  24
#                               -> actual tol  5.32e+06  versus  2.88e+00
#                         .... iteration:  25
#                               -> actual tol  5.02e+06  versus  2.88e+00
#                         .... iteration:  26
#                               -> actual tol  6.73e+06  versus  2.88e+00
#                         .... iteration:  27
#                               -> actual tol  1.07e+07  versus  2.88e+00
#                         .... iteration:  28
#                               -> actual tol  4.09e+06  versus  2.88e+00
#                         .... iteration:  29
#                               -> actual tol  4.06e+06  versus  2.88e+00
#                         .... iteration:  30
#                               -> actual tol  3.90e+06  versus  2.88e+00
#                         .... iteration:  31
#                               -> actual tol  2.84e+06  versus  2.88e+00
#                         .... iteration:  32
#                               -> actual tol  2.67e+06  versus  2.88e+00
#                         .... iteration:  33
#                               -> actual tol  3.55e+06  versus  2.88e+00
#                         .... iteration:  34
#                               -> actual tol  2.89e+06  versus  2.88e+00
#                         .... iteration:  35
#                               -> actual tol  2.24e+06  versus  2.88e+00
#                         .... iteration:  36
#                               -> actual tol  1.84e+06  versus  2.88e+00
#                         .... iteration:  37
#                               -> actual tol  1.81e+06  versus  2.88e+00
#                         .... iteration:  38
#                               -> actual tol  1.88e+06  versus  2.88e+00
#                         .... iteration:  39
#                               -> actual tol  1.59e+06  versus  2.88e+00
#                         .... iteration:  40
#                               -> actual tol  1.98e+06  versus  2.88e+00
#                         .... iteration:  41
#                               -> actual tol  2.69e+06  versus  2.88e+00
#                         .... iteration:  42
#                               -> actual tol  2.58e+06  versus  2.88e+00
#                         .... iteration:  43
#                               -> actual tol  8.49e+05  versus  2.88e+00
#                         .... iteration:  44
#                               -> actual tol  8.30e+05  versus  2.88e+00
#                         .... iteration:  45
#                               -> actual tol  8.43e+05  versus  2.88e+00
#                         .... iteration:  46
#                               -> actual tol  8.36e+05  versus  2.88e+00
#                         .... iteration:  47
#                               -> actual tol  5.80e+05  versus  2.88e+00
#                         .... iteration:  48
#                               -> actual tol  1.46e+06  versus  2.88e+00
#                         .... iteration:  49
#                               -> actual tol  4.42e+05  versus  2.88e+00
#                         .... iteration:  50
#                               -> actual tol  4.24e+05  versus  2.88e+00
#                         .... iteration:  51
#                               -> actual tol  3.59e+05  versus  2.88e+00
#                         .... iteration:  52
#                               -> actual tol  3.30e+05  versus  2.88e+00
#                         .... iteration:  53
#                               -> actual tol  3.66e+05  versus  2.88e+00
#                         .... iteration:  54
#                               -> actual tol  3.67e+05  versus  2.88e+00
#                         .... iteration:  55
#                               -> actual tol  4.95e+05  versus  2.88e+00
#                         .... iteration:  56
#                               -> actual tol  3.04e+05  versus  2.88e+00
#                         .... iteration:  57
#                               -> actual tol  3.08e+05  versus  2.88e+00
#                         .... iteration:  58
#                               -> actual tol  2.06e+05  versus  2.88e+00
#                         .... iteration:  59
#                               -> actual tol  1.98e+05  versus  2.88e+00
#                         .... iteration:  60
#                               -> actual tol  1.84e+05  versus  2.88e+00
#                         .... iteration:  61
#                               -> actual tol  2.30e+05  versus  2.88e+00
#                         .... iteration:  62
#                               -> actual tol  2.56e+05  versus  2.88e+00
#                         .... iteration:  63
#                               -> actual tol  2.49e+05  versus  2.88e+00
#                         .... iteration:  64
#                               -> actual tol  1.05e+05  versus  2.88e+00
#                         .... iteration:  65
#                               -> actual tol  1.30e+05  versus  2.88e+00
#                         .... iteration:  66
#                               -> actual tol  1.26e+05  versus  2.88e+00
#                         .... iteration:  67
#                               -> actual tol  1.21e+05  versus  2.88e+00
#                         .... iteration:  68
#                               -> actual tol  1.52e+05  versus  2.88e+00
#                         .... iteration:  69
#                               -> actual tol  1.50e+05  versus  2.88e+00
#                         .... iteration:  70
#                               -> actual tol  9.75e+04  versus  2.88e+00
#                         .... iteration:  71
#                               -> actual tol  4.82e+04  versus  2.88e+00
#                         .... iteration:  72
#                               -> actual tol  4.34e+04  versus  2.88e+00
#                         .... iteration:  73
#                               -> actual tol  4.29e+04  versus  2.88e+00
#                         .... iteration:  74
#                               -> actual tol  9.11e+04  versus  2.88e+00
#                         .... iteration:  75
#                               -> actual tol  2.94e+05  versus  2.88e+00
#                         .... iteration:  76
#                               -> actual tol  7.30e+04  versus  2.88e+00
#                         .... iteration:  77
#                               -> actual tol  8.45e+04  versus  2.88e+00
#                         .... iteration:  78
#                               -> actual tol  5.30e+04  versus  2.88e+00
#                         .... iteration:  79
#                               -> actual tol  4.20e+04  versus  2.88e+00
#                         .... iteration:  80
#                               -> actual tol  4.32e+04  versus  2.88e+00
#                         .... iteration:  81
#                               -> actual tol  4.29e+04  versus  2.88e+00
#                         .... iteration:  82
#                               -> actual tol  4.25e+04  versus  2.88e+00
#                         .... iteration:  83
#                               -> actual tol  4.52e+04  versus  2.88e+00
#                         .... iteration:  84
#                               -> actual tol  4.44e+04  versus  2.88e+00
#                         .... iteration:  85
#                               -> actual tol  4.23e+04  versus  2.88e+00
#                         .... iteration:  86
#                               -> actual tol  2.03e+04  versus  2.88e+00
#                         .... iteration:  87
#                               -> actual tol  2.20e+04  versus  2.88e+00
#                         .... iteration:  88
#                               -> actual tol  1.06e+05  versus  2.88e+00
#                         .... iteration:  89
#                               -> actual tol  1.51e+05  versus  2.88e+00
#                         .... iteration:  90
#                               -> actual tol  2.03e+05  versus  2.88e+00
#                         .... iteration:  91
#                               -> actual tol  2.38e+05  versus  2.88e+00
#                         .... iteration:  92
#                               -> actual tol  4.21e+04  versus  2.88e+00
#                         .... iteration:  93
#                               -> actual tol  2.23e+04  versus  2.88e+00
#                         .... iteration:  94
#                               -> actual tol  2.24e+04  versus  2.88e+00
#                         .... iteration:  95
#                               -> actual tol  1.95e+04  versus  2.88e+00
#                         .... iteration:  96
#                               -> actual tol  1.96e+04  versus  2.88e+00
#                         .... iteration:  97
#                               -> actual tol  1.88e+04  versus  2.88e+00
#                         .... iteration:  98
#                               -> actual tol  1.82e+04  versus  2.88e+00
#                         .... iteration:  99
#                               -> actual tol  1.81e+04  versus  2.88e+00
#                         .... iteration:  100
#                               -> actual tol  2.07e+04  versus  2.88e+00
#                         .... iteration:  101
#                               -> actual tol  1.66e+04  versus  2.88e+00
#                         .... iteration:  102
#                               -> actual tol  1.64e+04  versus  2.88e+00
#                         .... iteration:  103
#                               -> actual tol  1.66e+04  versus  2.88e+00
#                         .... iteration:  104
#                               -> actual tol  1.65e+04  versus  2.88e+00
#                         .... iteration:  105
#                               -> actual tol  1.62e+04  versus  2.88e+00
#                         .... iteration:  106
#                               -> actual tol  1.65e+04  versus  2.88e+00
#                         .... iteration:  107
#                               -> actual tol  1.77e+04  versus  2.88e+00
#                         .... iteration:  108
#                               -> actual tol  1.94e+04  versus  2.88e+00
#                         .... iteration:  109
#                               -> actual tol  2.39e+04  versus  2.88e+00
#                         .... iteration:  110
#                               -> actual tol  6.98e+03  versus  2.88e+00
#                         .... iteration:  111
#                               -> actual tol  5.13e+03  versus  2.88e+00
#                         .... iteration:  112
#                               -> actual tol  6.70e+03  versus  2.88e+00
#                         .... iteration:  113
#                               -> actual tol  8.08e+03  versus  2.88e+00
#                         .... iteration:  114
#                               -> actual tol  7.95e+03  versus  2.88e+00
#                         .... iteration:  115
#                               -> actual tol  7.92e+03  versus  2.88e+00
#                         .... iteration:  116
#                               -> actual tol  7.90e+03  versus  2.88e+00
#                         .... iteration:  117
#                               -> actual tol  8.30e+03  versus  2.88e+00
#                         .... iteration:  118
#                               -> actual tol  8.61e+03  versus  2.88e+00
#                         .... iteration:  119
#                               -> actual tol  8.43e+03  versus  2.88e+00
#                         .... iteration:  120
#                               -> actual tol  9.29e+03  versus  2.88e+00
#                         .... iteration:  121
#                               -> actual tol  4.77e+03  versus  2.88e+00
#                         .... iteration:  122
#                               -> actual tol  2.88e+03  versus  2.88e+00
#                         .... iteration:  123
#                               -> actual tol  2.58e+03  versus  2.88e+00
#                         .... iteration:  124
#                               -> actual tol  2.74e+03  versus  2.88e+00
#                         .... iteration:  125
#                               -> actual tol  2.67e+03  versus  2.88e+00
#                         .... iteration:  126
#                               -> actual tol  2.56e+03  versus  2.88e+00
#                         .... iteration:  127
#                               -> actual tol  2.55e+03  versus  2.88e+00
#                         .... iteration:  128
#                               -> actual tol  2.55e+03  versus  2.88e+00
#                         .... iteration:  129
#                               -> actual tol  2.64e+03  versus  2.88e+00
#                         .... iteration:  130
#                               -> actual tol  2.63e+03  versus  2.88e+00
#                         .... iteration:  131
#                               -> actual tol  2.63e+03  versus  2.88e+00
#                         .... iteration:  132
#                               -> actual tol  2.59e+03  versus  2.88e+00
#                         .... iteration:  133
#                               -> actual tol  2.63e+03  versus  2.88e+00
#                         .... iteration:  134
#                               -> actual tol  2.80e+03  versus  2.88e+00
#                         .... iteration:  135
#                               -> actual tol  3.86e+03  versus  2.88e+00
#                         .... iteration:  136
#                               -> actual tol  3.07e+03  versus  2.88e+00
#                         .... iteration:  137
#                               -> actual tol  2.04e+03  versus  2.88e+00
#                         .... iteration:  138
#                               -> actual tol  1.96e+03  versus  2.88e+00
#                         .... iteration:  139
#                               -> actual tol  1.95e+03  versus  2.88e+00
#                         .... iteration:  140
#                               -> actual tol  2.01e+03  versus  2.88e+00
#                         .... iteration:  141
#                               -> actual tol  1.57e+03  versus  2.88e+00
#                         .... iteration:  142
#                               -> actual tol  1.49e+03  versus  2.88e+00
#                         .... iteration:  143
#                               -> actual tol  1.46e+03  versus  2.88e+00
#                         .... iteration:  144
#                               -> actual tol  1.44e+03  versus  2.88e+00
#                         .... iteration:  145
#                               -> actual tol  1.42e+03  versus  2.88e+00
#                         .... iteration:  146
#                               -> actual tol  1.37e+03  versus  2.88e+00
#                         .... iteration:  147
#                               -> actual tol  1.42e+03  versus  2.88e+00
#                         .... iteration:  148
#                               -> actual tol  1.12e+03  versus  2.88e+00
#                         .... iteration:  149
#                               -> actual tol  1.13e+03  versus  2.88e+00
#                         .... iteration:  150
#                               -> actual tol  1.07e+03  versus  2.88e+00
#                         .... iteration:  151
#                               -> actual tol  9.97e+02  versus  2.88e+00
#                         .... iteration:  152
#                               -> actual tol  5.85e+02  versus  2.88e+00
#                         .... iteration:  153
#                               -> actual tol  5.89e+02  versus  2.88e+00
#                         .... iteration:  154
#                               -> actual tol  5.82e+02  versus  2.88e+00
#                         .... iteration:  155
#                               -> actual tol  5.72e+02  versus  2.88e+00
#                         .... iteration:  156
#                               -> actual tol  5.47e+02  versus  2.88e+00
#                         .... iteration:  157
#                               -> actual tol  5.22e+02  versus  2.88e+00
#                         .... iteration:  158
#                               -> actual tol  5.13e+02  versus  2.88e+00
#                         .... iteration:  159
#                               -> actual tol  5.04e+02  versus  2.88e+00
#                         .... iteration:  160
#                               -> actual tol  5.13e+02  versus  2.88e+00
#                         .... iteration:  161
#                               -> actual tol  5.12e+02  versus  2.88e+00
#                         .... iteration:  162
#                               -> actual tol  5.49e+02  versus  2.88e+00
#                         .... iteration:  163
#                               -> actual tol  3.89e+02  versus  2.88e+00
#                         .... iteration:  164
#                               -> actual tol  3.89e+02  versus  2.88e+00
#                         .... iteration:  165
#                               -> actual tol  3.79e+02  versus  2.88e+00
#                         .... iteration:  166
#                               -> actual tol  3.66e+02  versus  2.88e+00
#                         .... iteration:  167
#                               -> actual tol  3.15e+02  versus  2.88e+00
#                         .... iteration:  168
#                               -> actual tol  2.67e+02  versus  2.88e+00
#                         .... iteration:  169
#                               -> actual tol  2.60e+02  versus  2.88e+00
#                         .... iteration:  170
#                               -> actual tol  2.56e+02  versus  2.88e+00
#                         .... iteration:  171
#                               -> actual tol  2.49e+02  versus  2.88e+00
#                         .... iteration:  172
#                               -> actual tol  2.41e+02  versus  2.88e+00
#                         .... iteration:  173
#                               -> actual tol  2.24e+02  versus  2.88e+00
#                         .... iteration:  174
#                               -> actual tol  2.05e+02  versus  2.88e+00
#                         .... iteration:  175
#                               -> actual tol  2.43e+02  versus  2.88e+00
#                         .... iteration:  176
#                               -> actual tol  1.58e+02  versus  2.88e+00
#                         .... iteration:  177
#                               -> actual tol  1.27e+02  versus  2.88e+00
#                         .... iteration:  178
#                               -> actual tol  1.20e+02  versus  2.88e+00
#                         .... iteration:  179
#                               -> actual tol  1.02e+02  versus  2.88e+00
#                         .... iteration:  180
#                               -> actual tol  9.70e+01  versus  2.88e+00
#                         .... iteration:  181
#                               -> actual tol  7.71e+01  versus  2.88e+00
#                         .... iteration:  182
#                               -> actual tol  4.67e+01  versus  2.88e+00
#                         .... iteration:  183
#                               -> actual tol  4.43e+01  versus  2.88e+00
#                         .... iteration:  184
#                               -> actual tol  1.11e+02  versus  2.88e+00
#                         .... iteration:  185
#                               -> actual tol  7.04e+01  versus  2.88e+00
#                         .... iteration:  186
#                               -> actual tol  6.79e+01  versus  2.88e+00
#                         .... iteration:  187
#                               -> actual tol  6.52e+01  versus  2.88e+00
#                         .... iteration:  188
#                               -> actual tol  6.46e+01  versus  2.88e+00
#                         .... iteration:  189
#                               -> actual tol  6.40e+01  versus  2.88e+00
#                         .... iteration:  190
#                               -> actual tol  6.48e+01  versus  2.88e+00
#                         .... iteration:  191
#                               -> actual tol  6.80e+01  versus  2.88e+00
#                         .... iteration:  192
#                               -> actual tol  5.06e+01  versus  2.88e+00
#                         .... iteration:  193
#                               -> actual tol  3.80e+01  versus  2.88e+00
#                         .... iteration:  194
#                               -> actual tol  4.14e+01  versus  2.88e+00
#                         .... iteration:  195
#                               -> actual tol  5.88e+01  versus  2.88e+00
#                         .... iteration:  196
#                               -> actual tol  5.11e+01  versus  2.88e+00
#                         .... iteration:  197
#                               -> actual tol  4.82e+01  versus  2.88e+00
#                         .... iteration:  198
#                               -> actual tol  4.95e+01  versus  2.88e+00
#                         .... iteration:  199
#                               -> actual tol  3.58e+01  versus  2.88e+00
#                         .... iteration:  200
#                               -> actual tol  3.66e+01  versus  2.88e+00
#                         .... iteration:  201
#                               -> actual tol  3.46e+01  versus  2.88e+00
#                         .... iteration:  202
#                               -> actual tol  3.38e+01  versus  2.88e+00
#                         .... iteration:  203
#                               -> actual tol  3.27e+01  versus  2.88e+00
#                         .... iteration:  204
#                               -> actual tol  3.24e+01  versus  2.88e+00
#                         .... iteration:  205
#                               -> actual tol  3.08e+01  versus  2.88e+00
#                         .... iteration:  206
#                               -> actual tol  2.96e+01  versus  2.88e+00
#                         .... iteration:  207
#                               -> actual tol  2.96e+01  versus  2.88e+00
#                         .... iteration:  208
#                               -> actual tol  2.88e+01  versus  2.88e+00
#                         .... iteration:  209
#                               -> actual tol  2.86e+01  versus  2.88e+00
#                         .... iteration:  210
#                               -> actual tol  2.84e+01  versus  2.88e+00
#                         .... iteration:  211
#                               -> actual tol  2.82e+01  versus  2.88e+00
#                         .... iteration:  212
#                               -> actual tol  2.94e+01  versus  2.88e+00
#                         .... iteration:  213
#                               -> actual tol  3.94e+01  versus  2.88e+00
#                         .... iteration:  214
#                               -> actual tol  2.19e+01  versus  2.88e+00
#                         .... iteration:  215
#                               -> actual tol  2.07e+01  versus  2.88e+00
#                         .... iteration:  216
#                               -> actual tol  2.00e+01  versus  2.88e+00
#                         .... iteration:  217
#                               -> actual tol  1.99e+01  versus  2.88e+00
#                         .... iteration:  218
#                               -> actual tol  1.83e+01  versus  2.88e+00
#                         .... iteration:  219
#                               -> actual tol  1.46e+01  versus  2.88e+00
#                         .... iteration:  220
#                               -> actual tol  1.48e+01  versus  2.88e+00
#                         .... iteration:  221
#                               -> actual tol  1.47e+01  versus  2.88e+00
#                         .... iteration:  222
#                               -> actual tol  1.43e+01  versus  2.88e+00
#                         .... iteration:  223
#                               -> actual tol  1.44e+01  versus  2.88e+00
#                         .... iteration:  224
#                               -> actual tol  1.42e+01  versus  2.88e+00
#                         .... iteration:  225
#                               -> actual tol  1.39e+01  versus  2.88e+00
#                         .... iteration:  226
#                               -> actual tol  1.46e+01  versus  2.88e+00
#                         .... iteration:  227
#                               -> actual tol  1.61e+01  versus  2.88e+00
#                         .... iteration:  228
#                               -> actual tol  9.98e+00  versus  2.88e+00
#                         .... iteration:  229
#                               -> actual tol  1.07e+01  versus  2.88e+00
#                         .... iteration:  230
#                               -> actual tol  1.04e+01  versus  2.88e+00
#                         .... iteration:  231
#                               -> actual tol  8.92e+00  versus  2.88e+00
#                         .... iteration:  232
#                               -> actual tol  8.06e+00  versus  2.88e+00
#                         .... iteration:  233
#                               -> actual tol  7.70e+00  versus  2.88e+00
#                         .... iteration:  234
#                               -> actual tol  7.60e+00  versus  2.88e+00
#                         .... iteration:  235
#                               -> actual tol  7.57e+00  versus  2.88e+00
#                         .... iteration:  236
#                               -> actual tol  7.52e+00  versus  2.88e+00
#                         .... iteration:  237
#                               -> actual tol  6.94e+00  versus  2.88e+00
#                         .... iteration:  238
#                               -> actual tol  6.50e+00  versus  2.88e+00
#                         .... iteration:  239
#                               -> actual tol  6.81e+00  versus  2.88e+00
#                         .... iteration:  240
#                               -> actual tol  6.92e+00  versus  2.88e+00
#                         .... iteration:  241
#                               -> actual tol  1.58e+01  versus  2.88e+00
#                         .... iteration:  242
#                               -> actual tol  9.03e+00  versus  2.88e+00
#                         .... iteration:  243
#                               -> actual tol  1.05e+01  versus  2.88e+00
#                         .... iteration:  244
#                               -> actual tol  6.48e+00  versus  2.88e+00
#                         .... iteration:  245
#                               -> actual tol  4.21e+00  versus  2.88e+00
#                         .... iteration:  246
#                               -> actual tol  4.16e+00  versus  2.88e+00
#                         .... iteration:  247
#                               -> actual tol  4.10e+00  versus  2.88e+00
#                         .... iteration:  248
#                               -> actual tol  3.96e+00  versus  2.88e+00
#                         .... iteration:  249
#                               -> actual tol  3.78e+00  versus  2.88e+00
#                         .... iteration:  250
#                               -> actual tol  3.50e+00  versus  2.88e+00
# converged by norm of s
#          + time BiCGStab = 0.75  min |  45.18 seconds
#           + CGM converged?   True
#           + Fit correctly?    ✔✔✔✔✔✔✔ CGM Sucess..
# Building full visibility model...
# --> times building full visibility model = 6.69  min |  401.43 seconds
# xxxxxxxxxxxxxxxxxxxxxxxxx F2D with N = 3000 took 469.3745777606964 seconds xxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
Plot_ = Plot(frank2d, geom_f2d)

# %%
Plot_.intensity(gamma=0.7, zoom=2)

# %% [markdown]
# ### Open fits file
# Of image regridded in CASA with imregrid, the same image from where we got the CLEAN model uvtable.

# %%
from astropy.io import fits
dir_  = "../../data/"
disk = 'CLEAN_AS209_dotimage_cellsize0p0016_imsize3000_regrid.fits' # this is the model regridded!

fits_name = dir_ + disk

# %%
hdul = fits.open(fits_name)

# %%
import matplotlib.colors as colors

# %% [markdown]
# ### CLEAN model imregridded

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

# %%
hdr = hdul[0].header
data = hdul[0].data

# %%
# beam
bmaj = hdr.get('BMAJ') # degrees
bmaj_arsec = bmaj * 3600 # arcseconds
bmin = hdr.get('BMIN')
bmin_arsec = bmin * 3600 # arcseconds
bpa = hdr.get('BPA')

# %%
w = WCS(hdr)

# %%
data_squeezed = np.squeeze(data)   # (3000,3000) si los ejes 1 desaparecen
print("shape original:", data.shape, "-> squeezed:", data_squeezed.shape)
# Out:
# shape original: (1, 1, 3000, 3000) -> squeezed: (3000, 3000)

# %%
data = data_squeezed

# %%
if data.ndim == 3:
    # asumo (nz, ny, nx)
    nz, ny, nx = data.shape
    if channel_index is None:
        # elige el canal central por defecto
        ci = nz // 2
    else:
        ci = int(channel_index)
    img = data[ci, :, :].copy()
    # build a WCS for the 2D plane (drop the spectral axis)
    w2 = w.celestial  # WCS restringido a ejes celestes (RA/Dec)
else:
    ny, nx = data.shape
    img = data.copy()
    w2 = w.celestial

# %%
# pixel coordinates
x = np.arange(nx)
y = np.arange(ny)
xx, yy = np.meshgrid(x, y)

# wcs expects pixel coords in 1-based -> use wcs_pix2world with origin=0
ra_deg, dec_deg = w2.wcs_pix2world(xx, yy, 0)  # devuelve en grados

# reference coordinate (CRVAL)
crval_ra = w2.wcs.crval[0]
crval_dec = w2.wcs.crval[1]
refcoord = SkyCoord(crval_ra*u.deg, crval_dec*u.deg)

# compute offsets in arcsec from reference coordinate
coords = SkyCoord(ra_deg*u.deg, dec_deg*u.deg)
lon_off, lat_off = coords.spherical_offsets_to(refcoord)
# convertir a arcsec, y poner el eje x como RA offset (positivo hacia el Este)
ra_off_arcsec = -lon_off.to(u.arcsec).value
dec_off_arcsec = lat_off.to(u.arcsec).value

# extent of the image in arcsec (for imshow)
xmin = ra_off_arcsec.min()
xmax = ra_off_arcsec.max()
ymin = dec_off_arcsec.min()
ymax = dec_off_arcsec.max()

# we need to flip the y axis to match the imshow convention
img = np.flipud(img)

# %%
cellsize_clean = np.abs(ra_off_arcsec[0][1]-ra_off_arcsec[0][0])

# %%
pixel_scale_x_as = cellsize_clean
pixel_scale_y_as = cellsize_clean

bmaj_pix = bmaj_as/pixel_scale_x_as
bmin_pix = bmin_as/pixel_scale_y_as
angle_display = 90.0 - bpa

# %%
rout*2 / imsize
# Out:
# 0.0015999999999999999

# %%
import matplotlib.patches as patches
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(6,5))
norm = colors.PowerNorm(gamma=0.7, vmin=0, vmax = img.max())
ax = plt.gca()

im = ax.imshow(
    img,
    extent=[xmin, xmax, ymax, ymin],
    aspect='equal',
    cmap='magma',
    norm=norm,
)

ax.set_xlabel('RA ["]')
ax.set_ylabel('Dec ["]')
ax.set_xlim(xmax/2, xmin/2)
ax.set_ylim(ymax/2, ymin/2)
ax.set_title(r'$I^{Model}_{CLEAN}$')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label( hdr.get('BUNIT'))
cbar.formatter = FuncFormatter(lambda x, pos: f"{x:.1e}")
cbar.update_ticks()
ax.grid(False)

xloc = xmin + 0.5 * (xmax - xmin)
yloc = ymin + 0.5 * (ymax - ymin)


beam = patches.Ellipse(
    (0.9, -0.9), 
    width=bmaj_as, 
    height=bmin_as, 
    angle=angle_display, 
    facecolor='white', 
    edgecolor='black', 
    linewidth=0.8, 
    zorder=5
)

ax.add_patch(beam)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# arcsecs per pixel
ra_off_arcsec[0][1] -ra_off_arcsec[0][0]
# Out:
# -0.0016000046066801943

# %% [markdown]
# ### Convolve f2d

# %%
I_f2d = frank2d.intensity_model

# %%
I_f2d.shape
# Out:
# (3000, 3000)

# %% [markdown]
# **Jy/sr $\implies$ Jy/beam**

# %%
FHWM_maj = bmaj_arsec / rad_to_arcsec
FHWM_min = bmin_arsec / rad_to_arcsec
omega = ( np.pi / 4 * np.log(2) ) * FHWM_maj * FHWM_min
I_f2d_Jybeam = I_f2d * omega

# %%
xmin = - (imsize/2) * cell
xmax = (imsize/2) * cell
ymin = - (imsize/2) * cell
ymax = (imsize/2) * cell


plt.figure(figsize=(6,5))
norm = colors.PowerNorm(gamma=0.7, vmin=0, vmax = I_f2d_Jybeam.max())
ax = plt.gca()

im = ax.imshow(
    I_f2d_Jybeam,
    extent=[xmin, xmax, ymax, ymin],
    aspect='equal',
    cmap='magma',
    norm=norm,
)

ax.set_xlabel('RA ["]')
ax.set_ylabel('Dec ["]')
ax.set_xlim(xmax/2, xmin/2)
ax.set_ylim(ymax/2, ymin/2)
ax.set_title(r'$I^{Model}_{frank2d}$')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Jy/beam')
cbar.formatter = FuncFormatter(lambda x, pos: f"{x:.1e}")
cbar.update_ticks()
ax.grid(False)

xloc = xmin + 0.5 * (xmax - xmin)
yloc = ymin + 0.5 * (ymax - ymin)

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Convolution**

# %%
FWHM_frank2d = 23.4e-3

# %%
# defining beams
from radio_beam import Beam
beam_orig =  Beam(major=FWHM_frank2d*u.arcsec, minor=FWHM_frank2d*u.arcsec, pa=0)
beam_target = Beam(major=bmaj_as*u.arcsec, minor=bmin_as*u.arcsec, pa=hdr['BPA']*u.deg)

# %%
# calculating convolution beam
conv_beam = beam_target.deconvolve(beam_orig)

# %%
recon_beam = conv_beam.convolve(beam_orig)
print("reconvolved: ", recon_beam)
# Out:
# Reconvolvido:  Beam: BMAJ=0.03821629285874 arcsec BMIN=0.03622492402851421 arcsec BPA=62.98761749268001 deg

# %%
# creating kernel in pixels
from astropy.convolution import convolve_fft, Gaussian2DKernel
pixscale = cellsize_clean
sigma_conv_pix = (conv_beam.major / (2.355 * pixscale)).decompose().value
kernel = Gaussian2DKernel(sigma_conv_pix)

# %%
cellsize_clean
# Out:
# 0.0016000046066801943

# %%
# convolve
I_f2d_Jybeam_conv = convolve_fft(I_f2d_Jybeam, kernel, boundary='wrap')

# %%
xmin = - (imsize/2) * cell
xmax = (imsize/2) * cell
ymin = - (imsize/2) * cell
ymax = (imsize/2) * cell

plt.figure(figsize=(6,5))
norm = colors.PowerNorm(gamma=0.7, vmin=0, vmax = I_f2d_Jybeam_conv.max())
ax = plt.gca()

im = ax.imshow(
    I_f2d_Jybeam_conv,
    extent=[xmin, xmax, ymax, ymin],
    aspect='equal',
    cmap='magma',
    norm=norm,
)

ax.set_xlabel('RA ["]')
ax.set_ylabel('Dec ["]')
ax.set_xlim(xmax/2, xmin/2)
ax.set_ylim(ymax/2, ymin/2)
ax.set_title(r'$I^{Model}_{frank2d}$ convolved')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Jy/beam')
cbar.formatter = FuncFormatter(lambda x, pos: f"{x:.1e}")
cbar.update_ticks()
ax.grid(False)


beam = patches.Ellipse(
    (0.9, -0.9), 
    width=bmaj_as, 
    height=bmin_as, 
    angle=angle_display, 
    facecolor='white', 
    edgecolor='black', 
    linewidth=0.8, 
    zorder=5
)

ax.add_patch(beam)

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Difference

# %%
diff = I_f2d_Jybeam_conv - img

plt.figure(figsize=(6,5))
norm = colors.PowerNorm(gamma=0.7, vmin=diff.min(), vmax = diff.max())
ax = plt.gca()

im = ax.imshow(
    diff,
    extent=[xmin, xmax, ymax, ymin],
    aspect='equal',
    cmap='magma',
    norm=norm,
)

ax.set_xlabel('RA ["]')
ax.set_ylabel('Dec ["]')
ax.set_xlim(xmax/2, xmin/2)
ax.set_ylim(ymax/2, ymin/2)
ax.set_title(r'|$I_{frank2d}^{Model}$ - $I_{CLEAN}^{Model}$|')


cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Jy/beam')
cbar.formatter = FuncFormatter(lambda x, pos: f"{x:.1e}")
cbar.update_ticks()
ax.grid(False)


beam = patches.Ellipse(
    (0.9, -0.9), 
    width=bmaj_as, 
    height=bmin_as, 
    angle=angle_display, 
    facecolor='white', 
    edgecolor='black', 
    linewidth=0.8, 
    zorder=5
)

ax.add_patch(beam)

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1D Profile

# %%
f2d = frank2d
geom = geom_f2d
inc, pa, dra, ddec = geom.inc, geom.pa, geom.dra, geom.ddec

# %%
from gofish import imagecube
cube_1mm = imagecube(fits_name)
x_clean, y_clean, dy_clean = cube_1mm.radial_profile(inc= inc, PA=pa, x0=dra, y0=ddec)
# Out:
# WARNING: Provided cube is only 2D. Shifting not available.
# WARNING: Attached data is not 3D, so shifting cannot be applied.
# 	 Reverting to standard azimuthal averaging; will ignore `unit` argument.

# %%
beam_frank2d = {'bmaj': FWHM_frank2d, 'bmin': FWHM_frank2d, 'beam_pa': 0}
beam_clean = {'bmaj': bmaj_as, 'bmin': bmin_as, 'beam_pa': hdr['BPA']}
final_beam_f2d = calculate_resolution2( beam_clean, beam_frank2d)

# %%
fits_image = fits.open(fits_name)
header = fits_image[0].header
bmaj_deg = float(header["BMAJ"])
bmin_deg = float(header["BMIN"])
bmaj_as = bmaj_deg * 3600.0
bmin_as = bmin_deg * 3600.0
bpa_deg = header['BPA']

clean_beam = {'bmaj': bmaj_as, 'bmin': bmin_as, 'beam_pa': bpa_deg}
clean_area = clean_beam['bmaj']*clean_beam['bmin']*np.pi/4./np.log(2.)*(1/rad_to_arcsec)**2
area = clean_area
print(f"Clean beam: {bmaj_as} x {bmin_as} arcsec")

beam_for_f2d = calculate_resolution(clean_beam, FWHM_frank2d)
beam_for_f2d = final_beam_f2d
# Out:
# Clean beam: 0.038216292858108 x 0.036224924027904 arcsec
# -> Final beam to convolve with: 0.030214649424024045 x 0.027652940545761426 arcsec

# %%
# f2d model
u_model = f2d.u_grid
v_model = f2d.v_grid
vis_model = f2d.visibility_model

u_model_1d = f2d.u
v_model_1d = f2d.v

x_model = f2d.x_grid * rad_to_arcsec
y_model = f2d.y_grid * rad_to_arcsec

x_model_1d = f2d.x * rad_to_arcsec
y_model_1d = f2d.y * rad_to_arcsec

        
# phase shift
vis = geom.apply_phase_shift(-u_model, -v_model, vis_model) # the East of North convention.
I = f2d.transform(vis).real

# deproject
x_model, y_model = geom.deproject_xy(x_model, y_model)
x_model_1d_d, y_model_1d_d = geom.deproject_xy(x_model_1d, y_model_1d)

# collocation points for the plot.
r = np.unique(np.hypot(x_model_1d_d, y_model_1d_d))
bins = 800
r = np.linspace(r.min(), r.max(), bins)
edges_ = edges(r)


r_model_1d, I_model_1d = get_profile(x_model, y_model, I, bins = edges_)
I_model_1d = np.nan_to_num(I_model_1d, nan=0)

# %%
from frank.utilities import convolve_profile
I_model_1d_convolved = convolve_profile(r_model_1d, I_model_1d, inc, pa, beam_for_f2d)
I_model_1d_convolved *= area # Jy/beam

# %%
plt.figure(figsize=(10,4))
#  CLEAN --------------------------------------------------------------------
plt.plot(x_clean, y_clean, "black", label = "CLEAN")
plt.fill_between(x_clean, y_clean-dy_clean, y_clean+dy_clean, alpha=0.7)
# frank2D -------------------------------------------------------------------
plt.plot(r_model_1d, I_model_1d_convolved, color = 'blue',ls ='--', label = r'frank2d')

plt.ylabel(r'log($I_\nu$) [Jy/beam]', size=10)
plt.xlabel('Radius ["]', size=10)
plt.legend(fontsize=12)
plt.yscale('log')
plt.title(f'Convolving Frank2D with FWHM beam: {FWHM_frank2d:.3f} x {FWHM_frank2d:.3f} arcsec')
plt.xlim(0, rout*0.6)
plt.ylim(1e-7, 0.5e-2)
plt.show()

# %%
import pickle

path_f1d = "../../data/f1d_N1100_a1p05_w1em4_r2p4.pkl"

# Abrir y cargar el objeto
with open(path_f1d, 'rb') as f:   # 'rb' = read binary
    f1d = pickle.load(f)

# %%
FWHM_frank1d = 14.7e-3

beam_frank1d = {'bmaj': FWHM_frank1d, 'bmin': FWHM_frank1d, 'beam_pa': 0}
final_beam_f1d = calculate_resolution2( clean_beam, beam_frank1d)

# %%
r_f1d = f1d.r
I_f1d = f1d.mean
I_f1d_convolved = convolve_profile(r_f1d[1:], I_f1d[1:], inc, pa, final_beam_f1d)
I_f1d_convolved *= area # Jy/beam

# %%
plt.figure(figsize=(10,4))
#  CLEAN --------------------------------------------------------------------
plt.plot(x_clean, y_clean, "black", label = "CLEAN")
plt.fill_between(x_clean, y_clean-dy_clean, y_clean+dy_clean, alpha=0.7)
# frank2D -------------------------------------------------------------------
plt.plot(r_model_1d, I_model_1d_convolved, color = 'blue',ls ='--', label = r'frank2d')
# frank1D -------------------------------------------------------------------
plt.plot(r_f1d[1:], I_f1d_convolved, color = 'red',ls ='-.', label = r'frank1d')

plt.ylabel(r'$I_\nu$ [Jy/beam]', size=10)
plt.xlabel('Radius ["]', size=10)
plt.legend(fontsize=12)
plt.yscale('log')
plt.title(f'')
plt.xlim(0.001, rout/2)
plt.ylim(5e-6, 3e-3)
plt.show()
