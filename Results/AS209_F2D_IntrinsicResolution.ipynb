# %%
import os
import sys
import numpy as np
import time
import scipy
import matplotlib.pyplot as plt
import time

# %%
# frank1d
import frank
from frank.geometry import FixedGeometry, SourceGeometry, FitGeometryGaussian
from frank.radial_fitters import FrankFitter
from frank.utilities import UVDataBinner
from frank.utilities import convolve_profile

# %%
# import the frank2d directory
current_dir =  os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.append(parent_dir)

#frank2d
from frank2d.frank2d import Frank2D 
from frank2d.geometry import Geometry
from frank2d.constants import rad_to_arcsec
from frank2d.plot import Plot
from frank2d.fitting import IterativeSolverMethod

# %%
from scipy.special import j0
from scipy.stats import binned_statistic

# %%
from scipy.optimize import curve_fit

# %% [markdown]
# ### Functions

# %%
def gauss(r, sigma):
    return np.exp(-0.5*((r-rout/2.)/sigma)**2)

# %% [markdown]
# ### Load data

# %%
AS209 = {'inc': 34.97, 'pa': 85.76, 'dra':1.9e-3, 'ddec':-2.5e-3, 'rout': 1.2, 'disk_name': 'AS209'}

# %%
data = AS209

# UVtable
dir = "../../data/"
disk_name = data['disk_name']
data_file = dir +"uvtable_" + disk_name + "_continuum.npz"

# Load data
file = np.load(data_file)
u, v, Re, Im, Weights = file['u'], file['v'], file['Re'], file['Im'], file['w']
Vis = Re + Im*1j

# %%
# Huang 2018 
inc = data['inc']
pa = data['pa']
dra = data['dra']
ddec = data['ddec']
rout = data['rout']

# %%
geom_f2d = Geometry(inc, pa, dra, ddec)
geom_Ring = geom_f2d

# %%
Rmax = 3*rout
Qmax = max(np.hypot(u,v))
N = 4*(Rmax/rad_to_arcsec)*Qmax

# %%
from math import ceil

N = ceil(N)
N
# Out:
# 619

# %% [markdown]
# ### Create the ring in uv-space

# %%
# Deprojection
du, dv, _ = geom_f2d.deproject(u, v)
dbaseline = np.hypot(du, dv)

baseline = np.hypot(u, v)

# %%
baseline_ring = baseline
u_ring = u
v_ring = v

# %%
Re_ring = np.median(Re[np.where(baseline_ring<3e4)])*np.real(j0(2.*np.pi*(Rmax/rad_to_arcsec/2)*baseline_ring))

# %%
Imag_ring = np.zeros(len(Re))
Vis_ring = Re_ring + Imag_ring*1j

# %%
uvtable = {'u': u_ring, 'v': v_ring, 'vis': Vis_ring, 'weights': Weights}

# %% [markdown]
# ### Frank2D

# %%
N = 619

# %%
frank2d = Frank2D(N, Rmax)

# %%
frank2d.process_vis(uvtable)
# Out:
# ===>  Setting gridded data...

# %%
best = {'m': -1.3620943031521517, 'c': 4681.257567443593, 'l': 72454.22528223816}

# %%
frank2d.fit(kernel_params = best, rtol = 1e-10)
# Out:
# ===>  Creating sparse linear system...
#         +  Kernel = 0.12  min |  7.16 seconds
#         +  Building system = 0.12  min |  7.44 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  9.03e+07  versus  9.03e-03
#       .... iteration  10 :   actual tol  4.21e+07  versus  9.03e-03
#       .... iteration  20 :   actual tol  2.65e+07  versus  9.03e-03
#       .... iteration  30 :   actual tol  2.21e+07  versus  9.03e-03
#       .... iteration  40 :   actual tol  1.88e+07  versus  9.03e-03
#       .... iteration  50 :   actual tol  1.05e+07  versus  9.03e-03
#       .... iteration  60 :   actual tol  1.22e+08  versus  9.03e-03
#       .... iteration  70 :   actual tol  1.47e+07  versus  9.03e-03
#       .... iteration  80 :   actual tol  8.82e+06  versus  9.03e-03
#       .... iteration  90 :   actual tol  6.67e+06  versus  9.03e-03
#       .... iteration  100 :   actual tol  6.34e+06  versus  9.03e-03
#       .... iteration  110 :   actual tol  3.45e+06  versus  9.03e-03
#       .... iteration  120 :   actual tol  7.15e+06  versus  9.03e-03
#       .... iteration  130 :   actual tol  1.11e+07  versus  9.03e-03
#       .... iteration  140 :   actual tol  3.41e+06  versus  9.03e-03
#       .... iteration  150 :   actual tol  1.66e+06  versus  9.03e-03
#       .... iteration  160 :   actual tol  1.63e+06  versus  9.03e-03
#       .... iteration  170 :   actual tol  1.56e+06  versus  9.03e-03
#       .... iteration  180 :   actual tol  1.53e+06  versus  9.03e-03
#       .... iteration  190 :   actual tol  1.45e+06  versus  9.03e-03
#       .... iteration  200 :   actual tol  2.41e+06  versus  9.03e-03
#       .... iteration  210 :   actual tol  2.19e+06  versus  9.03e-03
#       .... iteration  220 :   actual tol  1.16e+06  versus  9.03e-03
#       .... iteration  230 :   actual tol  2.13e+06  versus  9.03e-03
#       .... iteration  240 :   actual tol  9.91e+05  versus  9.03e-03
#       .... iteration  250 :   actual tol  6.83e+05  versus  9.03e-03
#       .... iteration  260 :   actual tol  3.45e+05  versus  9.03e-03
#       .... iteration  270 :   actual tol  7.23e+05  versus  9.03e-03
#       .... iteration  280 :   actual tol  8.44e+05  versus  9.03e-03
#       .... iteration  290 :   actual tol  2.90e+05  versus  9.03e-03
#       .... iteration  300 :   actual tol  1.95e+06  versus  9.03e-03
#       .... iteration  310 :   actual tol  2.12e+06  versus  9.03e-03
#       .... iteration  320 :   actual tol  2.04e+06  versus  9.03e-03
#       .... iteration  330 :   actual tol  1.73e+06  versus  9.03e-03
#       .... iteration  340 :   actual tol  9.49e+04  versus  9.03e-03
#       .... iteration  350 :   actual tol  1.82e+05  versus  9.03e-03
#       .... iteration  360 :   actual tol  7.42e+04  versus  9.03e-03
#       .... iteration  370 :   actual tol  7.84e+04  versus  9.03e-03
#       .... iteration  380 :   actual tol  6.93e+04  versus  9.03e-03
#       .... iteration  390 :   actual tol  6.50e+04  versus  9.03e-03
#       .... iteration  400 :   actual tol  6.41e+04  versus  9.03e-03
#       .... iteration  410 :   actual tol  1.78e+05  versus  9.03e-03
#       .... iteration  420 :   actual tol  4.41e+04  versus  9.03e-03
#       .... iteration  430 :   actual tol  7.56e+04  versus  9.03e-03
#       .... iteration  440 :   actual tol  7.77e+04  versus  9.03e-03
#       .... iteration  450 :   actual tol  6.84e+04  versus  9.03e-03
#       .... iteration  460 :   actual tol  1.87e+04  versus  9.03e-03
#       .... iteration  470 :   actual tol  2.52e+04  versus  9.03e-03
#       .... iteration  480 :   actual tol  1.34e+04  versus  9.03e-03
#       .... iteration  490 :   actual tol  1.28e+04  versus  9.03e-03
#       .... iteration  500 :   actual tol  1.29e+04  versus  9.03e-03
#       .... iteration  510 :   actual tol  1.39e+04  versus  9.03e-03
#       .... iteration  520 :   actual tol  1.39e+04  versus  9.03e-03
#       .... iteration  530 :   actual tol  1.32e+04  versus  9.03e-03
#       .... iteration  540 :   actual tol  2.91e+04  versus  9.03e-03
#       .... iteration  550 :   actual tol  1.17e+04  versus  9.03e-03
#       .... iteration  560 :   actual tol  6.87e+03  versus  9.03e-03
#       .... iteration  570 :   actual tol  2.15e+03  versus  9.03e-03
#       .... iteration  580 :   actual tol  1.96e+03  versus  9.03e-03
#       .... iteration  590 :   actual tol  1.94e+03  versus  9.03e-03
#       .... iteration  600 :   actual tol  1.93e+03  versus  9.03e-03
#       .... iteration  610 :   actual tol  1.45e+03  versus  9.03e-03
#       .... iteration  620 :   actual tol  7.99e+03  versus  9.03e-03
#       .... iteration  630 :   actual tol  1.17e+03  versus  9.03e-03
#       .... iteration  640 :   actual tol  1.07e+03  versus  9.03e-03
#       .... iteration  650 :   actual tol  1.08e+03  versus  9.03e-03
#       .... iteration  660 :   actual tol  1.08e+03  versus  9.03e-03
#       .... iteration  670 :   actual tol  1.07e+03  versus  9.03e-03
#       .... iteration  680 :   actual tol  1.02e+03  versus  9.03e-03
#       .... iteration  690 :   actual tol  9.89e+02  versus  9.03e-03
#       .... iteration  700 :   actual tol  1.02e+03  versus  9.03e-03
#       .... iteration  710 :   actual tol  1.00e+03  versus  9.03e-03
#       .... iteration  720 :   actual tol  8.88e+02  versus  9.03e-03
#       .... iteration  730 :   actual tol  8.91e+02  versus  9.03e-03
#       .... iteration  740 :   actual tol  8.70e+02  versus  9.03e-03
#       .... iteration  750 :   actual tol  7.66e+02  versus  9.03e-03
#       .... iteration  760 :   actual tol  6.89e+02  versus  9.03e-03
#       .... iteration  770 :   actual tol  6.56e+02  versus  9.03e-03
#       .... iteration  780 :   actual tol  6.30e+02  versus  9.03e-03
#       .... iteration  790 :   actual tol  4.97e+02  versus  9.03e-03
#       .... iteration  800 :   actual tol  1.02e+03  versus  9.03e-03
#       .... iteration  810 :   actual tol  8.27e+02  versus  9.03e-03
#       .... iteration  820 :   actual tol  1.74e+03  versus  9.03e-03
#       .... iteration  830 :   actual tol  4.15e+02  versus  9.03e-03
#       .... iteration  840 :   actual tol  3.31e+02  versus  9.03e-03
#       .... iteration  850 :   actual tol  5.11e+01  versus  9.03e-03
#       .... iteration  860 :   actual tol  6.07e+01  versus  9.03e-03
#       .... iteration  870 :   actual tol  6.30e+01  versus  9.03e-03
#       .... iteration  880 :   actual tol  5.83e+01  versus  9.03e-03
#       .... iteration  890 :   actual tol  8.11e+01  versus  9.03e-03
#       .... iteration  900 :   actual tol  1.40e+02  versus  9.03e-03
#       .... iteration  910 :   actual tol  1.65e+02  versus  9.03e-03
#       .... iteration  920 :   actual tol  7.31e+01  versus  9.03e-03
#       .... iteration  930 :   actual tol  6.05e+01  versus  9.03e-03
#       .... iteration  940 :   actual tol  7.77e+01  versus  9.03e-03
#       .... iteration  950 :   actual tol  5.37e+01  versus  9.03e-03
#       .... iteration  960 :   actual tol  1.23e+01  versus  9.03e-03
#       .... iteration  970 :   actual tol  1.22e+01  versus  9.03e-03
#       .... iteration  980 :   actual tol  1.20e+01  versus  9.03e-03
#       .... iteration  990 :   actual tol  7.83e+00  versus  9.03e-03
#       .... iteration  1000 :   actual tol  1.14e+01  versus  9.03e-03
#       .... iteration  1010 :   actual tol  1.23e+01  versus  9.03e-03
#       .... iteration  1020 :   actual tol  1.56e+01  versus  9.03e-03
#       .... iteration  1030 :   actual tol  1.31e+01  versus  9.03e-03
#       .... iteration  1040 :   actual tol  1.13e+01  versus  9.03e-03
#       .... iteration  1050 :   actual tol  1.20e+01  versus  9.03e-03
#       .... iteration  1060 :   actual tol  1.23e+01  versus  9.03e-03
#       .... iteration  1070 :   actual tol  1.34e+01  versus  9.03e-03
#       .... iteration  1080 :   actual tol  6.05e+00  versus  9.03e-03
#       .... iteration  1090 :   actual tol  1.06e+01  versus  9.03e-03
#       .... iteration  1100 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1110 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1120 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1130 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1140 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1150 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1160 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1170 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1180 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1190 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1200 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1210 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1220 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1230 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1240 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1250 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1260 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1270 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1280 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1290 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1300 :   actual tol  7.59e+00  versus  9.03e-03
#       .... iteration  1310 :   actual tol  7.58e+00  versus  9.03e-03
#       .... iteration  1320 :   actual tol  7.50e+00  versus  9.03e-03
#       .... iteration  1330 :   actual tol  7.44e+00  versus  9.03e-03
#       .... iteration  1340 :   actual tol  7.43e+00  versus  9.03e-03
#       .... iteration  1350 :   actual tol  7.31e+00  versus  9.03e-03
#       .... iteration  1360 :   actual tol  7.32e+00  versus  9.03e-03
#       .... iteration  1370 :   actual tol  7.34e+00  versus  9.03e-03
#       .... iteration  1380 :   actual tol  6.88e+00  versus  9.03e-03
#       .... iteration  1390 :   actual tol  7.45e+00  versus  9.03e-03
#       .... iteration  1400 :   actual tol  7.22e+00  versus  9.03e-03
#       .... iteration  1410 :   actual tol  7.34e+00  versus  9.03e-03
#       .... iteration  1420 :   actual tol  6.89e+00  versus  9.03e-03
#       .... iteration  1430 :   actual tol  6.96e+00  versus  9.03e-03
#       .... iteration  1440 :   actual tol  3.88e+00  versus  9.03e-03
#       .... iteration  1450 :   actual tol  7.44e+00  versus  9.03e-03
#       .... iteration  1460 :   actual tol  7.13e+00  versus  9.03e-03
#       .... iteration  1470 :   actual tol  3.87e+00  versus  9.03e-03
#       .... iteration  1480 :   actual tol  3.40e+00  versus  9.03e-03
#       .... iteration  1490 :   actual tol  4.59e+00  versus  9.03e-03
#       .... iteration  1500 :   actual tol  4.42e+00  versus  9.03e-03
#       .... iteration  1510 :   actual tol  5.16e+00  versus  9.03e-03
#       .... iteration  1520 :   actual tol  5.31e+00  versus  9.03e-03
#       .... iteration  1530 :   actual tol  2.35e+01  versus  9.03e-03
#       .... iteration  1540 :   actual tol  2.06e+01  versus  9.03e-03
#       .... iteration  1550 :   actual tol  1.89e+01  versus  9.03e-03
#       .... iteration  1560 :   actual tol  1.49e+01  versus  9.03e-03
#       .... iteration  1570 :   actual tol  9.43e+00  versus  9.03e-03
#       .... iteration  1580 :   actual tol  5.79e+00  versus  9.03e-03
#       .... iteration  1590 :   actual tol  5.87e+00  versus  9.03e-03
#       .... iteration  1600 :   actual tol  1.33e+00  versus  9.03e-03
#       .... iteration  1610 :   actual tol  8.47e-01  versus  9.03e-03
#       .... iteration  1620 :   actual tol  3.17e-01  versus  9.03e-03
#       .... iteration  1630 :   actual tol  1.43e-01  versus  9.03e-03
#       .... iteration  1640 :   actual tol  2.20e-02  versus  9.03e-03
#       .... iteration  1650 :   actual tol  6.90e-02  versus  9.03e-03
#          +  BiCGStab = 4.48  min |  268.89 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of s',
#  'final_tol': 0.009028797055763654,
#  'iterations': 1657,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.16  min |  9.54 seconds
# --> times building full visibility model = 0.16  min |  9.65 seconds

# %%
Plot_ = Plot(frank2d, geom_Ring)

# %%
Plot_.intensity(vmax = 5e10, zoom = 1)

# %% [markdown]
# ### Best

# %%
frank2d.search_MAP()
# Out:
# Using existing visibility data...
# !!!!!!!!! 1012855.8556767445
# Fitting the visibilities with Frank2D with 2DFT...
#  + Time to preprocess the visibilities: 281.21 seconds
# Setting the initial guess...
# Optimizing the posterior...

# %%
best = frank2d.MAP
best
# Out:
# {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}

# %%
best ={'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}

# %% [markdown]
# ### Run a new Frank2D Object

# %%
best = {'m': -1.2280363156419676, 'c': 180000.63036415094, 'l': 31207.587861481617}

# %%
N = 1100

# %%
frank2d2 = Frank2D(N, rout, geom_f2d)

# %%
frank2d2.fit( data = uvtable, kernel_params = best, rtol = 1e-8)
# Out:
# ===>  Setting gridded data...
# ===>  Setting GP Kernel Wendland...
#      + Kernel parameters:  {'m': -1.2280363156419676, 'c': 180000.63036415094, 'l': 31207.587861481617}
# ===>  Creating sparse linear system...
#     + time kernel = 0.01  min |  0.85 seconds
# Using preconditioner method:  jacobi
#     + time building system = 0.01  min |  0.86 seconds
# ===>  Solving linear system...
#      + maxiter =  50000  & rtol =  1e-08
#          * rtol: 1e-08
#          * final tolerance: 1.846797792829358
#      + final tolerance :  1.846797792829358
#                        .... iteration:  0
#                         -> actual tol:  184679779.2829358  vs  1.846797792829358
#                        .... iteration:  1
#                         -> actual tol:  16037615.545594981  vs  1.846797792829358
#                        .... iteration:  2
#                         -> actual tol:  8041188.505822175  vs  1.846797792829358
#                        .... iteration:  3
#                         -> actual tol:  4188509.106008183  vs  1.846797792829358
#                        .... iteration:  4
#                         -> actual tol:  2230947.5576259336  vs  1.846797792829358
#                        .... iteration:  5
#                         -> actual tol:  1629071.8700219283  vs  1.846797792829358
#                        .... iteration:  6
#                         -> actual tol:  1149285.643756264  vs  1.846797792829358
#                        .... iteration:  7
#                         -> actual tol:  563799.817569151  vs  1.846797792829358
#                        .... iteration:  8
#                         -> actual tol:  461253.3757862745  vs  1.846797792829358
#                        .... iteration:  9
#                         -> actual tol:  243264.7100117964  vs  1.846797792829358
#                        .... iteration:  10
#                         -> actual tol:  116253.09998111457  vs  1.846797792829358
#                        .... iteration:  11
#                         -> actual tol:  45943.75641653586  vs  1.846797792829358
#                        .... iteration:  12
#                         -> actual tol:  50419.42728990424  vs  1.846797792829358
#                        .... iteration:  13
#                         -> actual tol:  23531.423243234105  vs  1.846797792829358
#                        .... iteration:  14
#                         -> actual tol:  5291.2800606714645  vs  1.846797792829358
#                        .... iteration:  15
#                         -> actual tol:  19840.798905448126  vs  1.846797792829358
#                        .... iteration:  16
#                         -> actual tol:  1033.6299263159738  vs  1.846797792829358
#                        .... iteration:  17
#                         -> actual tol:  436.52209084763376  vs  1.846797792829358
#                        .... iteration:  18
#                         -> actual tol:  389.1393120133249  vs  1.846797792829358
#                        .... iteration:  19
#                         -> actual tol:  187.1387688741306  vs  1.846797792829358
#                        .... iteration:  20
#                         -> actual tol:  129.885957176173  vs  1.846797792829358
#                        .... iteration:  21
#                         -> actual tol:  527.129063205929  vs  1.846797792829358
#                        .... iteration:  22
#                         -> actual tol:  83.8560589481412  vs  1.846797792829358
#                        .... iteration:  23
#                         -> actual tol:  12.208082470263601  vs  1.846797792829358
#                        .... iteration:  24
#                         -> actual tol:  4.747009703374723  vs  1.846797792829358
#                        .... iteration:  25
#                         -> actual tol:  3.833726522235454  vs  1.846797792829358
#                        .... iteration:  26
#                         -> actual tol:  2.2113639449628972  vs  1.846797792829358
#                        .... iteration:  27
#                         -> actual tol:  1.5996418584968102  vs  1.846797792829358
#          + CGM converged in  27  iterations with tol  1.5996418584968102
#     + time = 0.00  min |  0.20 seconds
#      + CGM converged?   True
#          ✘✘✘✘✘✘ CGM Failed..
#      + Fit correctly?   None
# Building full visibility model...
# --> times building full visibility model = 0.33  min |  19.90 seconds

# %% [markdown]
# ### Plot

# %%
Plot_ = Plot(frank2d, geom_Ring)

# %%
Plot_.visibility(fig_size = 4, kind = 'input',  title= r'$log|V_{input}|$')

# %%
Plot_.visibility(fig_size = 4, title= r'$log|V_{model}|$')

# %%
Plot_.intensity(fig_size = 6)

# %% [markdown]
# ### Try with different N's

# %%
Ns = [ceil(0.5*N), ceil(N), ceil(1.25*N), ceil(1.5*N), ceil(1.75*N), ceil(2*N), ceil(2.5*N), ceil(3*N)]

# %%
Ns
# Out:
# [310, 619, 774, 929, 1084, 1238, 1548, 1857]

# %%
resolutions = []
resolutions_error = []

# %%
for N in Ns:
    print("xxxxxxxxxxxxxxxxxxxxxx N =", N, " xxxxxxxxxxxxxxxxxxxxxx")
    frank2d2 = Frank2D(N, Rmax)
    frank2d2.fit( data = uvtable, kernel_params = best, rtol = 1e-10)
    Plot_ = Plot(frank2d2, geom_f2d)
    Plot_.intensity(fig_size = 4, zoom=1)
    Plot_.visibility(fig_size = 4, kind = 'input',  title= r'$log|V_{input}|$')

    def gauss(r, sigma):
        return np.exp(-0.5*((r-Rmax/2.)/sigma)**2)

    # FWHM
    # deproject
    x_model_1d, y_model_1d = geom_f2d.deproject_xy(Plot_._x_model_1d, Plot_._y_model_1d)
    x_model, y_model = Plot_._x_model, Plot_._y_model

    I = Plot_._int_model

    r_ = np.unique(np.hypot(x_model_1d, y_model_1d))
    bins_f2d = 2*N
    r = np.linspace(r_.min(), r_.max(), bins_f2d)
    edges = Plot_.edges(r)

    r_f2d, I_f2d = Plot_.get_profile(x_model, y_model, I, bins = edges)
    I_f2d = np.nan_to_num(I_f2d, nan=0)

    popt_frank2d, cov = curve_fit(gauss, r_f2d, I_f2d/np.max(I_f2d), p0=[0.09])
    FWHM_frank2d = popt_frank2d[0]* 2. *np.sqrt(2.*np.log(2.))
    Error_FWHM_f2d = np.sqrt(cov[0][0])* 2. *np.sqrt(2.*np.log(2.)) 

    plt.close()
    plt.figure(figsize=(6,3))
    plt.plot(r_f2d, I_f2d, color='C0',label= r'Frank2D Solution, $N^{2}$ pixels with N = ' + str(N))
    plt.plot(r_f2d, gauss(r_f2d, *popt_frank2d)*np.max(I_f2d), color='C1', label='Fit, FWHM=%.1f mas'%(FWHM_frank2d*1000))
    plt.ylabel(r'I [Jy/$sr^{-1}$]')
    plt.xlabel('r ["]')
    plt.xlim(1.5, 2.5)
    plt.ylim(-1e10, 1e11)

    plt.title(r'F2D: $\delta$ Ring, $N_{bins}$ = '+ str(bins_f2d))
    plt.legend(loc='best', fontsize = 9)
    
    resolutions.append(FWHM_frank2d)
    resolutions_error.append(Error_FWHM_f2d)

    print ('FWHM=', FWHM_frank2d, '+/-', Error_FWHM_f2d, 'arcsec')
# Out:
# xxxxxxxxxxxxxxxxxxxxxx N = 310  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.03  min |  1.94 seconds
#         +  Building system = 0.03  min |  1.97 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  1.13e+08  versus  1.13e-02
#       .... iteration  10 :   actual tol  1.26e+06  versus  1.13e-02
#       .... iteration  20 :   actual tol  1.24e+05  versus  1.13e-02
#       .... iteration  30 :   actual tol  8.55e+02  versus  1.13e-02
#       .... iteration  40 :   actual tol  1.26e+01  versus  1.13e-02
#       .... iteration  50 :   actual tol  1.06e+00  versus  1.13e-02
#       .... iteration  60 :   actual tol  1.23e-02  versus  1.13e-02
#          +  BiCGStab = 0.02  min |  1.38 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.011344315586462563,
#  'iterations': 61,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.02  min |  1.43 seconds
# --> times building full visibility model = 0.02  min |  1.44 seconds
# FWHM= 0.03411543523854569 +/- 0.00040695376275130677 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 619  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.65 seconds
#         +  Building system = 0.04  min |  2.69 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  9.03e+07  versus  9.03e-03
#       .... iteration  10 :   actual tol  1.25e+06  versus  9.03e-03
#       .... iteration  20 :   actual tol  2.92e+04  versus  9.03e-03
#       .... iteration  30 :   actual tol  2.66e+03  versus  9.03e-03
#       .... iteration  40 :   actual tol  3.36e+01  versus  9.03e-03
#       .... iteration  50 :   actual tol  6.43e-01  versus  9.03e-03
#       .... iteration  60 :   actual tol  1.27e-02  versus  9.03e-03
#          +  BiCGStab = 0.03  min |  1.56 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.009028797055763654,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.11  min |  6.85 seconds
# --> times building full visibility model = 0.11  min |  6.87 seconds
# FWHM= 0.03163925248078839 +/- 0.00039193362672141035 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 774  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.24 seconds
#         +  Building system = 0.04  min |  2.28 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  1.13e+08  versus  1.13e-02
#       .... iteration  10 :   actual tol  1.26e+06  versus  1.13e-02
#       .... iteration  20 :   actual tol  1.22e+05  versus  1.13e-02
#       .... iteration  30 :   actual tol  5.87e+02  versus  1.13e-02
#       .... iteration  40 :   actual tol  1.45e+01  versus  1.13e-02
#       .... iteration  50 :   actual tol  1.03e+00  versus  1.13e-02
#       .... iteration  60 :   actual tol  1.74e-02  versus  1.13e-02
#          +  BiCGStab = 0.02  min |  1.30 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.011344382355631025,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.17  min |  9.97 seconds
# --> times building full visibility model = 0.17  min |  10.00 seconds
# FWHM= 0.030792046657540345 +/- 0.00019167126564074324 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 929  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.26 seconds
#         +  Building system = 0.04  min |  2.30 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  9.03e+07  versus  9.03e-03
#       .... iteration  10 :   actual tol  1.25e+06  versus  9.03e-03
#       .... iteration  20 :   actual tol  2.92e+04  versus  9.03e-03
#       .... iteration  30 :   actual tol  2.66e+03  versus  9.03e-03
#       .... iteration  40 :   actual tol  3.36e+01  versus  9.03e-03
#       .... iteration  50 :   actual tol  6.43e-01  versus  9.03e-03
#       .... iteration  60 :   actual tol  1.27e-02  versus  9.03e-03
#          +  BiCGStab = 0.02  min |  1.23 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.009028797055763654,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.23  min |  14.04 seconds
# --> times building full visibility model = 0.23  min |  14.07 seconds
# FWHM= 0.030338181337693993 +/- 0.0003175143761713989 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 1084  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.11 seconds
#         +  Building system = 0.04  min |  2.15 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  1.13e+08  versus  1.13e-02
#       .... iteration  10 :   actual tol  1.26e+06  versus  1.13e-02
#       .... iteration  20 :   actual tol  1.22e+05  versus  1.13e-02
#       .... iteration  30 :   actual tol  5.87e+02  versus  1.13e-02
#       .... iteration  40 :   actual tol  1.45e+01  versus  1.13e-02
#       .... iteration  50 :   actual tol  1.03e+00  versus  1.13e-02
#       .... iteration  60 :   actual tol  1.74e-02  versus  1.13e-02
#          +  BiCGStab = 0.02  min |  1.23 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.011344382355631025,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.32  min |  19.37 seconds
# --> times building full visibility model = 0.32  min |  19.41 seconds
# FWHM= 0.03045753785628603 +/- 0.00015986382680206184 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 1238  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.27 seconds
#         +  Building system = 0.04  min |  2.31 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  1.13e+08  versus  1.13e-02
#       .... iteration  10 :   actual tol  1.26e+06  versus  1.13e-02
#       .... iteration  20 :   actual tol  1.22e+05  versus  1.13e-02
#       .... iteration  30 :   actual tol  5.87e+02  versus  1.13e-02
#       .... iteration  40 :   actual tol  1.45e+01  versus  1.13e-02
#       .... iteration  50 :   actual tol  1.03e+00  versus  1.13e-02
#       .... iteration  60 :   actual tol  1.74e-02  versus  1.13e-02
#          +  BiCGStab = 0.02  min |  1.29 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.011344382355631025,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.43  min |  25.89 seconds
# --> times building full visibility model = 0.43  min |  25.95 seconds
# FWHM= 0.030743214677177545 +/- 0.0001510178127854276 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 1548  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.22 seconds
#         +  Building system = 0.04  min |  2.26 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  1.13e+08  versus  1.13e-02
#       .... iteration  10 :   actual tol  1.26e+06  versus  1.13e-02
#       .... iteration  20 :   actual tol  1.22e+05  versus  1.13e-02
#       .... iteration  30 :   actual tol  5.87e+02  versus  1.13e-02
#       .... iteration  40 :   actual tol  1.45e+01  versus  1.13e-02
#       .... iteration  50 :   actual tol  1.03e+00  versus  1.13e-02
#       .... iteration  60 :   actual tol  1.74e-02  versus  1.13e-02
#          +  BiCGStab = 0.02  min |  1.30 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.011344382355631025,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 0.68  min |  40.53 seconds
# --> times building full visibility model = 0.68  min |  40.62 seconds
# FWHM= 0.03055419114610967 +/- 0.00013187375382805078 arcsec
# xxxxxxxxxxxxxxxxxxxxxx N = 1857  xxxxxxxxxxxxxxxxxxxxxx
# ===>  Setting gridded data...
# ===>  Setting GP Kernel wend...
#         + Kernel parameters:  {'m': -1.6022270950588295, 'c': 103492.73642088867, 'l': 26144.727973944253}
# ===>  Creating sparse linear system...
#         +  Kernel = 0.04  min |  2.20 seconds
#         +  Building system = 0.04  min |  2.24 seconds
# ===>  Solving linear system...
#       .... iteration  0 :   actual tol  9.03e+07  versus  9.03e-03
#       .... iteration  10 :   actual tol  1.25e+06  versus  9.03e-03
#       .... iteration  20 :   actual tol  2.92e+04  versus  9.03e-03
#       .... iteration  30 :   actual tol  2.66e+03  versus  9.03e-03
#       .... iteration  40 :   actual tol  3.36e+01  versus  9.03e-03
#       .... iteration  50 :   actual tol  6.43e-01  versus  9.03e-03
#       .... iteration  60 :   actual tol  1.27e-02  versus  9.03e-03
#          +  BiCGStab = 0.02  min |  1.30 seconds
# {'CGM_converged': True,
#  'Fit_correctly': True,
#  'convergence_by': 'norm of r',
#  'final_tol': 0.009028797055763654,
#  'iterations': 63,
#  'maxiter': 50000,
#  'preconditioner_method': 'jacobi',
#  'rtol': 1e-10}
# Building full visibility model...
#      + Setting kernel..
# --> time building S_12_T = 1.00  min |  60.26 seconds
# --> times building full visibility model = 1.01  min |  60.40 seconds
# FWHM= 0.02940703185648275 +/- 0.00022088885698392981 arcsec

# %%
plt.figure(figsize=(6,3))
plt.errorbar(Ns, np.array(resolutions)*1000, yerr=np.array(resolutions_error)*1000, fmt='x:', color='C3')
plt.xlabel('Number of pixels N')
plt.axhline(y=26, color='k', linestyle='--', label='26 mas')
plt.ylabel('FWHM [mas]')
plt.legend()
plt.show()

# %% [markdown]
# ### FWHM

# %%
# deproject
x_model_1d, y_model_1d = geom_f2d.deproject_xy(Plot_._x_model_1d, Plot_._y_model_1d)
x_model, y_model = Plot_._x_model, Plot_._y_model

# %%
I = Plot_._int_model

# %%
r_ = np.unique(np.hypot(x_model_1d, y_model_1d))
bins_f2d = 3*N
r = np.linspace(r_.min(), r_.max(), bins_f2d)
edges = Plot_.edges(r)

# %%
r_f2d, I_f2d = Plot_.get_profile(x_model, y_model, I, bins = edges)

# %%
I_f2d = np.nan_to_num(I_f2d, nan=0)

# %%
popt_frank2d, cov = curve_fit(gauss, r_f2d, I_f2d/np.max(I_f2d), p0=[0.09])
FWHM_frank2d = popt_frank2d[0]* 2. *np.sqrt(2.*np.log(2.))
Error_FWHM_f2d = np.sqrt(cov[0][0])* 2. *np.sqrt(2.*np.log(2.))

# %%
plt.close()
plt.figure(figsize=(6,2))
plt.plot(r_f2d, I_f2d, color='C0',label= r'Frank2D Solution, $N^{2}$ pixels with N = ' + str(N))
plt.plot(r_f2d, gauss(r_f2d, *popt_frank2d)*np.max(I_f2d), color='C1', label='Fit, FWHM=%.1f mas'%(FWHM_frank2d*1000))
plt.ylabel(r'I [Jy/$sr^{-1}$]')
plt.xlabel('r ["]')
plt.xlim(0.4, rout)
plt.ylim(-1e10, 1.4e11)

plt.title(r'F2D: $\delta$ Ring, $N_{bins}$ = '+ str(bins_f2d))
plt.legend(loc='best', fontsize = 8)

# %%
print ('FWHM=', FWHM_frank2d, '+/-', Error_FWHM_f2d, 'arcsec')
# Out:
# FWHM= 0.02512462865555891 +/- 9.290774739879294e-05 arcsec

# %% [markdown]
# ### Frank1D

# %%
# UVtable
dir = "../../../data/uvtables/"
data_file = dir +'uvtable_' + disk_name + '_continuum_1d.txt'

 # load data||
u_f1d, v_f1d, Re_f1d, Imag_f1d, Weights_f1d = u, v, Re, Im, Weights
Vis_f1d = Re_f1d + Imag_f1d*1j

# %%
u_f1d_d, v_f1d_d, _ = geom_f2d.deproject(u_f1d, v_f1d)
dbaseline_f1d = np.hypot(u_f1d_d, v_f1d_d)
baseline_f1d = np.hypot(u_f1d, v_f1d)

# %%
baseline_ring_f1d = dbaseline_f1d

# %%
Re_ring = np.median(Re_f1d[np.where(baseline_ring_f1d<3e4)])*np.real(j0(2.*np.pi*(rout/rad_to_arcsec/2.)*baseline_ring_f1d))

# %%
Imag_ring = np.zeros(len(Re_ring))
Vis_f1d = Re_ring + Imag_ring*1j

# %%
rout
# Out:
# 2.4

# %%
# Frank 1D parameters
n_pts = 1100
alpha = 1.05
w_smooth = 1e-4
r_out = rout

geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)
FF = FrankFitter(r_out, n_pts, geom, alpha = alpha, weights_smooth = w_smooth)
sol = FF.fit(u_f1d, v_f1d, Vis_f1d, Weights_f1d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 9
#       7 geom = SourceGeometry(inc= inc, PA= pa, dRA= dra, dDec= ddec)
#       8 FF = FrankFitter(r_out, n_pts, geom, alpha = alpha, weights_smooth = w_smooth)
# ----> 9 sol = FF.fit(u_f1d, v_f1d, Vis_f1d, Weights_f1d)
#
# File ~/.conda/envs/py3/lib/python3.12/site-packages/frank/radial_fitters.py:569, in FourierBesselFitter.fit(self, u, v, V, weights)
#     564     logging.info('  Fitting for brightness profile using'
#     565                  ' {}'.format(self.fit_method()))
#     567 self._geometry.fit(u, v, V, weights)
# --> 569 mapping = self.preprocess_visibilities(u, v, V, weights)
#     570 self._build_matrices(mapping)
#     572 return self._fit()
#
# File ~/.conda/envs/py3/lib/python3.12/site-packages/frank/radial_fitters.py:498, in FourierBesselFitter.preprocess_visibilities(self, u, v, V, weights)
#     468 def preprocess_visibilities(self, u, v, V, weights=1):
#     469     r"""Prepare the visibilities for fitting.
#     470
#     471     This step will be done by the automatically fit method, but it can be
#    (...)
#     496     conducted.
#     497     """
# --> 498     return self._vis_map.map_visibilities(u, v, V, weights)
#
# File ~/.conda/envs/py3/lib/python3.12/site-packages/frank/statistical_models.py:206, in VisibilityMapping.map_visibilities(self, u, v, V, weights, frequencies, geometry)
#     203 ws = wi[start:end]
#     204 Vs = Vi[start:end]
# --> 206 X = self._get_mapping_coefficients(qs, ks)
#     208 wXT = np.array(X.T * ws, order='C')
#     210 Ms[i] += np.dot(wXT, X)
#
# File ~/.conda/envs/py3/lib/python3.12/site-packages/frank/statistical_models.py:487, in VisibilityMapping._get_mapping_coefficients(self, qs, ks, geometry, inverse)
#     484 else:
#     485     direction='forward'
# --> 487 H = self._DHT.coefficients(qs, direction=direction) * scale
#     489 return H
#
# File ~/.conda/envs/py3/lib/python3.12/site-packages/frank/hankel.py:202, in DiscreteHankelTransform.coefficients(self, q, direction)
#     198 if q is None:
#     199     return 0.5 * self._j_nN * norm * self._Ykm
#     201 H = (norm * self._scale_factor) * \
# --> 202     self._jnu0(np.outer(k * q, self._j_nk))
#     204 return H
#
# KeyboardInterrupt:

# %%
r_f1d = sol.r
I_f1d = sol.mean

# %%
#Plot_2 = Plot(frank2d, geom_f2d)

#r_ = np.unique(np.hypot(x_model_1d, y_model_1d))
#r_ = r_f1d

#bins = 500
#r = np.linspace(r_.min(), r_.max(), bins)
#edges = Plot_.edges(r)

#r_f1d, I_f1d = Plot_.get_profile(sol.r, sol.r, sol.mean, bins = edges, fit_1d = True)

#I_f1d = np.nan_to_num(I_f1d, nan=0)

# %%
popt_frank1d, cov_frank1d = curve_fit(gauss, r_f1d, I_f1d/np.max(I_f1d), p0=[0.02])
FWHM_frank1d = popt_frank1d[0]* 2. *np.sqrt(2.*np.log(2.))
Error_FWHM_frank1d = np.sqrt(cov_frank1d[0][0])* 2. *np.sqrt(2.*np.log(2.))

# %%
print ('FWHM=', FWHM_frank1d, '+/-', Error_FWHM_frank1d, 'arcsec')
# Out:
# FWHM= 0.014728107962258659 +/- 0.00016069426374943485 arcsec

# %%
plt.close()
plt.figure(figsize=(6,2))
plt.plot(r_f1d, I_f1d, color='C0',label= r'Frank1D Solution, $N^{2}$ pixels with N = ' + str(n_pts))
plt.plot(r_f1d, gauss(r_f1d, *popt_frank1d)*np.max(sol.mean), color='C1', label='Fit, FWHM=%.1f mas'%(FWHM_frank1d*1000))
plt.ylabel(r'I [Jy/$sr^{-1}$]')
plt.xlabel('r ["]')
plt.xlim(1, 1.8)
plt.title(r'F1D: $\delta$ Ring, no binning')
plt.legend(loc='best', fontsize = 9)

# %%
plt.close()
plt.figure(figsize=(4,2))
plt.plot(r_f1d, I_f1d,label= r'F2D, $N^{2}$ pixels (N = ' + str(N) + '), bins ='+  ' no bins' + ', FWHM = %.1f mas'%(FWHM_frank1d*1000))
plt.plot(r_f2d, I_f2d, label= r'F2D, $N^{2}$ pixels (N = ' + str(N) + '), bins ='+  str(bins_f2d) + ', FWHM = %.1f mas'%(FWHM_frank2d*1000))
plt.ylabel(r'I [Jy/$sr^{-1}$]')
plt.xlabel('r ["]')
plt.xlim(1, 1.8)
plt.ylim(-3e10, 2e11)
plt.title(r'$\delta$ Ring')
plt.legend(loc='best', fontsize = 6)

# %%
plt.close()
plt.figure(figsize=(4,2))
plt.plot(sol.r, gauss(sol.r, *popt_frank1d)*np.max(sol.mean), label='Fit F1D, FWHM=%.1f mas'%(FWHM_frank1d*1000))
plt.plot(r, gauss(r, *popt_frank2d)*np.max(I), label='Fit F2D, FWHM=%.1f mas'%(FWHM_frank2d*1000))
plt.ylabel(r'I [Jy/$sr^{-1}$]')
plt.xlabel('r ["]')
plt.xlim(1, 1.8)
plt.title('Gaussian fits')
plt.legend(loc='best', fontsize = 9)

# %% [markdown]
# ### Convolve to the f2d beam

# %%
sigma_final = np.sqrt(FWHM_frank2d**2 - FWHM_frank1d**2)
sigma_final
# Out:
# 0.01795838309477733

# %%
beam_1mm = {'bmaj':sigma_final, 'bmin':sigma_final, 'beam_pa':geom.PA}
convolved_frank1d = convolve_profile(r_f1d, I_f1d, geom.inc, geom.PA, beam_1mm)

# %%
plt.figure(figsize=(7, 4))
plt.plot(r_f2d, I_f2d, "red", label=r'frank2d' + ', N = ' +str(n_pts))
plt.plot(r_f1d, convolved_frank1d, "blue", label=r'frank1d' + ', N = ' +str(N)+ ' convolved')
plt.title(r'Radial profile delta ring', size=10)
plt.ylabel("log(I) [Jy/beam]", size=10)
plt.xlabel('r ["]', size=10)
plt.xlim(0.6, 1.7)
plt.ylim(-1e10, 10e10)
plt.legend(fontsize=10)
plt.show()

# %%
popt_frank1d_conv, cov_frank1d_conv = curve_fit(gauss, r_f1d, convolved_frank1d/np.max(convolved_frank1d), p0=[0.009])
FWHM_frank1d_conv = popt_frank1d_conv[0]* 2. *np.sqrt(2.*np.log(2.))
Error_FWHM_frank1d_conv = np.sqrt(cov_frank1d[0][0])* 2. *np.sqrt(2.*np.log(2.))

# %%
FWHM_frank1d_conv
# Out:
# 0.0225764452262478

# %% [markdown]
# ### Trying with real disk

# %%
u, v, Re, Im, Weights = file['u'], file['v'], file['Re'], file['Im'], file['w']
Vis = Re + Im*1j

# %%
N = 300
best = {'m': -1.011407337728121, 'c': 222.9257843669846, 'l': 46452.74921193543}

# %%
geom = Geometry(inc, pa, dra, ddec)
frank2d = Frank2D(N, rout, geom)

# %%
uvtable = {'u': u, 'v': v, 'vis': Vis, 'weights': Weights}

# %%
start_time = time.time()


frank2d.fit(data = uvtable, kernel_params = best, rtol = 1e-8 )

end_time = time.time()
print(f"F2D model in {(end_time - start_time):.2f} seconds.")
# Out:
# Warning: You are using the default grid from the Fourier Transform object.
# Shifted grid..
# Setting gridded data...
# Setting GP Kernel Wendland...
# Creating sparse linear system...
# --> time kernel = 0.02  min |  1.37 seconds
# --> time = 0.02  min |  1.41 seconds
# Solving linear system...
#          * rtol: 1e-08
#          * final tolerance: 3.5986215447871888
# Final tolerance :  3.5986215447871888
# .... iteration:  0
#                         -> actual tol:  359862154.4787189 vs  3.5986215447871888
# .... iteration:  1
#                         -> actual tol:  16248311.289388938 vs  3.5986215447871888
# .... iteration:  2
#                         -> actual tol:  12793022.141465731 vs  3.5986215447871888
# .... iteration:  3
#                         -> actual tol:  17458649.174258534 vs  3.5986215447871888
# .... iteration:  4
#                         -> actual tol:  3767348.9717458216 vs  3.5986215447871888
# .... iteration:  5
#                         -> actual tol:  5315434.46853328 vs  3.5986215447871888
# .... iteration:  6
#                         -> actual tol:  1524640.4976162645 vs  3.5986215447871888
# .... iteration:  7
#                         -> actual tol:  903407.702382685 vs  3.5986215447871888
# .... iteration:  8
#                         -> actual tol:  815463.257929798 vs  3.5986215447871888
# .... iteration:  9
#                         -> actual tol:  2790920.4632909377 vs  3.5986215447871888
# .... iteration:  10
#                         -> actual tol:  2259928.1989242197 vs  3.5986215447871888
# .... iteration:  11
#                         -> actual tol:  129595.18249834844 vs  3.5986215447871888
# .... iteration:  12
#                         -> actual tol:  89173.23244835033 vs  3.5986215447871888
# .... iteration:  13
#                         -> actual tol:  67475.02639453093 vs  3.5986215447871888
# .... iteration:  14
#                         -> actual tol:  52598.640982761695 vs  3.5986215447871888
# .... iteration:  15
#                         -> actual tol:  49045.71008266409 vs  3.5986215447871888
# .... iteration:  16
#                         -> actual tol:  65128.43038287573 vs  3.5986215447871888
# .... iteration:  17
#                         -> actual tol:  14858.402218825353 vs  3.5986215447871888
# .... iteration:  18
#                         -> actual tol:  24555.84110174377 vs  3.5986215447871888
# .... iteration:  19
#                         -> actual tol:  2096.817515142131 vs  3.5986215447871888
# .... iteration:  20
#                         -> actual tol:  1712.177335847556 vs  3.5986215447871888
# .... iteration:  21
#                         -> actual tol:  1554.771076673883 vs  3.5986215447871888
# .... iteration:  22
#                         -> actual tol:  10909.335376129346 vs  3.5986215447871888
# .... iteration:  23
#                         -> actual tol:  351.45190138534093 vs  3.5986215447871888
# .... iteration:  24
#                         -> actual tol:  117.02274767718261 vs  3.5986215447871888
# .... iteration:  25
#                         -> actual tol:  100.51750475792011 vs  3.5986215447871888
# .... iteration:  26
#                         -> actual tol:  94.80675282666857 vs  3.5986215447871888
# .... iteration:  27
#                         -> actual tol:  66.2532425044799 vs  3.5986215447871888
# .... iteration:  28
#                         -> actual tol:  50.657884132744385 vs  3.5986215447871888
# .... iteration:  29
#                         -> actual tol:  345.15460560077565 vs  3.5986215447871888
# .... iteration:  30
#                         -> actual tol:  6.3081249296096695 vs  3.5986215447871888
# .... iteration:  31
#                         -> actual tol:  3.8249275754509067 vs  3.5986215447871888
# .... iteration:  32
#                         -> actual tol:  9.529243526573866 vs  3.5986215447871888
# converged by norm of s
# --> time = 0.02  min |  0.93 seconds
#                ---> CGM converged?   True
#                     ---> Fit correctly?   False
# Building full visibility model...
# F2D model in 28.01 seconds.

# %%
FWHM_frank2d = 0.022905863089907247
FWHM_frank1d = 0.011191120375380921

# %%
Plot_ = Plot(frank2d, geom)

# %%
from astropy.io import fits
dir =  "/Users/mariajmelladot/Desktop/Frank2D/data/fits/"
disk = disk_name + '_continuum.fits'

fits_name = dir + disk

# %%
Plot_.set_fits_file(fits_name)

# %%
sol_f1d = frank2d.frank1d(uvtable, alpha=1.2, w_smooth=1e-3, n_pts=300, rout=rout, geom=geom)
# Out:
# Performing 1D Frank fit...
#
# $\alpha$ =  1.2  and $w_{smooth}$ =  0.001
#
# N =  300  and $R_{max}$ =  1.9

# %%
Plot_.set_f1d_solution(sol_f1d)

# %%
Plot_.intensity_profile(   clean = True, frank1d = True,
                            resol_f2d = FWHM_frank2d, resol_f1d = FWHM_frank1d
                        )
# Out:
# WARNING: Provided cube is only 2D. Shifting not available.
# WARNING: Attached data is not 3D, so shifting cannot be applied.
# 	 Reverting to standard azimuthal averaging; will ignore `unit` argument.
# Clean beam: 0.038216292858108 x 0.036224924027904 arcsec
# FWHM for frank2d: 0.022905863089907247 arcsec
# -> Final beam to convolve with: 0.03059095415189107 x 0.028063616248335515 arcsec
# FWHM for frank1d: 0.011191120375380921 arcsec
# -> Final beam to convolve with: 0.0365409888284432 x 0.034452923614276196 arcsec

# %%
Plot_.intensity_profile(   clean = False, frank1d = True,
                            resol_f2d = FWHM_frank2d, resol_f1d = FWHM_frank1d, 
                            y_lims = (1e8, 1e12)
                        )
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Plot_.intensity_profile(   clean = False, frank1d = True,
#       2                             resol_f2d = FWHM_frank2d, resol_f1d = FWHM_frank1d,
#       3                             y_lims = (1e8, 1e12)
#       4                         )
#
# File ~/Desktop/Frank2D/6_Frank2D_Oficial/frank2d/frank2d/plot.py:444, in Plot.intensity_profile(self, title, clean, frank1d, bins, Rmax, resol_f2d, resol_f1d, log_scale, x_lims, y_lims)
#     442 plt.title(title)
#     443 plt.xlim(x_lims)
# --> 444 plt.ylim(y_lims_sr)
#     445 if log_scale:
#     446     plt.yscale('log')
#
# UnboundLocalError: cannot access local variable 'y_lims_sr' where it is not associated with a value
